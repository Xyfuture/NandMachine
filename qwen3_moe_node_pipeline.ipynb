# %% [markdown]
# # Node-Level Frontend Pipeline For Qwen3 MoE
#
# 实现 Qwen3 MoE decoder layer 的最小前端全流程，并在 code gen pass 之后按 node 读取 `marco_op_list`，对每个 node 单独运行硬件仿真，同时对完整 `macro_op_list` 运行一次整体硬件仿真，并把 perf trace 输出到 `trace/qwen3_moe/` 目录。

# %% [markdown]
# ## 流程
# - 加载 `qwen3-moe-235B` model card 并初始化 `Qwen3MoEModelConfig`
# - 初始化 `NandConfig`、`MoEParallelConfig` 和 `InferenceConfig`
# - 初始化 `Qwen3MoEDecoderLayer`
# - 使用 `NxTracer` trace 得到计算图
# - 运行 `NormalizePass` 获得简化图
# - 用 `build_kv_cache_state` 构造 `KVCacheState`
# - 构造 `NxGraphMeta` 并写入 `graph.meta`
# - 运行 `CodeGenPass`，收集全局和 node 级别的 `marco_op_list`
# - 对完整 `macro_op_list` 运行一次硬件仿真，并把完整 trace 保存到 `trace/qwen3_moe/full_simulation.json`
# - 对每个 node 单独运行硬件仿真，并把 node trace 保存到 `trace/qwen3_moe/` 目录
# - 汇总完整仿真和 node 级别的 macro op、时延和 trace 信息

# %%
import json
import logging
import re
from collections import Counter
from dataclasses import fields, is_dataclass
from math import ceil
from pathlib import Path
from pprint import pprint

import torch
from Desim import SimSession
from torch.fx import GraphModule

from nandmachine.commands.macro import All2AllOp, FlashAttnOp, MacroOp, MatMulOp, VectorOp
from nandmachine.config.config import NandConfig
from nandmachine.config.hardware_config import get_device_or_raise
from nandmachine.config.inference_config import InferenceConfig, MoEParallelConfig
from nandmachine.config.model_config import Qwen3MoEModelConfig
from nandmachine.frontend.core.graph.base import NxGraphMeta, NxTracer
from nandmachine.frontend.core.passes.cod_gen import CodeGenPass
from nandmachine.frontend.core.passes.normalize import NormalizePass
from nandmachine.frontend.network.qwen3_moe import Qwen3MoEDecoderLayer
from nandmachine.frontend.utlis import build_kv_cache_state
from nandmachine.simulator.hardware.xpu import xPU

MODEL_CARD_PATH = Path("model_cards/qwen3-moe-235B.json")
DEVICE_NAME = "H200_SXM"
COMPILE_MODE = "heuristic-GPU"
NUM_RANKS = 8
ATTN_DP_SIZE = 8
ATTN_TP_SIZE = 1
FFN_TP_SIZE = 1
FFN_EP_SIZE = 8
HBM_BANDWIDTH_GBPS = 3350
TRACE_DIR = Path("trace/qwen3_moe")
FULL_TRACE_FILE_NAME = "full_simulation.json"

assert MODEL_CARD_PATH.exists(), MODEL_CARD_PATH
assert NUM_RANKS > 0, NUM_RANKS
assert ATTN_DP_SIZE > 0, ATTN_DP_SIZE
assert ATTN_TP_SIZE > 0, ATTN_TP_SIZE
assert FFN_TP_SIZE > 0, FFN_TP_SIZE
assert FFN_EP_SIZE > 0, FFN_EP_SIZE


def node_summary(graph_module: GraphModule) -> list[tuple[str, str, str]]:
    return [(node.name, node.op, str(node.target)) for node in graph_module.graph.nodes]


def macro_summary(macro_op_list: list[object]) -> Counter:
    return Counter(type(op).__name__ for op in macro_op_list)


def node_info(node: torch.fx.Node) -> dict[str, object]:
    return {
        "node_name": node.name,
        "node_op": node.op,
        "node_target": str(node.target),
    }


def _serialize_value(value: object) -> object:
    if isinstance(value, MacroOp):
        return {
            "id": value.id,
            "type": type(value).__name__,
        }
    if isinstance(value, list):
        return [_serialize_value(item) for item in value]
    if isinstance(value, tuple):
        return tuple(_serialize_value(item) for item in value)
    return value


def macro_info(op: MacroOp) -> dict[str, object]:
    assert is_dataclass(op), type(op)
    payload = {field.name: _serialize_value(getattr(op, field.name)) for field in fields(op)}
    payload["type"] = type(op).__name__
    return payload


def _sanitize_trace_name(raw_name: str) -> str:
    return re.sub(r"[^0-9A-Za-z._-]+", "_", raw_name).strip("._")


def trace_file_path(node_index: int, node: torch.fx.Node) -> Path:
    file_name = _sanitize_trace_name(f"node_{node_index:03d}_{node.name}_{node.op}")
    return TRACE_DIR / f"{file_name}.json"


def full_trace_file_path() -> Path:
    return TRACE_DIR / FULL_TRACE_FILE_NAME


def run_macro_ops_with_trace(
    nand_config: NandConfig,
    commands: list[MacroOp],
    *,
    trace_path: Path,
    device_name: str,
    compile_mode: str,
    hbm_bandwidth_GBps: float,
) -> dict[str, object]:
    SimSession.reset()
    SimSession.init()

    hbm_bandwidth_bytes_per_sec = hbm_bandwidth_GBps * 10**9

    sim_xpu = xPU(
        nand_config,
        hbm_bandwidth_bytes_per_sec=hbm_bandwidth_bytes_per_sec,
        device_name=device_name,
        compile_mode=compile_mode,
        enable_trace=True,
    )
    sim_xpu.load_command(commands)
    SimSession.scheduler.run()

    final_time_ns = int(SimSession.sim_time.cycle)
    device = get_device_or_raise(device_name)
    final_cycle = ceil(final_time_ns * device.compute_module.clock_freq / 1e9)

    trace_path.parent.mkdir(parents=True, exist_ok=True)
    saved_trace_path = Path(sim_xpu.save_trace_file(str(trace_path)))

    tracer = sim_xpu.tracer
    assert tracer is not None
    complete_events = [event for event in tracer._events if event["ph"] == "X"]

    return {
        "cycle": final_cycle,
        "time_ns": final_time_ns,
        "trace_path": str(saved_trace_path),
        "trace_event_count": len(tracer._events),
        "trace_complete_event_count": len(complete_events),
        "trace_complete_event_categories": dict(
            Counter(event["cat"] for event in complete_events)
        ),
    }

# %%
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
)

model_card = json.loads(MODEL_CARD_PATH.read_text())
model_card.setdefault("attention_type", "gqa")
raw_model_config = type("Qwen3MoeConfig", (), model_card)()
model_config = Qwen3MoEModelConfig.from_config(raw_model_config)
nand_config = NandConfig(
    num_channels=6 * 8,
    num_plane=96,
    num_block=16, # 没什么用的参数
    num_pages=16, # 没什么用的参数
    tRead=4000, # ns
    tWrite=4000 * 10, # ns
    tErase=4000 * 100, # ns
    page_size=4, # KB
    sram_threshold=1024 * 80,  # KB  --  可以考虑之后统一改成 Bytes，统一所有的单位
)
parallel_config = MoEParallelConfig(
    num_ranks=NUM_RANKS,
    attn_dp_size=ATTN_DP_SIZE,
    attn_tp_size=ATTN_TP_SIZE,
    ffn_tp_size=FFN_TP_SIZE,
    ffn_ep_size=FFN_EP_SIZE,
)
inference_config = InferenceConfig(
    batch_size=128,
    input_sequence_length=8*1024,
    output_sequence_length=1*1024,
    weight_bits=16,
    activation_bits=16,
    kv_cache_bits=16,
    kv_block_size_bytes=1024 * 256,
    memory_backend="nand",
    parallel_config=parallel_config,
)
kv_cache_state = build_kv_cache_state(nand_config, model_config, inference_config)
graph_meta = NxGraphMeta(
    nand_config=nand_config,
    model_config=model_config,
    inference_config=inference_config,
    kv_cache_state=kv_cache_state,
)
simulator_config = {
    "device_name": DEVICE_NAME,
    "compile_mode": COMPILE_MODE,
    "hbm_bandwidth_GBps": HBM_BANDWIDTH_GBPS,
}
runtime_simulator_config = {
    "device_name": simulator_config["device_name"],
    "compile_mode": simulator_config["compile_mode"],
    "hbm_bandwidth_GBps": simulator_config["hbm_bandwidth_GBps"],
}
TRACE_DIR.mkdir(parents=True, exist_ok=True)

print("HBM bandwidth (GBps):", HBM_BANDWIDTH_GBPS)
print("trace output dir:", TRACE_DIR)
print("full simulation trace path:", full_trace_file_path())
print("parallel config:", parallel_config)
print("simulator config:", simulator_config)
# Out:
# HBM bandwidth (GBps): 3350
# trace output dir: trace/qwen3_moe
# full simulation trace path: trace/qwen3_moe/full_simulation.json
# parallel config: MoEParallelConfig(num_ranks=8, attn_dp_size=8, attn_tp_size=1, ffn_tp_size=1, ffn_ep_size=8)
# simulator config: {'device_name': 'H200_SXM', 'compile_mode': 'heuristic-GPU', 'hbm_bandwidth_GBps': 3350}

# %%
with torch.device("meta"):
    model = Qwen3MoEDecoderLayer(raw_model_config, parallel_config)
    graph = NxTracer().trace(model)
    graph_module = GraphModule(model, graph)

NormalizePass().transform(graph_module)
graph_module.graph.meta = {CodeGenPass.GRAPH_META_KEY: graph_meta}
CodeGenPass().transform(graph_module)

all_graph_nodes = list(graph_module.graph.nodes)
all_node_infos = [node_info(node) for node in all_graph_nodes]
node_count_with_macro_ops = sum(1 for node in all_graph_nodes if "marco_op_list" in node.meta)
macro_op_list = graph_module.graph.meta[CodeGenPass.MACRO_OP_LIST_META_KEY]
vector_ops = [op for op in macro_op_list if isinstance(op, VectorOp)]
all_to_all_ops = [op for op in macro_op_list if isinstance(op, All2AllOp)]

print("normalized node count:", len(node_summary(graph_module)))
print("node count with macro op entries:", node_count_with_macro_ops)
print("global macro op count:", len(macro_op_list))
print("global macro op type summary:", dict(macro_summary(macro_op_list)))
print("vector op type summary:", dict(Counter(op.vector_op_type for op in vector_ops)))
print("all_to_all count:", len(all_to_all_ops))
print("all node infos:")
for current_node_info in all_node_infos:
    pprint(current_node_info)
# Out:
# 2026-04-05 16:54:04,075 - INFO - Processed node=input_layernorm generated_macro_ops=1
# 2026-04-05 16:54:04,075 - INFO - Processed node=self_attn_qkv_proj generated_macro_ops=3
# 2026-04-05 16:54:04,075 - INFO - Processed node=self_attn_q_norm generated_macro_ops=1
# 2026-04-05 16:54:04,076 - INFO - Processed node=self_attn_k_norm generated_macro_ops=1
# 2026-04-05 16:54:04,076 - INFO - Processed node=self_attn_rotary_emb generated_macro_ops=0
# 2026-04-05 16:54:04,119 - INFO - Processed node=self_attn_attn generated_macro_ops=48
# 2026-04-05 16:54:04,119 - INFO - Processed node=self_attn_o_proj generated_macro_ops=3
# 2026-04-05 16:54:04,120 - INFO - Processed node=post_attention_layernorm generated_macro_ops=1
# 2026-04-05 16:54:04,120 - INFO - Processed node=mlp generated_macro_ops=119
# normalized node count: 13
# node count with macro op entries: 9
# global macro op count: 177
# global macro op type summary: {'VectorOp': 22, 'SramPrefetch': 51, 'MatMulOp': 35, 'SramPrefetchRelease': 51, 'FlashAttnOp': 16, 'All2AllOp': 2}
# vector op type summary: {'rms_norm': 4, 'moe_topk_router': 1, 'silu_mul': 16, 'moe_weighted_sum': 1}
# all_to_all count: 2
# all node infos:
# {'node_name': 'hidden_states',
#  'node_op': 'placeholder',
#  'node_target': 'hidden_states'}
# {'node_name': 'input_layernorm',
#  'node_op': 'call_module',
#  'node_target': 'input_layernorm'}
# {'node_name': 'self_attn_qkv_proj',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.qkv_proj'}
# {'node_name': 'self_attn_q_norm',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.q_norm'}
# {'node_name': 'self_attn_k_norm',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.k_norm'}
# {'node_name': 'self_attn__dummy_positions',
#  'node_op': 'get_attr',
#  'node_target': 'self_attn._dummy_positions'}
# {'node_name': 'self_attn_rotary_emb',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.rotary_emb'}
# {'node_name': 'self_attn_attn',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.attn'}
# {'node_name': 'self_attn_o_proj',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.o_proj'}
# {'node_name': 'add',
#  'node_op': 'call_function',
#  'node_target': '<built-in function add>'}
# {'node_name': 'post_attention_layernorm',
#  'node_op': 'call_module',
#  'node_target': 'post_attention_layernorm'}
# {'node_name': 'mlp', 'node_op': 'call_module', 'node_target': 'mlp'}
# {'node_name': 'add_1',
#  'node_op': 'call_function',
#  'node_target': '<built-in function add>'}

# %%
assert macro_op_list
assert all_graph_nodes
assert any(isinstance(op, MatMulOp) for op in macro_op_list)
assert any(isinstance(op, FlashAttnOp) for op in macro_op_list)
assert any(isinstance(op, All2AllOp) for op in macro_op_list)
assert any(op.vector_op_type == "moe_topk_router" for op in vector_ops)
assert any(op.vector_op_type == "moe_weighted_sum" for op in vector_ops)
assert any(op.vector_op_type == "silu_mul" for op in vector_ops)
assert any(op.vector_op_type == "rms_norm" for op in vector_ops)
assert all(all(dim > 0 for dim in op.vector_shape) for op in vector_ops)

print("qwen3 moe node-level frontend pipeline completed successfully")
# Out:
# qwen3 moe node-level frontend pipeline completed successfully

# %%
print("=" * 120)
print("full simulation")
print("macro op count:", len(macro_op_list))
print("macro op type summary:", dict(macro_summary(macro_op_list)))

full_trace_path = full_trace_file_path()
full_sim_result = run_macro_ops_with_trace(
    nand_config,
    macro_op_list,
    trace_path=full_trace_path,
    **runtime_simulator_config,
)
assert full_sim_result["cycle"] > 0
assert full_sim_result["time_ns"] > 0
print("sim cycle:", full_sim_result["cycle"])
print("sim time ns:", full_sim_result["time_ns"])
print("trace path:", full_sim_result["trace_path"])
print("trace event count:", full_sim_result["trace_event_count"])
print("trace complete event count:", full_sim_result["trace_complete_event_count"])
print(
    "trace complete event categories:",
    full_sim_result["trace_complete_event_categories"],
)

node_sim_results = []

for node_index, node in enumerate(all_graph_nodes):
    node_macro_ops = node.meta.get("marco_op_list", [])
    current_node_info = node_info(node)
    current_macro_summary = dict(macro_summary(node_macro_ops))

    print("=" * 120)
    print("node index:", node_index)
    print("node info:")
    pprint(current_node_info)
    print("macro op count:", len(node_macro_ops))
    print("macro op type summary:", current_macro_summary)

    serialized_macro_ops = [macro_info(op) for op in node_macro_ops]
    print("macro op details:")
    for macro_op_payload in serialized_macro_ops:
        pprint(macro_op_payload)

    if not node_macro_ops:
        print("simulation skipped because this node produced no macro ops")
        node_sim_results.append(
            {
                **current_node_info,
                "macro_op_count": 0,
                "macro_op_types": [],
                "sim_cycle": None,
                "sim_time_ns": None,
                "trace_path": None,
                "trace_event_count": None,
                "trace_complete_event_count": None,
                "trace_complete_event_categories": None,
                "macro_ops": serialized_macro_ops,
            }
        )
        continue

    current_trace_path = trace_file_path(node_index, node)
    sim_result = run_macro_ops_with_trace(
        nand_config,
        node_macro_ops,
        trace_path=current_trace_path,
        **runtime_simulator_config,
    )
    assert sim_result["cycle"] > 0
    assert sim_result["time_ns"] > 0
    print("sim cycle:", sim_result["cycle"])
    print("sim time ns:", sim_result["time_ns"])
    print("trace path:", sim_result["trace_path"])
    print("trace event count:", sim_result["trace_event_count"])
    print("trace complete event count:", sim_result["trace_complete_event_count"])
    print(
        "trace complete event categories:",
        sim_result["trace_complete_event_categories"],
    )

    node_sim_results.append(
        {
            **current_node_info,
            "macro_op_count": len(node_macro_ops),
            "macro_op_types": [type(op).__name__ for op in node_macro_ops],
            "sim_cycle": sim_result["cycle"],
            "sim_time_ns": sim_result["time_ns"],
            "trace_path": sim_result["trace_path"],
            "trace_event_count": sim_result["trace_event_count"],
            "trace_complete_event_count": sim_result["trace_complete_event_count"],
            "trace_complete_event_categories": sim_result[
                "trace_complete_event_categories"
            ],
            "macro_ops": serialized_macro_ops,
        }
    )
# Out:
# ========================================================================================================================
# full simulation
# macro op count: 177
# macro op type summary: {'VectorOp': 22, 'SramPrefetch': 51, 'MatMulOp': 35, 'SramPrefetchRelease': 51, 'FlashAttnOp': 16, 'All2AllOp': 2}
# VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 4096], weight_bits=16)
# MatMulOp(id=3, input_ops=[SramPrefetch(id=2, input_ops=[], num_prefetch_pages=18432), VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 4096], weight_bits=16)], dim=(128, 4096, 9216), weight_bits=16)
# VectorOp(id=5, input_ops=[MatMulOp(id=3, input_ops=[SramPrefetch(id=2, input_ops=[], num_prefetch_pages=18432), VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 4096], weight_bits=16)], dim=(128, 4096, 9216), weight_bits=16)], vector_op_type='rms_norm', vector_shape=[128, 128], weight_bits=16)
# VectorOp(id=6, input_ops=[VectorOp(id=5, input_ops=[MatMulOp(id=3, input_ops=[SramPrefetch(id=2, input_ops=[], num_prefetch_pages=18432), VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 4096], weight_bits=16)], dim=(128, 4096, 9216), weight_bits=16)], vector_op_type='rms_norm', vector_shape=[128, 128], weight_bits=16)], vector_op_type='rms_norm', vector_shape=[128, 128], weight_bits=16)
# FlashAttnOp(id=8, input_ops=[SramPrefetch(id=7, input_ops=[], num_prefetch_pages=4608), VectorOp(id=6, input_ops=[VectorOp(id=5, input_ops=[MatMulOp(id=3, input_ops=[SramPrefetch(id=2, input_ops=[], num_prefetch_pages=18432), VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 4096], weight_bits=16)], dim=(128, 4096, 9216), weight_bits=16)], vector_op_type='rms_norm', vector_shape=[128, 128], weight_bits=16)], vector_op_type='rms_norm', vector_shape=[128, 128], weight_bits=16)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=11, input_ops=[SramPrefetch(id=10, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=14, input_ops=[SramPrefetch(id=13, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=17, input_ops=[SramPrefetch(id=16, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=20, input_ops=[SramPrefetch(id=19, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=23, input_ops=[SramPrefetch(id=22, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=26, input_ops=[SramPrefetch(id=25, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=29, input_ops=[SramPrefetch(id=28, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=32, input_ops=[SramPrefetch(id=31, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=35, input_ops=[SramPrefetch(id=34, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=38, input_ops=[SramPrefetch(id=37, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=41, input_ops=[SramPrefetch(id=40, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=44, input_ops=[SramPrefetch(id=43, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=47, input_ops=[SramPrefetch(id=46, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=50, input_ops=[SramPrefetch(id=49, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=53, input_ops=[SramPrefetch(id=52, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# MatMulOp(id=56, input_ops=[SramPrefetch(id=55, input_ops=[], num_prefetch_pages=16384), FlashAttnOp(id=53, input_ops=[SramPrefetch(id=52, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)], dim=(128, 8192, 4096), weight_bits=16)
# VectorOp(id=58, input_ops=[MatMulOp(id=56, input_ops=[SramPrefetch(id=55, input_ops=[], num_prefetch_pages=16384), FlashAttnOp(id=53, input_ops=[SramPrefetch(id=52, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)], dim=(128, 8192, 4096), weight_bits=16)], vector_op_type='rms_norm', vector_shape=[128, 4096], weight_bits=16)
# MatMulOp(id=60, input_ops=[SramPrefetch(id=59, input_ops=[], num_prefetch_pages=256), VectorOp(id=58, input_ops=[MatMulOp(id=56, input_ops=[SramPrefetch(id=55, input_ops=[], num_prefetch_pages=16384), FlashAttnOp(id=53, input_ops=[SramPrefetch(id=52, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)], dim=(128, 8192, 4096), weight_bits=16)], vector_op_type='rms_norm', vector_shape=[128, 4096], weight_bits=16)], dim=(128, 4096, 128), weight_bits=16)
# VectorOp(id=62, input_ops=[], vector_op_type='moe_topk_router', vector_shape=[128, 128, 8], weight_bits=16)
# MatMulOp(id=65, input_ops=[SramPrefetch(id=64, input_ops=[], num_prefetch_pages=6144), All2AllOp(id=63, input_ops=[VectorOp(id=62, input_ops=[], vector_op_type='moe_topk_router', vector_shape=[128, 128, 8], weight_bits=16)], num_gpus=8, data_size=1048576, weight_bits=16)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=67, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=69, input_ops=[SramPrefetch(id=68, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=72, input_ops=[SramPrefetch(id=71, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=74, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=76, input_ops=[SramPrefetch(id=75, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=79, input_ops=[SramPrefetch(id=78, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=81, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=83, input_ops=[SramPrefetch(id=82, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=86, input_ops=[SramPrefetch(id=85, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=88, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=90, input_ops=[SramPrefetch(id=89, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=93, input_ops=[SramPrefetch(id=92, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=95, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=97, input_ops=[SramPrefetch(id=96, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=100, input_ops=[SramPrefetch(id=99, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=102, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=104, input_ops=[SramPrefetch(id=103, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=107, input_ops=[SramPrefetch(id=106, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=109, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=111, input_ops=[SramPrefetch(id=110, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=114, input_ops=[SramPrefetch(id=113, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=116, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=118, input_ops=[SramPrefetch(id=117, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=121, input_ops=[SramPrefetch(id=120, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=123, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=125, input_ops=[SramPrefetch(id=124, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=128, input_ops=[SramPrefetch(id=127, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=130, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=132, input_ops=[SramPrefetch(id=131, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=135, input_ops=[SramPrefetch(id=134, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=137, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=139, input_ops=[SramPrefetch(id=138, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=142, input_ops=[SramPrefetch(id=141, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=144, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=146, input_ops=[SramPrefetch(id=145, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=149, input_ops=[SramPrefetch(id=148, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=151, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=153, input_ops=[SramPrefetch(id=152, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=156, input_ops=[SramPrefetch(id=155, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=158, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=160, input_ops=[SramPrefetch(id=159, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=163, input_ops=[SramPrefetch(id=162, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=165, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=167, input_ops=[SramPrefetch(id=166, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=170, input_ops=[SramPrefetch(id=169, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=172, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=174, input_ops=[SramPrefetch(id=173, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# VectorOp(id=177, input_ops=[All2AllOp(id=176, input_ops=[MatMulOp(id=174, input_ops=[SramPrefetch(id=173, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)], num_gpus=8, data_size=1048576, weight_bits=16)], vector_op_type='moe_weighted_sum', vector_shape=[128, 4096], weight_bits=16)
# sim cycle: 564588
# sim time ns: 308518
# trace path: trace/qwen3_moe/full_simulation.json
# trace event count: 130
# trace complete event count: 126
# trace complete event categories: {'compute': 73, 'prefetch': 51, 'transfer': 2}
# ========================================================================================================================
# node index: 0
# node info:
# {'node_name': 'hidden_states',
#  'node_op': 'placeholder',
#  'node_target': 'hidden_states'}
# macro op count: 0
# macro op type summary: {}
# macro op details:
# simulation skipped because this node produced no macro ops
# ========================================================================================================================
# node index: 1
# node info:
# {'node_name': 'input_layernorm',
#  'node_op': 'call_module',
#  'node_target': 'input_layernorm'}
# macro op count: 1
# macro op type summary: {'VectorOp': 1}
# macro op details:
# {'id': 1,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'rms_norm',
#  'vector_shape': [128, 4096],
#  'weight_bits': 16}
# VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 4096], weight_bits=16)
# sim cycle: 65
# sim time ns: 35
# trace path: trace/qwen3_moe/node_001_input_layernorm_call_module.json
# trace event count: 5
# trace complete event count: 1
# trace complete event categories: {'compute': 1}
# ========================================================================================================================
# node index: 2
# node info:
# {'node_name': 'self_attn_qkv_proj',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.qkv_proj'}
# macro op count: 3
# macro op type summary: {'SramPrefetch': 1, 'MatMulOp': 1, 'SramPrefetchRelease': 1}
# macro op details:
# {'id': 2, 'input_ops': [], 'num_prefetch_pages': 18432, 'type': 'SramPrefetch'}
# {'dim': (128, 4096, 9216),
#  'id': 3,
#  'input_ops': [{'id': 2, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 4,
#  'input_ops': [{'id': 3, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# MatMulOp(id=3, input_ops=[SramPrefetch(id=2, input_ops=[], num_prefetch_pages=18432)], dim=(128, 4096, 9216), weight_bits=16)
# sim cycle: 59873
# sim time ns: 32717
# trace path: trace/qwen3_moe/node_002_self_attn_qkv_proj_call_module.json
# trace event count: 6
# trace complete event count: 2
# trace complete event categories: {'prefetch': 1, 'compute': 1}
# ========================================================================================================================
# node index: 3
# node info:
# {'node_name': 'self_attn_q_norm',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.q_norm'}
# macro op count: 1
# macro op type summary: {'VectorOp': 1}
# macro op details:
# {'id': 5,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'rms_norm',
#  'vector_shape': [128, 128],
#  'weight_bits': 16}
# VectorOp(id=5, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 128], weight_bits=16)
# sim cycle: 6
# sim time ns: 3
# trace path: trace/qwen3_moe/node_003_self_attn_q_norm_call_module.json
# trace event count: 5
# trace complete event count: 1
# trace complete event categories: {'compute': 1}
# ========================================================================================================================
# node index: 4
# node info:
# {'node_name': 'self_attn_k_norm',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.k_norm'}
# macro op count: 1
# macro op type summary: {'VectorOp': 1}
# macro op details:
# {'id': 6,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'rms_norm',
#  'vector_shape': [128, 128],
#  'weight_bits': 16}
# VectorOp(id=6, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 128], weight_bits=16)
# sim cycle: 6
# sim time ns: 3
# trace path: trace/qwen3_moe/node_004_self_attn_k_norm_call_module.json
# trace event count: 5
# trace complete event count: 1
# trace complete event categories: {'compute': 1}
# ========================================================================================================================
# node index: 5
# node info:
# {'node_name': 'self_attn__dummy_positions',
#  'node_op': 'get_attr',
#  'node_target': 'self_attn._dummy_positions'}
# macro op count: 0
# macro op type summary: {}
# macro op details:
# simulation skipped because this node produced no macro ops
# ========================================================================================================================
# node index: 6
# node info:
# {'node_name': 'self_attn_rotary_emb',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.rotary_emb'}
# macro op count: 0
# macro op type summary: {}
# macro op details:
# simulation skipped because this node produced no macro ops
# ========================================================================================================================
# node index: 7
# node info:
# {'node_name': 'self_attn_attn',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.attn'}
# macro op count: 48
# macro op type summary: {'SramPrefetch': 16, 'FlashAttnOp': 16, 'SramPrefetchRelease': 16}
# macro op details:
# {'id': 7, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 8,
#  'input_ops': [{'id': 7, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (288, 16, 128, 128),
#  'softmax_shape': (4608, 128),
#  'sv_bmm_shape': (288, 16, 128, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 9,
#  'input_ops': [{'id': 8, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 10, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 11,
#  'input_ops': [{'id': 10, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (288, 16, 128, 128),
#  'softmax_shape': (4608, 128),
#  'sv_bmm_shape': (288, 16, 128, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 12,
#  'input_ops': [{'id': 11, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 13, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 14,
#  'input_ops': [{'id': 13, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (288, 16, 128, 128),
#  'softmax_shape': (4608, 128),
#  'sv_bmm_shape': (288, 16, 128, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 15,
#  'input_ops': [{'id': 14, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 16, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 17,
#  'input_ops': [{'id': 16, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (288, 16, 128, 128),
#  'softmax_shape': (4608, 128),
#  'sv_bmm_shape': (288, 16, 128, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 18,
#  'input_ops': [{'id': 17, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 19, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 20,
#  'input_ops': [{'id': 19, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (288, 16, 128, 128),
#  'softmax_shape': (4608, 128),
#  'sv_bmm_shape': (288, 16, 128, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 21,
#  'input_ops': [{'id': 20, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 22, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 23,
#  'input_ops': [{'id': 22, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (288, 16, 128, 128),
#  'softmax_shape': (4608, 128),
#  'sv_bmm_shape': (288, 16, 128, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 24,
#  'input_ops': [{'id': 23, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 25, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 26,
#  'input_ops': [{'id': 25, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (288, 16, 128, 128),
#  'softmax_shape': (4608, 128),
#  'sv_bmm_shape': (288, 16, 128, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 27,
#  'input_ops': [{'id': 26, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 28, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 29,
#  'input_ops': [{'id': 28, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (288, 16, 128, 128),
#  'softmax_shape': (4608, 128),
#  'sv_bmm_shape': (288, 16, 128, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 30,
#  'input_ops': [{'id': 29, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 31, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 32,
#  'input_ops': [{'id': 31, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (288, 16, 128, 128),
#  'softmax_shape': (4608, 128),
#  'sv_bmm_shape': (288, 16, 128, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 33,
#  'input_ops': [{'id': 32, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 34, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 35,
#  'input_ops': [{'id': 34, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (288, 16, 128, 128),
#  'softmax_shape': (4608, 128),
#  'sv_bmm_shape': (288, 16, 128, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 36,
#  'input_ops': [{'id': 35, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 37, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 38,
#  'input_ops': [{'id': 37, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (288, 16, 128, 128),
#  'softmax_shape': (4608, 128),
#  'sv_bmm_shape': (288, 16, 128, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 39,
#  'input_ops': [{'id': 38, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 40, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 41,
#  'input_ops': [{'id': 40, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (288, 16, 128, 128),
#  'softmax_shape': (4608, 128),
#  'sv_bmm_shape': (288, 16, 128, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 42,
#  'input_ops': [{'id': 41, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 43, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 44,
#  'input_ops': [{'id': 43, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (288, 16, 128, 128),
#  'softmax_shape': (4608, 128),
#  'sv_bmm_shape': (288, 16, 128, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 45,
#  'input_ops': [{'id': 44, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 46, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 47,
#  'input_ops': [{'id': 46, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (288, 16, 128, 128),
#  'softmax_shape': (4608, 128),
#  'sv_bmm_shape': (288, 16, 128, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 48,
#  'input_ops': [{'id': 47, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 49, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 50,
#  'input_ops': [{'id': 49, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (288, 16, 128, 128),
#  'softmax_shape': (4608, 128),
#  'sv_bmm_shape': (288, 16, 128, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 51,
#  'input_ops': [{'id': 50, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 52, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 53,
#  'input_ops': [{'id': 52, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (288, 16, 128, 128),
#  'softmax_shape': (4608, 128),
#  'sv_bmm_shape': (288, 16, 128, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 54,
#  'input_ops': [{'id': 53, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# FlashAttnOp(id=8, input_ops=[SramPrefetch(id=7, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=11, input_ops=[SramPrefetch(id=10, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=14, input_ops=[SramPrefetch(id=13, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=17, input_ops=[SramPrefetch(id=16, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=20, input_ops=[SramPrefetch(id=19, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=23, input_ops=[SramPrefetch(id=22, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=26, input_ops=[SramPrefetch(id=25, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=29, input_ops=[SramPrefetch(id=28, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=32, input_ops=[SramPrefetch(id=31, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=35, input_ops=[SramPrefetch(id=34, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=38, input_ops=[SramPrefetch(id=37, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=41, input_ops=[SramPrefetch(id=40, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=44, input_ops=[SramPrefetch(id=43, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=47, input_ops=[SramPrefetch(id=46, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=50, input_ops=[SramPrefetch(id=49, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=53, input_ops=[SramPrefetch(id=52, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# sim cycle: 146843
# sim time ns: 80242
# trace path: trace/qwen3_moe/node_007_self_attn_attn_call_module.json
# trace event count: 36
# trace complete event count: 32
# trace complete event categories: {'prefetch': 16, 'compute': 16}
# ========================================================================================================================
# node index: 8
# node info:
# {'node_name': 'self_attn_o_proj',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.o_proj'}
# macro op count: 3
# macro op type summary: {'SramPrefetch': 1, 'MatMulOp': 1, 'SramPrefetchRelease': 1}
# macro op details:
# {'id': 55, 'input_ops': [], 'num_prefetch_pages': 16384, 'type': 'SramPrefetch'}
# {'dim': (128, 8192, 4096),
#  'id': 56,
#  'input_ops': [{'id': 55, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 57,
#  'input_ops': [{'id': 56, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# MatMulOp(id=56, input_ops=[SramPrefetch(id=55, input_ops=[], num_prefetch_pages=16384)], dim=(128, 8192, 4096), weight_bits=16)
# sim cycle: 53565
# sim time ns: 29270
# trace path: trace/qwen3_moe/node_008_self_attn_o_proj_call_module.json
# trace event count: 6
# trace complete event count: 2
# trace complete event categories: {'prefetch': 1, 'compute': 1}
# ========================================================================================================================
# node index: 9
# node info:
# {'node_name': 'add',
#  'node_op': 'call_function',
#  'node_target': '<built-in function add>'}
# macro op count: 0
# macro op type summary: {}
# macro op details:
# simulation skipped because this node produced no macro ops
# ========================================================================================================================
# node index: 10
# node info:
# {'node_name': 'post_attention_layernorm',
#  'node_op': 'call_module',
#  'node_target': 'post_attention_layernorm'}
# macro op count: 1
# macro op type summary: {'VectorOp': 1}
# macro op details:
# {'id': 58,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'rms_norm',
#  'vector_shape': [128, 4096],
#  'weight_bits': 16}
# VectorOp(id=58, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 4096], weight_bits=16)
# sim cycle: 65
# sim time ns: 35
# trace path: trace/qwen3_moe/node_010_post_attention_layernorm_call_module.json
# trace event count: 5
# trace complete event count: 1
# trace complete event categories: {'compute': 1}
# ========================================================================================================================
# node index: 11
# node info:
# {'node_name': 'mlp', 'node_op': 'call_module', 'node_target': 'mlp'}
# macro op count: 119
# macro op type summary: {'SramPrefetch': 33, 'MatMulOp': 33, 'SramPrefetchRelease': 33, 'VectorOp': 18, 'All2AllOp': 2}
# macro op details:
# {'id': 59, 'input_ops': [], 'num_prefetch_pages': 256, 'type': 'SramPrefetch'}
# {'dim': (128, 4096, 128),
#  'id': 60,
#  'input_ops': [{'id': 59, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 61,
#  'input_ops': [{'id': 60, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 62,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'moe_topk_router',
#  'vector_shape': [128, 128, 8],
#  'weight_bits': 16}
# {'data_size': 1048576,
#  'id': 63,
#  'input_ops': [{'id': 62, 'type': 'VectorOp'}],
#  'num_gpus': 8,
#  'type': 'All2AllOp',
#  'weight_bits': 16}
# {'id': 64, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (8, 4096, 3072),
#  'id': 65,
#  'input_ops': [{'id': 64, 'type': 'SramPrefetch'},
#                {'id': 63, 'type': 'All2AllOp'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 66,
#  'input_ops': [{'id': 65, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 67,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [8, 1536],
#  'weight_bits': 16}
# {'id': 68, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (8, 1536, 4096),
#  'id': 69,
#  'input_ops': [{'id': 68, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 70,
#  'input_ops': [{'id': 69, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 71, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (8, 4096, 3072),
#  'id': 72,
#  'input_ops': [{'id': 71, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 73,
#  'input_ops': [{'id': 72, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 74,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [8, 1536],
#  'weight_bits': 16}
# {'id': 75, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (8, 1536, 4096),
#  'id': 76,
#  'input_ops': [{'id': 75, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 77,
#  'input_ops': [{'id': 76, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 78, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (8, 4096, 3072),
#  'id': 79,
#  'input_ops': [{'id': 78, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 80,
#  'input_ops': [{'id': 79, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 81,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [8, 1536],
#  'weight_bits': 16}
# {'id': 82, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (8, 1536, 4096),
#  'id': 83,
#  'input_ops': [{'id': 82, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 84,
#  'input_ops': [{'id': 83, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 85, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (8, 4096, 3072),
#  'id': 86,
#  'input_ops': [{'id': 85, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 87,
#  'input_ops': [{'id': 86, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 88,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [8, 1536],
#  'weight_bits': 16}
# {'id': 89, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (8, 1536, 4096),
#  'id': 90,
#  'input_ops': [{'id': 89, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 91,
#  'input_ops': [{'id': 90, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 92, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (8, 4096, 3072),
#  'id': 93,
#  'input_ops': [{'id': 92, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 94,
#  'input_ops': [{'id': 93, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 95,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [8, 1536],
#  'weight_bits': 16}
# {'id': 96, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (8, 1536, 4096),
#  'id': 97,
#  'input_ops': [{'id': 96, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 98,
#  'input_ops': [{'id': 97, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 99, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (8, 4096, 3072),
#  'id': 100,
#  'input_ops': [{'id': 99, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 101,
#  'input_ops': [{'id': 100, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 102,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [8, 1536],
#  'weight_bits': 16}
# {'id': 103, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (8, 1536, 4096),
#  'id': 104,
#  'input_ops': [{'id': 103, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 105,
#  'input_ops': [{'id': 104, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 106, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (8, 4096, 3072),
#  'id': 107,
#  'input_ops': [{'id': 106, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 108,
#  'input_ops': [{'id': 107, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 109,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [8, 1536],
#  'weight_bits': 16}
# {'id': 110, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (8, 1536, 4096),
#  'id': 111,
#  'input_ops': [{'id': 110, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 112,
#  'input_ops': [{'id': 111, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 113, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (8, 4096, 3072),
#  'id': 114,
#  'input_ops': [{'id': 113, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 115,
#  'input_ops': [{'id': 114, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 116,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [8, 1536],
#  'weight_bits': 16}
# {'id': 117, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (8, 1536, 4096),
#  'id': 118,
#  'input_ops': [{'id': 117, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 119,
#  'input_ops': [{'id': 118, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 120, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (8, 4096, 3072),
#  'id': 121,
#  'input_ops': [{'id': 120, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 122,
#  'input_ops': [{'id': 121, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 123,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [8, 1536],
#  'weight_bits': 16}
# {'id': 124, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (8, 1536, 4096),
#  'id': 125,
#  'input_ops': [{'id': 124, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 126,
#  'input_ops': [{'id': 125, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 127, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (8, 4096, 3072),
#  'id': 128,
#  'input_ops': [{'id': 127, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 129,
#  'input_ops': [{'id': 128, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 130,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [8, 1536],
#  'weight_bits': 16}
# {'id': 131, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (8, 1536, 4096),
#  'id': 132,
#  'input_ops': [{'id': 131, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 133,
#  'input_ops': [{'id': 132, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 134, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (8, 4096, 3072),
#  'id': 135,
#  'input_ops': [{'id': 134, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 136,
#  'input_ops': [{'id': 135, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 137,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [8, 1536],
#  'weight_bits': 16}
# {'id': 138, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (8, 1536, 4096),
#  'id': 139,
#  'input_ops': [{'id': 138, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 140,
#  'input_ops': [{'id': 139, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 141, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (8, 4096, 3072),
#  'id': 142,
#  'input_ops': [{'id': 141, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 143,
#  'input_ops': [{'id': 142, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 144,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [8, 1536],
#  'weight_bits': 16}
# {'id': 145, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (8, 1536, 4096),
#  'id': 146,
#  'input_ops': [{'id': 145, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 147,
#  'input_ops': [{'id': 146, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 148, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (8, 4096, 3072),
#  'id': 149,
#  'input_ops': [{'id': 148, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 150,
#  'input_ops': [{'id': 149, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 151,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [8, 1536],
#  'weight_bits': 16}
# {'id': 152, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (8, 1536, 4096),
#  'id': 153,
#  'input_ops': [{'id': 152, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 154,
#  'input_ops': [{'id': 153, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 155, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (8, 4096, 3072),
#  'id': 156,
#  'input_ops': [{'id': 155, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 157,
#  'input_ops': [{'id': 156, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 158,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [8, 1536],
#  'weight_bits': 16}
# {'id': 159, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (8, 1536, 4096),
#  'id': 160,
#  'input_ops': [{'id': 159, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 161,
#  'input_ops': [{'id': 160, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 162, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (8, 4096, 3072),
#  'id': 163,
#  'input_ops': [{'id': 162, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 164,
#  'input_ops': [{'id': 163, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 165,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [8, 1536],
#  'weight_bits': 16}
# {'id': 166, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (8, 1536, 4096),
#  'id': 167,
#  'input_ops': [{'id': 166, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 168,
#  'input_ops': [{'id': 167, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 169, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (8, 4096, 3072),
#  'id': 170,
#  'input_ops': [{'id': 169, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 171,
#  'input_ops': [{'id': 170, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 172,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [8, 1536],
#  'weight_bits': 16}
# {'id': 173, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (8, 1536, 4096),
#  'id': 174,
#  'input_ops': [{'id': 173, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 175,
#  'input_ops': [{'id': 174, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'data_size': 1048576,
#  'id': 176,
#  'input_ops': [{'id': 174, 'type': 'MatMulOp'}],
#  'num_gpus': 8,
#  'type': 'All2AllOp',
#  'weight_bits': 16}
# {'id': 177,
#  'input_ops': [{'id': 176, 'type': 'All2AllOp'}],
#  'type': 'VectorOp',
#  'vector_op_type': 'moe_weighted_sum',
#  'vector_shape': [128, 4096],
#  'weight_bits': 16}
# MatMulOp(id=60, input_ops=[SramPrefetch(id=59, input_ops=[], num_prefetch_pages=256)], dim=(128, 4096, 128), weight_bits=16)
# VectorOp(id=62, input_ops=[], vector_op_type='moe_topk_router', vector_shape=[128, 128, 8], weight_bits=16)
# MatMulOp(id=65, input_ops=[SramPrefetch(id=64, input_ops=[], num_prefetch_pages=6144), All2AllOp(id=63, input_ops=[VectorOp(id=62, input_ops=[], vector_op_type='moe_topk_router', vector_shape=[128, 128, 8], weight_bits=16)], num_gpus=8, data_size=1048576, weight_bits=16)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=67, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=69, input_ops=[SramPrefetch(id=68, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=72, input_ops=[SramPrefetch(id=71, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=74, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=76, input_ops=[SramPrefetch(id=75, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=79, input_ops=[SramPrefetch(id=78, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=81, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=83, input_ops=[SramPrefetch(id=82, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=86, input_ops=[SramPrefetch(id=85, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=88, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=90, input_ops=[SramPrefetch(id=89, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=93, input_ops=[SramPrefetch(id=92, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=95, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=97, input_ops=[SramPrefetch(id=96, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=100, input_ops=[SramPrefetch(id=99, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=102, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=104, input_ops=[SramPrefetch(id=103, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=107, input_ops=[SramPrefetch(id=106, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=109, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=111, input_ops=[SramPrefetch(id=110, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=114, input_ops=[SramPrefetch(id=113, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=116, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=118, input_ops=[SramPrefetch(id=117, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=121, input_ops=[SramPrefetch(id=120, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=123, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=125, input_ops=[SramPrefetch(id=124, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=128, input_ops=[SramPrefetch(id=127, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=130, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=132, input_ops=[SramPrefetch(id=131, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=135, input_ops=[SramPrefetch(id=134, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=137, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=139, input_ops=[SramPrefetch(id=138, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=142, input_ops=[SramPrefetch(id=141, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=144, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=146, input_ops=[SramPrefetch(id=145, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=149, input_ops=[SramPrefetch(id=148, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=151, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=153, input_ops=[SramPrefetch(id=152, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=156, input_ops=[SramPrefetch(id=155, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=158, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=160, input_ops=[SramPrefetch(id=159, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=163, input_ops=[SramPrefetch(id=162, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=165, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=167, input_ops=[SramPrefetch(id=166, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# MatMulOp(id=170, input_ops=[SramPrefetch(id=169, input_ops=[], num_prefetch_pages=6144)], dim=(8, 4096, 3072), weight_bits=16)
# VectorOp(id=172, input_ops=[], vector_op_type='silu_mul', vector_shape=[8, 1536], weight_bits=16)
# MatMulOp(id=174, input_ops=[SramPrefetch(id=173, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)
# VectorOp(id=177, input_ops=[All2AllOp(id=176, input_ops=[MatMulOp(id=174, input_ops=[SramPrefetch(id=173, input_ops=[], num_prefetch_pages=3072)], dim=(8, 1536, 4096), weight_bits=16)], num_gpus=8, data_size=1048576, weight_bits=16)], vector_op_type='moe_weighted_sum', vector_shape=[128, 4096], weight_bits=16)
# sim cycle: 344912
# sim time ns: 188476
# trace path: trace/qwen3_moe/node_011_mlp_call_module.json
# trace event count: 90
# trace complete event count: 86
# trace complete event categories: {'prefetch': 33, 'compute': 51, 'transfer': 2}
# ========================================================================================================================
# node index: 12
# node info:
# {'node_name': 'add_1',
#  'node_op': 'call_function',
#  'node_target': '<built-in function add>'}
# macro op count: 0
# macro op type summary: {}
# macro op details:
# simulation skipped because this node produced no macro ops

# %%
node_sim_results
# Out:
# [{'node_name': 'hidden_states',
#   'node_op': 'placeholder',
#   'node_target': 'hidden_states',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []},
#  {'node_name': 'input_layernorm',
#   'node_op': 'call_module',
#   'node_target': 'input_layernorm',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 65,
#   'sim_time_ns': 35,
#   'trace_path': 'trace/qwen3_moe/node_001_input_layernorm_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 1,
#     'input_ops': [],
#     'vector_op_type': 'rms_norm',
#     'vector_shape': [128, 4096],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'self_attn_qkv_proj',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.qkv_proj',
#   'macro_op_count': 3,
#   'macro_op_types': ['SramPrefetch', 'MatMulOp', 'SramPrefetchRelease'],
#   'sim_cycle': 59873,
#   'sim_time_ns': 32717,
#   'trace_path': 'trace/qwen3_moe/node_002_self_attn_qkv_proj_call_module.json',
#   'trace_event_count': 6,
#   'trace_complete_event_count': 2,
#   'trace_complete_event_categories': {'prefetch': 1, 'compute': 1},
#   'macro_ops': [{'id': 2,
#     'input_ops': [],
#     'num_prefetch_pages': 18432,
#     'type': 'SramPrefetch'},
#    {'id': 3,
#     'input_ops': [{'id': 2, 'type': 'SramPrefetch'}],
#     'dim': (128, 4096, 9216),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 4,
#     'input_ops': [{'id': 3, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'}]},
#  {'node_name': 'self_attn_q_norm',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.q_norm',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 6,
#   'sim_time_ns': 3,
#   'trace_path': 'trace/qwen3_moe/node_003_self_attn_q_norm_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 5,
#     'input_ops': [],
#     'vector_op_type': 'rms_norm',
#     'vector_shape': [128, 128],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'self_attn_k_norm',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.k_norm',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 6,
#   'sim_time_ns': 3,
#   'trace_path': 'trace/qwen3_moe/node_004_self_attn_k_norm_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 6,
#     'input_ops': [],
#     'vector_op_type': 'rms_norm',
#     'vector_shape': [128, 128],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'self_attn__dummy_positions',
#   'node_op': 'get_attr',
#   'node_target': 'self_attn._dummy_positions',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []},
#  {'node_name': 'self_attn_rotary_emb',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.rotary_emb',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []},
#  {'node_name': 'self_attn_attn',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.attn',
#   'macro_op_count': 48,
#   'macro_op_types': ['SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease'],
#   'sim_cycle': 146843,
#   'sim_time_ns': 80242,
#   'trace_path': 'trace/qwen3_moe/node_007_self_attn_attn_call_module.json',
#   'trace_event_count': 36,
#   'trace_complete_event_count': 32,
#   'trace_complete_event_categories': {'prefetch': 16, 'compute': 16},
#   'macro_ops': [{'id': 7,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 8,
#     'input_ops': [{'id': 7, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 9,
#     'input_ops': [{'id': 8, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 10,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 11,
#     'input_ops': [{'id': 10, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 12,
#     'input_ops': [{'id': 11, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 13,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 14,
#     'input_ops': [{'id': 13, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 15,
#     'input_ops': [{'id': 14, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 16,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 17,
#     'input_ops': [{'id': 16, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 18,
#     'input_ops': [{'id': 17, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 19,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 20,
#     'input_ops': [{'id': 19, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 21,
#     'input_ops': [{'id': 20, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 22,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 23,
#     'input_ops': [{'id': 22, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 24,
#     'input_ops': [{'id': 23, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 25,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 26,
#     'input_ops': [{'id': 25, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 27,
#     'input_ops': [{'id': 26, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 28,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 29,
#     'input_ops': [{'id': 28, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 30,
#     'input_ops': [{'id': 29, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 31,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 32,
#     'input_ops': [{'id': 31, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 33,
#     'input_ops': [{'id': 32, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 34,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 35,
#     'input_ops': [{'id': 34, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 36,
#     'input_ops': [{'id': 35, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 37,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 38,
#     'input_ops': [{'id': 37, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 39,
#     'input_ops': [{'id': 38, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 40,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 41,
#     'input_ops': [{'id': 40, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 42,
#     'input_ops': [{'id': 41, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 43,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 44,
#     'input_ops': [{'id': 43, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 45,
#     'input_ops': [{'id': 44, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 46,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 47,
#     'input_ops': [{'id': 46, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 48,
#     'input_ops': [{'id': 47, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 49,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 50,
#     'input_ops': [{'id': 49, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 51,
#     'input_ops': [{'id': 50, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 52,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 53,
#     'input_ops': [{'id': 52, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 54,
#     'input_ops': [{'id': 53, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'}]},
#  {'node_name': 'self_attn_o_proj',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.o_proj',
#   'macro_op_count': 3,
#   'macro_op_types': ['SramPrefetch', 'MatMulOp', 'SramPrefetchRelease'],
#   'sim_cycle': 53565,
#   'sim_time_ns': 29270,
#   'trace_path': 'trace/qwen3_moe/node_008_self_attn_o_proj_call_module.json',
#   'trace_event_count': 6,
#   'trace_complete_event_count': 2,
#   'trace_complete_event_categories': {'prefetch': 1, 'compute': 1},
#   'macro_ops': [{'id': 55,
#     'input_ops': [],
#     'num_prefetch_pages': 16384,
#     'type': 'SramPrefetch'},
#    {'id': 56,
#     'input_ops': [{'id': 55, 'type': 'SramPrefetch'}],
#     'dim': (128, 8192, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 57,
#     'input_ops': [{'id': 56, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'}]},
#  {'node_name': 'add',
#   'node_op': 'call_function',
#   'node_target': '<built-in function add>',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []},
#  {'node_name': 'post_attention_layernorm',
#   'node_op': 'call_module',
#   'node_target': 'post_attention_layernorm',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 65,
#   'sim_time_ns': 35,
#   'trace_path': 'trace/qwen3_moe/node_010_post_attention_layernorm_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 58,
#     'input_ops': [],
#     'vector_op_type': 'rms_norm',
#     'vector_shape': [128, 4096],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'mlp',
#   'node_op': 'call_module',
#   'node_target': 'mlp',
#   'macro_op_count': 119,
#   'macro_op_types': ['SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'VectorOp',
#    'All2AllOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'VectorOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'VectorOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'VectorOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'VectorOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'VectorOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'VectorOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'VectorOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'VectorOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'VectorOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'VectorOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'VectorOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'VectorOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'VectorOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'VectorOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'VectorOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'VectorOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'All2AllOp',
#    'VectorOp'],
#   'sim_cycle': 344912,
#   'sim_time_ns': 188476,
#   'trace_path': 'trace/qwen3_moe/node_011_mlp_call_module.json',
#   'trace_event_count': 90,
#   'trace_complete_event_count': 86,
#   'trace_complete_event_categories': {'prefetch': 33,
#    'compute': 51,
#    'transfer': 2},
#   'macro_ops': [{'id': 59,
#     'input_ops': [],
#     'num_prefetch_pages': 256,
#     'type': 'SramPrefetch'},
#    {'id': 60,
#     'input_ops': [{'id': 59, 'type': 'SramPrefetch'}],
#     'dim': (128, 4096, 128),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 61,
#     'input_ops': [{'id': 60, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 62,
#     'input_ops': [],
#     'vector_op_type': 'moe_topk_router',
#     'vector_shape': [128, 128, 8],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 63,
#     'input_ops': [{'id': 62, 'type': 'VectorOp'}],
#     'num_gpus': 8,
#     'data_size': 1048576,
#     'weight_bits': 16,
#     'type': 'All2AllOp'},
#    {'id': 64,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 65,
#     'input_ops': [{'id': 64, 'type': 'SramPrefetch'},
#      {'id': 63, 'type': 'All2AllOp'}],
#     'dim': (8, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 66,
#     'input_ops': [{'id': 65, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 67,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [8, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 68,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 69,
#     'input_ops': [{'id': 68, 'type': 'SramPrefetch'}],
#     'dim': (8, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 70,
#     'input_ops': [{'id': 69, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 71,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 72,
#     'input_ops': [{'id': 71, 'type': 'SramPrefetch'}],
#     'dim': (8, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 73,
#     'input_ops': [{'id': 72, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 74,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [8, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 75,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 76,
#     'input_ops': [{'id': 75, 'type': 'SramPrefetch'}],
#     'dim': (8, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 77,
#     'input_ops': [{'id': 76, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 78,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 79,
#     'input_ops': [{'id': 78, 'type': 'SramPrefetch'}],
#     'dim': (8, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 80,
#     'input_ops': [{'id': 79, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 81,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [8, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 82,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 83,
#     'input_ops': [{'id': 82, 'type': 'SramPrefetch'}],
#     'dim': (8, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 84,
#     'input_ops': [{'id': 83, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 85,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 86,
#     'input_ops': [{'id': 85, 'type': 'SramPrefetch'}],
#     'dim': (8, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 87,
#     'input_ops': [{'id': 86, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 88,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [8, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 89,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 90,
#     'input_ops': [{'id': 89, 'type': 'SramPrefetch'}],
#     'dim': (8, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 91,
#     'input_ops': [{'id': 90, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 92,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 93,
#     'input_ops': [{'id': 92, 'type': 'SramPrefetch'}],
#     'dim': (8, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 94,
#     'input_ops': [{'id': 93, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 95,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [8, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 96,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 97,
#     'input_ops': [{'id': 96, 'type': 'SramPrefetch'}],
#     'dim': (8, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 98,
#     'input_ops': [{'id': 97, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 99,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 100,
#     'input_ops': [{'id': 99, 'type': 'SramPrefetch'}],
#     'dim': (8, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 101,
#     'input_ops': [{'id': 100, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 102,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [8, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 103,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 104,
#     'input_ops': [{'id': 103, 'type': 'SramPrefetch'}],
#     'dim': (8, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 105,
#     'input_ops': [{'id': 104, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 106,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 107,
#     'input_ops': [{'id': 106, 'type': 'SramPrefetch'}],
#     'dim': (8, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 108,
#     'input_ops': [{'id': 107, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 109,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [8, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 110,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 111,
#     'input_ops': [{'id': 110, 'type': 'SramPrefetch'}],
#     'dim': (8, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 112,
#     'input_ops': [{'id': 111, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 113,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 114,
#     'input_ops': [{'id': 113, 'type': 'SramPrefetch'}],
#     'dim': (8, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 115,
#     'input_ops': [{'id': 114, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 116,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [8, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 117,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 118,
#     'input_ops': [{'id': 117, 'type': 'SramPrefetch'}],
#     'dim': (8, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 119,
#     'input_ops': [{'id': 118, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 120,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 121,
#     'input_ops': [{'id': 120, 'type': 'SramPrefetch'}],
#     'dim': (8, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 122,
#     'input_ops': [{'id': 121, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 123,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [8, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 124,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 125,
#     'input_ops': [{'id': 124, 'type': 'SramPrefetch'}],
#     'dim': (8, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 126,
#     'input_ops': [{'id': 125, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 127,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 128,
#     'input_ops': [{'id': 127, 'type': 'SramPrefetch'}],
#     'dim': (8, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 129,
#     'input_ops': [{'id': 128, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 130,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [8, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 131,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 132,
#     'input_ops': [{'id': 131, 'type': 'SramPrefetch'}],
#     'dim': (8, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 133,
#     'input_ops': [{'id': 132, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 134,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 135,
#     'input_ops': [{'id': 134, 'type': 'SramPrefetch'}],
#     'dim': (8, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 136,
#     'input_ops': [{'id': 135, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 137,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [8, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 138,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 139,
#     'input_ops': [{'id': 138, 'type': 'SramPrefetch'}],
#     'dim': (8, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 140,
#     'input_ops': [{'id': 139, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 141,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 142,
#     'input_ops': [{'id': 141, 'type': 'SramPrefetch'}],
#     'dim': (8, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 143,
#     'input_ops': [{'id': 142, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 144,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [8, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 145,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 146,
#     'input_ops': [{'id': 145, 'type': 'SramPrefetch'}],
#     'dim': (8, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 147,
#     'input_ops': [{'id': 146, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 148,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 149,
#     'input_ops': [{'id': 148, 'type': 'SramPrefetch'}],
#     'dim': (8, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 150,
#     'input_ops': [{'id': 149, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 151,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [8, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 152,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 153,
#     'input_ops': [{'id': 152, 'type': 'SramPrefetch'}],
#     'dim': (8, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 154,
#     'input_ops': [{'id': 153, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 155,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 156,
#     'input_ops': [{'id': 155, 'type': 'SramPrefetch'}],
#     'dim': (8, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 157,
#     'input_ops': [{'id': 156, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 158,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [8, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 159,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 160,
#     'input_ops': [{'id': 159, 'type': 'SramPrefetch'}],
#     'dim': (8, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 161,
#     'input_ops': [{'id': 160, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 162,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 163,
#     'input_ops': [{'id': 162, 'type': 'SramPrefetch'}],
#     'dim': (8, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 164,
#     'input_ops': [{'id': 163, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 165,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [8, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 166,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 167,
#     'input_ops': [{'id': 166, 'type': 'SramPrefetch'}],
#     'dim': (8, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 168,
#     'input_ops': [{'id': 167, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 169,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 170,
#     'input_ops': [{'id': 169, 'type': 'SramPrefetch'}],
#     'dim': (8, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 171,
#     'input_ops': [{'id': 170, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 172,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [8, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 173,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 174,
#     'input_ops': [{'id': 173, 'type': 'SramPrefetch'}],
#     'dim': (8, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 175,
#     'input_ops': [{'id': 174, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 176,
#     'input_ops': [{'id': 174, 'type': 'MatMulOp'}],
#     'num_gpus': 8,
#     'data_size': 1048576,
#     'weight_bits': 16,
#     'type': 'All2AllOp'},
#    {'id': 177,
#     'input_ops': [{'id': 176, 'type': 'All2AllOp'}],
#     'vector_op_type': 'moe_weighted_sum',
#     'vector_shape': [128, 4096],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'add_1',
#   'node_op': 'call_function',
#   'node_target': '<built-in function add>',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []}]

# %%
non_empty_node_results = [result for result in node_sim_results if result["macro_op_count"] > 0]
empty_node_results = [result for result in node_sim_results if result["macro_op_count"] == 0]

assert len(node_sim_results) == len(all_graph_nodes)
assert full_sim_result["cycle"] > 0
assert full_sim_result["time_ns"] > 0
assert full_sim_result["trace_path"] is not None
assert full_sim_result["trace_event_count"] is not None
assert full_sim_result["trace_complete_event_count"] is not None
assert non_empty_node_results
assert all(result["sim_cycle"] is not None for result in non_empty_node_results)
assert all(result["sim_time_ns"] is not None for result in non_empty_node_results)
assert all(result["trace_path"] is not None for result in non_empty_node_results)
assert all(result["trace_event_count"] is not None for result in non_empty_node_results)
assert all(result["trace_complete_event_count"] is not None for result in non_empty_node_results)
assert all(result["sim_cycle"] is None for result in empty_node_results)
assert all(result["trace_path"] is None for result in empty_node_results)

full_sim_summary = {
    "macro_op_count": len(macro_op_list),
    "macro_op_type_summary": dict(macro_summary(macro_op_list)),
    "sim_cycle": full_sim_result["cycle"],
    "sim_time_ns": full_sim_result["time_ns"],
    "trace_path": full_sim_result["trace_path"],
    "trace_event_count": full_sim_result["trace_event_count"],
    "trace_complete_event_count": full_sim_result["trace_complete_event_count"],
    "trace_complete_event_categories": full_sim_result[
        "trace_complete_event_categories"
    ],
}

summary_rows = [
    {
        "node_name": result["node_name"],
        "node_op": result["node_op"],
        "node_target": result["node_target"],
        "macro_op_count": result["macro_op_count"],
        "macro_op_types": result["macro_op_types"],
        "sim_cycle": result["sim_cycle"],
        "sim_time_ns": result["sim_time_ns"],
        "trace_path": result["trace_path"],
        "trace_event_count": result["trace_event_count"],
        "trace_complete_event_count": result["trace_complete_event_count"],
        "trace_complete_event_categories": result["trace_complete_event_categories"],
    }
    for result in node_sim_results
]

{
    "full_simulation": full_sim_summary,
    "node_simulations": summary_rows,
}
# Out:
# {'full_simulation': {'macro_op_count': 177,
#   'macro_op_type_summary': {'VectorOp': 22,
#    'SramPrefetch': 51,
#    'MatMulOp': 35,
#    'SramPrefetchRelease': 51,
#    'FlashAttnOp': 16,
#    'All2AllOp': 2},
#   'sim_cycle': 564588,
#   'sim_time_ns': 308518,
#   'trace_path': 'trace/qwen3_moe/full_simulation.json',
#   'trace_event_count': 130,
#   'trace_complete_event_count': 126,
#   'trace_complete_event_categories': {'compute': 73,
#    'prefetch': 51,
#    'transfer': 2}},
#  'node_simulations': [{'node_name': 'hidden_states',
#    'node_op': 'placeholder',
#    'node_target': 'hidden_states',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None},
#   {'node_name': 'input_layernorm',
#    'node_op': 'call_module',
#    'node_target': 'input_layernorm',
#    'macro_op_count': 1,
#    'macro_op_types': ['VectorOp'],
#    'sim_cycle': 65,
#    'sim_time_ns': 35,
#    'trace_path': 'trace/qwen3_moe/node_001_input_layernorm_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'self_attn_qkv_proj',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.qkv_proj',
#    'macro_op_count': 3,
#    'macro_op_types': ['SramPrefetch', 'MatMulOp', 'SramPrefetchRelease'],
#    'sim_cycle': 59873,
#    'sim_time_ns': 32717,
#    'trace_path': 'trace/qwen3_moe/node_002_self_attn_qkv_proj_call_module.json',
#    'trace_event_count': 6,
#    'trace_complete_event_count': 2,
#    'trace_complete_event_categories': {'prefetch': 1, 'compute': 1}},
#   {'node_name': 'self_attn_q_norm',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.q_norm',
#    'macro_op_count': 1,
#    'macro_op_types': ['VectorOp'],
#    'sim_cycle': 6,
#    'sim_time_ns': 3,
#    'trace_path': 'trace/qwen3_moe/node_003_self_attn_q_norm_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'self_attn_k_norm',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.k_norm',
#    'macro_op_count': 1,
#    'macro_op_types': ['VectorOp'],
#    'sim_cycle': 6,
#    'sim_time_ns': 3,
#    'trace_path': 'trace/qwen3_moe/node_004_self_attn_k_norm_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'self_attn__dummy_positions',
#    'node_op': 'get_attr',
#    'node_target': 'self_attn._dummy_positions',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None},
#   {'node_name': 'self_attn_rotary_emb',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.rotary_emb',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None},
#   {'node_name': 'self_attn_attn',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.attn',
#    'macro_op_count': 48,
#    'macro_op_types': ['SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease'],
#    'sim_cycle': 146843,
#    'sim_time_ns': 80242,
#    'trace_path': 'trace/qwen3_moe/node_007_self_attn_attn_call_module.json',
#    'trace_event_count': 36,
#    'trace_complete_event_count': 32,
#    'trace_complete_event_categories': {'prefetch': 16, 'compute': 16}},
#   {'node_name': 'self_attn_o_proj',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.o_proj',
#    'macro_op_count': 3,
#    'macro_op_types': ['SramPrefetch', 'MatMulOp', 'SramPrefetchRelease'],
#    'sim_cycle': 53565,
#    'sim_time_ns': 29270,
#    'trace_path': 'trace/qwen3_moe/node_008_self_attn_o_proj_call_module.json',
#    'trace_event_count': 6,
#    'trace_complete_event_count': 2,
#    'trace_complete_event_categories': {'prefetch': 1, 'compute': 1}},
#   {'node_name': 'add',
#    'node_op': 'call_function',
#    'node_target': '<built-in function add>',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None},
#   {'node_name': 'post_attention_layernorm',
#    'node_op': 'call_module',
#    'node_target': 'post_attention_layernorm',
#    'macro_op_count': 1,
#    'macro_op_types': ['VectorOp'],
#    'sim_cycle': 65,
#    'sim_time_ns': 35,
#    'trace_path': 'trace/qwen3_moe/node_010_post_attention_layernorm_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'mlp',
#    'node_op': 'call_module',
#    'node_target': 'mlp',
#    'macro_op_count': 119,
#    'macro_op_types': ['SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'All2AllOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'All2AllOp',
#     'VectorOp'],
#    'sim_cycle': 344912,
#    'sim_time_ns': 188476,
#    'trace_path': 'trace/qwen3_moe/node_011_mlp_call_module.json',
#    'trace_event_count': 90,
#    'trace_complete_event_count': 86,
#    'trace_complete_event_categories': {'prefetch': 33,
#     'compute': 51,
#     'transfer': 2}},
#   {'node_name': 'add_1',
#    'node_op': 'call_function',
#    'node_target': '<built-in function add>',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None}]}

# %%
print(kv_cache_state)
# Out:
# KVCacheState(total_kv_cache_size_per_layer=2415919104, kv_block_size_tokens=128, num_kv_blocks=9216, num_nand_pages_per_layer=589824, num_hyper_pages_per_layer=128)
