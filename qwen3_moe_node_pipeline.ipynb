# %% [markdown]
# # Node-Level Frontend Pipeline For Qwen3 MoE
#
# 实现 Qwen3 MoE decoder layer 的最小前端全流程，并在 code gen pass 之后按 node 读取 `marco_op_list`，对每个 node 单独运行硬件仿真，同时对完整 `macro_op_list` 运行一次整体硬件仿真，并把 perf trace 输出到 `trace/qwen3_moe/` 目录。

# %% [markdown]
# ## 流程
# - 加载 `qwen3-moe-235B` model card 并初始化 `Qwen3MoEModelConfig`
# - 初始化 `NandConfig`、`MoEParallelConfig` 和 `InferenceConfig`
# - 初始化 `Qwen3MoEDecoderLayer`
# - 使用 `NxTracer` trace 得到计算图
# - 运行 `NormalizePass` 获得简化图
# - 用 `build_kv_cache_state` 构造 `KVCacheState`
# - 构造 `NxGraphMeta` 并写入 `graph.meta`
# - 运行 `CodeGenPass`，收集全局和 node 级别的 `marco_op_list`
# - 对完整 `macro_op_list` 运行一次硬件仿真，并把完整 trace 保存到 `trace/qwen3_moe/full_simulation.json`
# - 对每个 node 单独运行硬件仿真，并把 node trace 保存到 `trace/qwen3_moe/` 目录
# - 汇总完整仿真和 node 级别的 macro op、时延和 trace 信息

# %%
import json
import logging
import re
from collections import Counter
from dataclasses import fields, is_dataclass
from math import ceil
from pathlib import Path
from pprint import pprint

import torch
from Desim import SimSession
from torch.fx import GraphModule

from nandmachine.commands.macro import All2AllOp, FlashAttnOp, MacroOp, MatMulOp, VectorOp
from nandmachine.config.config import NandConfig
from nandmachine.config.hardware_config import get_device_or_raise
from nandmachine.config.inference_config import InferenceConfig, MoEParallelConfig
from nandmachine.config.model_config import Qwen3MoEModelConfig
from nandmachine.frontend.core.graph.base import NxGraphMeta, NxTracer
from nandmachine.frontend.core.passes.cod_gen import CodeGenPass
from nandmachine.frontend.core.passes.normalize import NormalizePass
from nandmachine.frontend.network.qwen3_moe import Qwen3MoEDecoderLayer
from nandmachine.frontend.utlis import build_kv_cache_state
from nandmachine.simulator.hardware.xpu import xPU

MODEL_CARD_PATH = Path("model_cards/qwen3-moe-235B.json")
DEVICE_NAME = "H200_SXM"
COMPILE_MODE = "heuristic-GPU"
NUM_RANKS = 8
ATTN_DP_SIZE = 8
ATTN_TP_SIZE = 1
FFN_TP_SIZE = 1
FFN_EP_SIZE = 8
HBM_BANDWIDTH_GBPS = 3350
TRACE_DIR = Path("trace/qwen3_moe")
FULL_TRACE_FILE_NAME = "full_simulation.json"

assert MODEL_CARD_PATH.exists(), MODEL_CARD_PATH
assert NUM_RANKS > 0, NUM_RANKS
assert ATTN_DP_SIZE > 0, ATTN_DP_SIZE
assert ATTN_TP_SIZE > 0, ATTN_TP_SIZE
assert FFN_TP_SIZE > 0, FFN_TP_SIZE
assert FFN_EP_SIZE > 0, FFN_EP_SIZE


def node_summary(graph_module: GraphModule) -> list[tuple[str, str, str]]:
    return [(node.name, node.op, str(node.target)) for node in graph_module.graph.nodes]


def macro_summary(macro_op_list: list[object]) -> Counter:
    return Counter(type(op).__name__ for op in macro_op_list)


def node_info(node: torch.fx.Node) -> dict[str, object]:
    return {
        "node_name": node.name,
        "node_op": node.op,
        "node_target": str(node.target),
    }


def _serialize_value(value: object) -> object:
    if isinstance(value, MacroOp):
        return {
            "id": value.id,
            "type": type(value).__name__,
        }
    if isinstance(value, list):
        return [_serialize_value(item) for item in value]
    if isinstance(value, tuple):
        return tuple(_serialize_value(item) for item in value)
    return value


def macro_info(op: MacroOp) -> dict[str, object]:
    assert is_dataclass(op), type(op)
    payload = {field.name: _serialize_value(getattr(op, field.name)) for field in fields(op)}
    payload["type"] = type(op).__name__
    return payload


def _sanitize_trace_name(raw_name: str) -> str:
    return re.sub(r"[^0-9A-Za-z._-]+", "_", raw_name).strip("._")


def trace_file_path(node_index: int, node: torch.fx.Node) -> Path:
    file_name = _sanitize_trace_name(f"node_{node_index:03d}_{node.name}_{node.op}")
    return TRACE_DIR / f"{file_name}.json"


def full_trace_file_path() -> Path:
    return TRACE_DIR / FULL_TRACE_FILE_NAME


def run_macro_ops_with_trace(
    nand_config: NandConfig,
    commands: list[MacroOp],
    *,
    trace_path: Path,
    device_name: str,
    compile_mode: str,
    hbm_bandwidth_GBps: float,
) -> dict[str, object]:
    SimSession.reset()
    SimSession.init()

    hbm_bandwidth_bytes_per_sec = hbm_bandwidth_GBps * 10**9

    sim_xpu = xPU(
        nand_config,
        hbm_bandwidth_bytes_per_sec=hbm_bandwidth_bytes_per_sec,
        device_name=device_name,
        compile_mode=compile_mode,
        enable_trace=True,
    )
    sim_xpu.load_command(commands)
    SimSession.scheduler.run()

    final_time_ns = int(SimSession.sim_time.cycle)
    device = get_device_or_raise(device_name)
    final_cycle = ceil(final_time_ns * device.compute_module.clock_freq / 1e9)

    trace_path.parent.mkdir(parents=True, exist_ok=True)
    saved_trace_path = Path(sim_xpu.save_trace_file(str(trace_path)))

    tracer = sim_xpu.tracer
    assert tracer is not None
    complete_events = [event for event in tracer._events if event["ph"] == "X"]

    return {
        "cycle": final_cycle,
        "time_ns": final_time_ns,
        "trace_path": str(saved_trace_path),
        "trace_event_count": len(tracer._events),
        "trace_complete_event_count": len(complete_events),
        "trace_complete_event_categories": dict(
            Counter(event["cat"] for event in complete_events)
        ),
    }

# %%
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
)

model_card = json.loads(MODEL_CARD_PATH.read_text())
model_card.setdefault("attention_type", "gqa")
raw_model_config = type("Qwen3MoeConfig", (), model_card)()
model_config = Qwen3MoEModelConfig.from_config(raw_model_config)
nand_config = NandConfig(
    num_channels=6 * 8,
    num_plane=96,
    num_block=16, # 没什么用的参数
    num_pages=16, # 没什么用的参数
    tRead=4000, # ns
    tWrite=4000 * 10, # ns
    tErase=4000 * 100, # ns
    page_size=4, # KB
    sram_threshold=1024 * 80,  # KB  --  可以考虑之后统一改成 Bytes，统一所有的单位
)
parallel_config = MoEParallelConfig(
    num_ranks=NUM_RANKS,
    attn_dp_size=ATTN_DP_SIZE,
    attn_tp_size=ATTN_TP_SIZE,
    ffn_tp_size=FFN_TP_SIZE,
    ffn_ep_size=FFN_EP_SIZE,
)
inference_config = InferenceConfig(
    batch_size=1024,
    input_sequence_length=8*1024,
    output_sequence_length=1*1024,
    weight_bits=16,
    activation_bits=16,
    kv_cache_bits=16,
    kv_block_size_bytes=1024 * 256,
    memory_backend="nand",
    parallel_config=parallel_config,
)
kv_cache_state = build_kv_cache_state(nand_config, model_config, inference_config)
graph_meta = NxGraphMeta(
    nand_config=nand_config,
    model_config=model_config,
    inference_config=inference_config,
    kv_cache_state=kv_cache_state,
)
simulator_config = {
    "device_name": DEVICE_NAME,
    "compile_mode": COMPILE_MODE,
    "hbm_bandwidth_GBps": HBM_BANDWIDTH_GBPS,
}
runtime_simulator_config = {
    "device_name": simulator_config["device_name"],
    "compile_mode": simulator_config["compile_mode"],
    "hbm_bandwidth_GBps": simulator_config["hbm_bandwidth_GBps"],
}
TRACE_DIR.mkdir(parents=True, exist_ok=True)

print("HBM bandwidth (GBps):", HBM_BANDWIDTH_GBPS)
print("trace output dir:", TRACE_DIR)
print("full simulation trace path:", full_trace_file_path())
print("parallel config:", parallel_config)
print("simulator config:", simulator_config)
# Out:
# HBM bandwidth (GBps): 3350
# trace output dir: trace/qwen3_moe
# full simulation trace path: trace/qwen3_moe/full_simulation.json
# parallel config: MoEParallelConfig(num_ranks=8, attn_dp_size=8, attn_tp_size=1, ffn_tp_size=1, ffn_ep_size=8)
# simulator config: {'device_name': 'H200_SXM', 'compile_mode': 'heuristic-GPU', 'hbm_bandwidth_GBps': 3350}

# %%
with torch.device("meta"):
    model = Qwen3MoEDecoderLayer(raw_model_config, parallel_config)
    graph = NxTracer().trace(model)
    graph_module = GraphModule(model, graph)

NormalizePass().transform(graph_module)
graph_module.graph.meta = {CodeGenPass.GRAPH_META_KEY: graph_meta}
CodeGenPass().transform(graph_module)

all_graph_nodes = list(graph_module.graph.nodes)
all_node_infos = [node_info(node) for node in all_graph_nodes]
node_count_with_macro_ops = sum(1 for node in all_graph_nodes if "marco_op_list" in node.meta)
macro_op_list = graph_module.graph.meta[CodeGenPass.MACRO_OP_LIST_META_KEY]
vector_ops = [op for op in macro_op_list if isinstance(op, VectorOp)]
all_to_all_ops = [op for op in macro_op_list if isinstance(op, All2AllOp)]

print("normalized node count:", len(node_summary(graph_module)))
print("node count with macro op entries:", node_count_with_macro_ops)
print("global macro op count:", len(macro_op_list))
print("global macro op type summary:", dict(macro_summary(macro_op_list)))
print("vector op type summary:", dict(Counter(op.vector_op_type for op in vector_ops)))
print("all_to_all count:", len(all_to_all_ops))
print("all node infos:")
for current_node_info in all_node_infos:
    pprint(current_node_info)
# Out:
# 2026-04-06 16:24:32,845 - INFO - Processed node=input_layernorm generated_macro_ops=1
# 2026-04-06 16:24:32,847 - INFO - Processed node=self_attn_qkv_proj generated_macro_ops=1
# 2026-04-06 16:24:32,847 - INFO - Processed node=self_attn_q_norm generated_macro_ops=1
# 2026-04-06 16:24:32,847 - INFO - Processed node=self_attn_k_norm generated_macro_ops=1
# 2026-04-06 16:24:32,847 - INFO - Processed node=self_attn_rotary_emb generated_macro_ops=0
# 2026-04-06 16:24:32,847 - INFO - Processed node=self_attn_attn generated_macro_ops=1
# 2026-04-06 16:24:32,848 - INFO - Processed node=self_attn_o_proj generated_macro_ops=1
# 2026-04-06 16:24:32,848 - INFO - Processed node=post_attention_layernorm generated_macro_ops=1
# 2026-04-06 16:24:32,848 - INFO - Processed node=mlp generated_macro_ops=53
# normalized node count: 13
# node count with macro op entries: 9
# global macro op count: 60
# global macro op type summary: {'VectorOp': 22, 'MatMulOp': 35, 'FlashAttnOp': 1, 'All2AllOp': 2}
# vector op type summary: {'rms_norm': 4, 'moe_topk_router': 1, 'silu_mul': 16, 'moe_weighted_sum': 1}
# all_to_all count: 2
# all node infos:
# {'node_name': 'hidden_states',
#  'node_op': 'placeholder',
#  'node_target': 'hidden_states'}
# {'node_name': 'input_layernorm',
#  'node_op': 'call_module',
#  'node_target': 'input_layernorm'}
# {'node_name': 'self_attn_qkv_proj',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.qkv_proj'}
# {'node_name': 'self_attn_q_norm',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.q_norm'}
# {'node_name': 'self_attn_k_norm',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.k_norm'}
# {'node_name': 'self_attn__dummy_positions',
#  'node_op': 'get_attr',
#  'node_target': 'self_attn._dummy_positions'}
# {'node_name': 'self_attn_rotary_emb',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.rotary_emb'}
# {'node_name': 'self_attn_attn',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.attn'}
# {'node_name': 'self_attn_o_proj',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.o_proj'}
# {'node_name': 'add',
#  'node_op': 'call_function',
#  'node_target': '<built-in function add>'}
# {'node_name': 'post_attention_layernorm',
#  'node_op': 'call_module',
#  'node_target': 'post_attention_layernorm'}
# {'node_name': 'mlp', 'node_op': 'call_module', 'node_target': 'mlp'}
# {'node_name': 'add_1',
#  'node_op': 'call_function',
#  'node_target': '<built-in function add>'}

# %%
assert macro_op_list
assert all_graph_nodes
assert any(isinstance(op, MatMulOp) for op in macro_op_list)
assert any(isinstance(op, FlashAttnOp) for op in macro_op_list)
assert any(isinstance(op, All2AllOp) for op in macro_op_list)
assert any(op.vector_op_type == "moe_topk_router" for op in vector_ops)
assert any(op.vector_op_type == "moe_weighted_sum" for op in vector_ops)
assert any(op.vector_op_type == "silu_mul" for op in vector_ops)
assert any(op.vector_op_type == "rms_norm" for op in vector_ops)
assert all(all(dim > 0 for dim in op.vector_shape) for op in vector_ops)

print("qwen3 moe node-level frontend pipeline completed successfully")
# Out:
# qwen3 moe node-level frontend pipeline completed successfully

# %%
print("=" * 120)
print("full simulation")
print("macro op count:", len(macro_op_list))
print("macro op type summary:", dict(macro_summary(macro_op_list)))

full_trace_path = full_trace_file_path()
full_sim_result = run_macro_ops_with_trace(
    nand_config,
    macro_op_list,
    trace_path=full_trace_path,
    **runtime_simulator_config,
)
assert full_sim_result["cycle"] > 0
assert full_sim_result["time_ns"] > 0
print("sim cycle:", full_sim_result["cycle"])
print("sim time ns:", full_sim_result["time_ns"])
print("trace path:", full_sim_result["trace_path"])
print("trace event count:", full_sim_result["trace_event_count"])
print("trace complete event count:", full_sim_result["trace_complete_event_count"])
print(
    "trace complete event categories:",
    full_sim_result["trace_complete_event_categories"],
)

node_sim_results = []

for node_index, node in enumerate(all_graph_nodes):
    node_macro_ops = node.meta.get("marco_op_list", [])
    current_node_info = node_info(node)
    current_macro_summary = dict(macro_summary(node_macro_ops))

    print("=" * 120)
    print("node index:", node_index)
    print("node info:")
    pprint(current_node_info)
    print("macro op count:", len(node_macro_ops))
    print("macro op type summary:", current_macro_summary)

    serialized_macro_ops = [macro_info(op) for op in node_macro_ops]
    print("macro op details:")
    for macro_op_payload in serialized_macro_ops:
        pprint(macro_op_payload)

    if not node_macro_ops:
        print("simulation skipped because this node produced no macro ops")
        node_sim_results.append(
            {
                **current_node_info,
                "macro_op_count": 0,
                "macro_op_types": [],
                "sim_cycle": None,
                "sim_time_ns": None,
                "trace_path": None,
                "trace_event_count": None,
                "trace_complete_event_count": None,
                "trace_complete_event_categories": None,
                "macro_ops": serialized_macro_ops,
            }
        )
        continue

    current_trace_path = trace_file_path(node_index, node)
    sim_result = run_macro_ops_with_trace(
        nand_config,
        node_macro_ops,
        trace_path=current_trace_path,
        **runtime_simulator_config,
    )
    assert sim_result["cycle"] > 0
    assert sim_result["time_ns"] > 0
    print("sim cycle:", sim_result["cycle"])
    print("sim time ns:", sim_result["time_ns"])
    print("trace path:", sim_result["trace_path"])
    print("trace event count:", sim_result["trace_event_count"])
    print("trace complete event count:", sim_result["trace_complete_event_count"])
    print(
        "trace complete event categories:",
        sim_result["trace_complete_event_categories"],
    )

    node_sim_results.append(
        {
            **current_node_info,
            "macro_op_count": len(node_macro_ops),
            "macro_op_types": [type(op).__name__ for op in node_macro_ops],
            "sim_cycle": sim_result["cycle"],
            "sim_time_ns": sim_result["time_ns"],
            "trace_path": sim_result["trace_path"],
            "trace_event_count": sim_result["trace_event_count"],
            "trace_complete_event_count": sim_result["trace_complete_event_count"],
            "trace_complete_event_categories": sim_result[
                "trace_complete_event_categories"
            ],
            "macro_ops": serialized_macro_ops,
        }
    )
# Out:
# ========================================================================================================================
# full simulation
# macro op count: 60
# macro op type summary: {'VectorOp': 22, 'MatMulOp': 35, 'FlashAttnOp': 1, 'All2AllOp': 2}
# VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[1024, 4096], weight_bits=16)
# MatMulOp(id=2, input_ops=[VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[1024, 4096], weight_bits=16)], dim=(1024, 4096, 9216), weight_bits=16)
# VectorOp(id=3, input_ops=[MatMulOp(id=2, input_ops=[VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[1024, 4096], weight_bits=16)], dim=(1024, 4096, 9216), weight_bits=16)], vector_op_type='rms_norm', vector_shape=[1024, 128], weight_bits=16)
# VectorOp(id=4, input_ops=[VectorOp(id=3, input_ops=[MatMulOp(id=2, input_ops=[VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[1024, 4096], weight_bits=16)], dim=(1024, 4096, 9216), weight_bits=16)], vector_op_type='rms_norm', vector_shape=[1024, 128], weight_bits=16)], vector_op_type='rms_norm', vector_shape=[1024, 128], weight_bits=16)
# FlashAttnOp(id=5, input_ops=[VectorOp(id=4, input_ops=[VectorOp(id=3, input_ops=[MatMulOp(id=2, input_ops=[VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[1024, 4096], weight_bits=16)], dim=(1024, 4096, 9216), weight_bits=16)], vector_op_type='rms_norm', vector_shape=[1024, 128], weight_bits=16)], vector_op_type='rms_norm', vector_shape=[1024, 128], weight_bits=16)], qk_bmm_shape=(36864, 16, 128, 128), sv_bmm_shape=(36864, 16, 128, 128), softmax_shape=(589824, 128), weight_bits=16)
# MatMulOp(id=6, input_ops=[FlashAttnOp(id=5, input_ops=[VectorOp(id=4, input_ops=[VectorOp(id=3, input_ops=[MatMulOp(id=2, input_ops=[VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[1024, 4096], weight_bits=16)], dim=(1024, 4096, 9216), weight_bits=16)], vector_op_type='rms_norm', vector_shape=[1024, 128], weight_bits=16)], vector_op_type='rms_norm', vector_shape=[1024, 128], weight_bits=16)], qk_bmm_shape=(36864, 16, 128, 128), sv_bmm_shape=(36864, 16, 128, 128), softmax_shape=(589824, 128), weight_bits=16)], dim=(1024, 8192, 4096), weight_bits=16)
# VectorOp(id=7, input_ops=[MatMulOp(id=6, input_ops=[FlashAttnOp(id=5, input_ops=[VectorOp(id=4, input_ops=[VectorOp(id=3, input_ops=[MatMulOp(id=2, input_ops=[VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[1024, 4096], weight_bits=16)], dim=(1024, 4096, 9216), weight_bits=16)], vector_op_type='rms_norm', vector_shape=[1024, 128], weight_bits=16)], vector_op_type='rms_norm', vector_shape=[1024, 128], weight_bits=16)], qk_bmm_shape=(36864, 16, 128, 128), sv_bmm_shape=(36864, 16, 128, 128), softmax_shape=(589824, 128), weight_bits=16)], dim=(1024, 8192, 4096), weight_bits=16)], vector_op_type='rms_norm', vector_shape=[1024, 4096], weight_bits=16)
# MatMulOp(id=8, input_ops=[VectorOp(id=7, input_ops=[MatMulOp(id=6, input_ops=[FlashAttnOp(id=5, input_ops=[VectorOp(id=4, input_ops=[VectorOp(id=3, input_ops=[MatMulOp(id=2, input_ops=[VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[1024, 4096], weight_bits=16)], dim=(1024, 4096, 9216), weight_bits=16)], vector_op_type='rms_norm', vector_shape=[1024, 128], weight_bits=16)], vector_op_type='rms_norm', vector_shape=[1024, 128], weight_bits=16)], qk_bmm_shape=(36864, 16, 128, 128), sv_bmm_shape=(36864, 16, 128, 128), softmax_shape=(589824, 128), weight_bits=16)], dim=(1024, 8192, 4096), weight_bits=16)], vector_op_type='rms_norm', vector_shape=[1024, 4096], weight_bits=16)], dim=(1024, 4096, 128), weight_bits=16)
# VectorOp(id=9, input_ops=[], vector_op_type='moe_topk_router', vector_shape=[1024, 128, 8], weight_bits=16)
# MatMulOp(id=11, input_ops=[All2AllOp(id=10, input_ops=[VectorOp(id=9, input_ops=[], vector_op_type='moe_topk_router', vector_shape=[1024, 128, 8], weight_bits=16)], num_gpus=8, data_size=8388608, weight_bits=16)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=12, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=13, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=14, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=15, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=16, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=17, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=18, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=19, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=20, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=21, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=22, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=23, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=24, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=25, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=26, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=27, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=28, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=29, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=30, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=31, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=32, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=33, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=34, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=35, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=36, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=37, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=38, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=39, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=40, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=41, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=42, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=43, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=44, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=45, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=46, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=47, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=48, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=49, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=50, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=51, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=52, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=53, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=54, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=55, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=56, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=57, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=58, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# VectorOp(id=60, input_ops=[All2AllOp(id=59, input_ops=[MatMulOp(id=58, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)], num_gpus=8, data_size=8388608, weight_bits=16)], vector_op_type='moe_weighted_sum', vector_shape=[1024, 4096], weight_bits=16)
# sim cycle: 2210450
# sim time ns: 1207896
# trace path: trace/qwen3_moe/full_simulation.json
# trace event count: 64
# trace complete event count: 60
# trace complete event categories: {'compute': 58, 'transfer': 2}
# ========================================================================================================================
# node index: 0
# node info:
# {'node_name': 'hidden_states',
#  'node_op': 'placeholder',
#  'node_target': 'hidden_states'}
# macro op count: 0
# macro op type summary: {}
# macro op details:
# simulation skipped because this node produced no macro ops
# ========================================================================================================================
# node index: 1
# node info:
# {'node_name': 'input_layernorm',
#  'node_op': 'call_module',
#  'node_target': 'input_layernorm'}
# macro op count: 1
# macro op type summary: {'VectorOp': 1}
# macro op details:
# {'id': 1,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'rms_norm',
#  'vector_shape': [1024, 4096],
#  'weight_bits': 16}
# VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[1024, 4096], weight_bits=16)
# sim cycle: 500
# sim time ns: 273
# trace path: trace/qwen3_moe/node_001_input_layernorm_call_module.json
# trace event count: 5
# trace complete event count: 1
# trace complete event categories: {'compute': 1}
# ========================================================================================================================
# node index: 2
# node info:
# {'node_name': 'self_attn_qkv_proj',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.qkv_proj'}
# macro op count: 1
# macro op type summary: {'MatMulOp': 1}
# macro op details:
# {'dim': (1024, 4096, 9216),
#  'id': 2,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# MatMulOp(id=2, input_ops=[], dim=(1024, 4096, 9216), weight_bits=16)
# sim cycle: 166428
# sim time ns: 90944
# trace path: trace/qwen3_moe/node_002_self_attn_qkv_proj_call_module.json
# trace event count: 5
# trace complete event count: 1
# trace complete event categories: {'compute': 1}
# ========================================================================================================================
# node index: 3
# node info:
# {'node_name': 'self_attn_q_norm',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.q_norm'}
# macro op count: 1
# macro op type summary: {'VectorOp': 1}
# macro op details:
# {'id': 3,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'rms_norm',
#  'vector_shape': [1024, 128],
#  'weight_bits': 16}
# VectorOp(id=3, input_ops=[], vector_op_type='rms_norm', vector_shape=[1024, 128], weight_bits=16)
# sim cycle: 19
# sim time ns: 10
# trace path: trace/qwen3_moe/node_003_self_attn_q_norm_call_module.json
# trace event count: 5
# trace complete event count: 1
# trace complete event categories: {'compute': 1}
# ========================================================================================================================
# node index: 4
# node info:
# {'node_name': 'self_attn_k_norm',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.k_norm'}
# macro op count: 1
# macro op type summary: {'VectorOp': 1}
# macro op details:
# {'id': 4,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'rms_norm',
#  'vector_shape': [1024, 128],
#  'weight_bits': 16}
# VectorOp(id=4, input_ops=[], vector_op_type='rms_norm', vector_shape=[1024, 128], weight_bits=16)
# sim cycle: 19
# sim time ns: 10
# trace path: trace/qwen3_moe/node_004_self_attn_k_norm_call_module.json
# trace event count: 5
# trace complete event count: 1
# trace complete event categories: {'compute': 1}
# ========================================================================================================================
# node index: 5
# node info:
# {'node_name': 'self_attn__dummy_positions',
#  'node_op': 'get_attr',
#  'node_target': 'self_attn._dummy_positions'}
# macro op count: 0
# macro op type summary: {}
# macro op details:
# simulation skipped because this node produced no macro ops
# ========================================================================================================================
# node index: 6
# node info:
# {'node_name': 'self_attn_rotary_emb',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.rotary_emb'}
# macro op count: 0
# macro op type summary: {}
# macro op details:
# simulation skipped because this node produced no macro ops
# ========================================================================================================================
# node index: 7
# node info:
# {'node_name': 'self_attn_attn',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.attn'}
# macro op count: 1
# macro op type summary: {'FlashAttnOp': 1}
# macro op details:
# {'id': 5,
#  'input_ops': [],
#  'qk_bmm_shape': (36864, 16, 128, 128),
#  'softmax_shape': (589824, 128),
#  'sv_bmm_shape': (36864, 16, 128, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# FlashAttnOp(id=5, input_ops=[], qk_bmm_shape=(36864, 16, 128, 128), sv_bmm_shape=(36864, 16, 128, 128), softmax_shape=(589824, 128), weight_bits=16)
# sim cycle: 1097605
# sim time ns: 599784
# trace path: trace/qwen3_moe/node_007_self_attn_attn_call_module.json
# trace event count: 5
# trace complete event count: 1
# trace complete event categories: {'compute': 1}
# ========================================================================================================================
# node index: 8
# node info:
# {'node_name': 'self_attn_o_proj',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.o_proj'}
# macro op count: 1
# macro op type summary: {'MatMulOp': 1}
# macro op details:
# {'dim': (1024, 8192, 4096),
#  'id': 6,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# MatMulOp(id=6, input_ops=[], dim=(1024, 8192, 4096), weight_bits=16)
# sim cycle: 147006
# sim time ns: 80331
# trace path: trace/qwen3_moe/node_008_self_attn_o_proj_call_module.json
# trace event count: 5
# trace complete event count: 1
# trace complete event categories: {'compute': 1}
# ========================================================================================================================
# node index: 9
# node info:
# {'node_name': 'add',
#  'node_op': 'call_function',
#  'node_target': '<built-in function add>'}
# macro op count: 0
# macro op type summary: {}
# macro op details:
# simulation skipped because this node produced no macro ops
# ========================================================================================================================
# node index: 10
# node info:
# {'node_name': 'post_attention_layernorm',
#  'node_op': 'call_module',
#  'node_target': 'post_attention_layernorm'}
# macro op count: 1
# macro op type summary: {'VectorOp': 1}
# macro op details:
# {'id': 7,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'rms_norm',
#  'vector_shape': [1024, 4096],
#  'weight_bits': 16}
# VectorOp(id=7, input_ops=[], vector_op_type='rms_norm', vector_shape=[1024, 4096], weight_bits=16)
# sim cycle: 500
# sim time ns: 273
# trace path: trace/qwen3_moe/node_010_post_attention_layernorm_call_module.json
# trace event count: 5
# trace complete event count: 1
# trace complete event categories: {'compute': 1}
# ========================================================================================================================
# node index: 11
# node info:
# {'node_name': 'mlp', 'node_op': 'call_module', 'node_target': 'mlp'}
# macro op count: 53
# macro op type summary: {'MatMulOp': 33, 'VectorOp': 18, 'All2AllOp': 2}
# macro op details:
# {'dim': (1024, 4096, 128),
#  'id': 8,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 9,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'moe_topk_router',
#  'vector_shape': [1024, 128, 8],
#  'weight_bits': 16}
# {'data_size': 8388608,
#  'id': 10,
#  'input_ops': [{'id': 9, 'type': 'VectorOp'}],
#  'num_gpus': 8,
#  'type': 'All2AllOp',
#  'weight_bits': 16}
# {'dim': (64, 4096, 3072),
#  'id': 11,
#  'input_ops': [{'id': 10, 'type': 'All2AllOp'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 12,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'dim': (64, 1536, 4096),
#  'id': 13,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'dim': (64, 4096, 3072),
#  'id': 14,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 15,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'dim': (64, 1536, 4096),
#  'id': 16,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'dim': (64, 4096, 3072),
#  'id': 17,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 18,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'dim': (64, 1536, 4096),
#  'id': 19,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'dim': (64, 4096, 3072),
#  'id': 20,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 21,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'dim': (64, 1536, 4096),
#  'id': 22,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'dim': (64, 4096, 3072),
#  'id': 23,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 24,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'dim': (64, 1536, 4096),
#  'id': 25,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'dim': (64, 4096, 3072),
#  'id': 26,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 27,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'dim': (64, 1536, 4096),
#  'id': 28,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'dim': (64, 4096, 3072),
#  'id': 29,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 30,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'dim': (64, 1536, 4096),
#  'id': 31,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'dim': (64, 4096, 3072),
#  'id': 32,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 33,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'dim': (64, 1536, 4096),
#  'id': 34,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'dim': (64, 4096, 3072),
#  'id': 35,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 36,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'dim': (64, 1536, 4096),
#  'id': 37,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'dim': (64, 4096, 3072),
#  'id': 38,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 39,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'dim': (64, 1536, 4096),
#  'id': 40,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'dim': (64, 4096, 3072),
#  'id': 41,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 42,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'dim': (64, 1536, 4096),
#  'id': 43,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'dim': (64, 4096, 3072),
#  'id': 44,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 45,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'dim': (64, 1536, 4096),
#  'id': 46,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'dim': (64, 4096, 3072),
#  'id': 47,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 48,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'dim': (64, 1536, 4096),
#  'id': 49,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'dim': (64, 4096, 3072),
#  'id': 50,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 51,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'dim': (64, 1536, 4096),
#  'id': 52,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'dim': (64, 4096, 3072),
#  'id': 53,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 54,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'dim': (64, 1536, 4096),
#  'id': 55,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'dim': (64, 4096, 3072),
#  'id': 56,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 57,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'dim': (64, 1536, 4096),
#  'id': 58,
#  'input_ops': [],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'data_size': 8388608,
#  'id': 59,
#  'input_ops': [{'id': 58, 'type': 'MatMulOp'}],
#  'num_gpus': 8,
#  'type': 'All2AllOp',
#  'weight_bits': 16}
# {'id': 60,
#  'input_ops': [{'id': 59, 'type': 'All2AllOp'}],
#  'type': 'VectorOp',
#  'vector_op_type': 'moe_weighted_sum',
#  'vector_shape': [1024, 4096],
#  'weight_bits': 16}
# MatMulOp(id=8, input_ops=[], dim=(1024, 4096, 128), weight_bits=16)
# VectorOp(id=9, input_ops=[], vector_op_type='moe_topk_router', vector_shape=[1024, 128, 8], weight_bits=16)
# MatMulOp(id=11, input_ops=[All2AllOp(id=10, input_ops=[VectorOp(id=9, input_ops=[], vector_op_type='moe_topk_router', vector_shape=[1024, 128, 8], weight_bits=16)], num_gpus=8, data_size=8388608, weight_bits=16)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=12, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=13, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=14, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=15, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=16, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=17, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=18, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=19, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=20, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=21, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=22, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=23, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=24, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=25, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=26, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=27, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=28, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=29, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=30, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=31, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=32, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=33, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=34, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=35, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=36, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=37, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=38, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=39, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=40, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=41, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=42, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=43, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=44, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=45, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=46, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=47, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=48, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=49, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=50, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=51, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=52, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=53, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=54, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=55, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=56, input_ops=[], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=57, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=58, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)
# VectorOp(id=60, input_ops=[All2AllOp(id=59, input_ops=[MatMulOp(id=58, input_ops=[], dim=(64, 1536, 4096), weight_bits=16)], num_gpus=8, data_size=8388608, weight_bits=16)], vector_op_type='moe_weighted_sum', vector_shape=[1024, 4096], weight_bits=16)
# sim cycle: 798376
# sim time ns: 436271
# trace path: trace/qwen3_moe/node_011_mlp_call_module.json
# trace event count: 57
# trace complete event count: 53
# trace complete event categories: {'compute': 51, 'transfer': 2}
# ========================================================================================================================
# node index: 12
# node info:
# {'node_name': 'add_1',
#  'node_op': 'call_function',
#  'node_target': '<built-in function add>'}
# macro op count: 0
# macro op type summary: {}
# macro op details:
# simulation skipped because this node produced no macro ops

# %%
node_sim_results
# Out:
# [{'node_name': 'hidden_states',
#   'node_op': 'placeholder',
#   'node_target': 'hidden_states',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []},
#  {'node_name': 'input_layernorm',
#   'node_op': 'call_module',
#   'node_target': 'input_layernorm',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 500,
#   'sim_time_ns': 273,
#   'trace_path': 'trace/qwen3_moe/node_001_input_layernorm_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 1,
#     'input_ops': [],
#     'vector_op_type': 'rms_norm',
#     'vector_shape': [1024, 4096],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'self_attn_qkv_proj',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.qkv_proj',
#   'macro_op_count': 1,
#   'macro_op_types': ['MatMulOp'],
#   'sim_cycle': 166428,
#   'sim_time_ns': 90944,
#   'trace_path': 'trace/qwen3_moe/node_002_self_attn_qkv_proj_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 2,
#     'input_ops': [],
#     'dim': (1024, 4096, 9216),
#     'weight_bits': 16,
#     'type': 'MatMulOp'}]},
#  {'node_name': 'self_attn_q_norm',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.q_norm',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 19,
#   'sim_time_ns': 10,
#   'trace_path': 'trace/qwen3_moe/node_003_self_attn_q_norm_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 3,
#     'input_ops': [],
#     'vector_op_type': 'rms_norm',
#     'vector_shape': [1024, 128],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'self_attn_k_norm',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.k_norm',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 19,
#   'sim_time_ns': 10,
#   'trace_path': 'trace/qwen3_moe/node_004_self_attn_k_norm_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 4,
#     'input_ops': [],
#     'vector_op_type': 'rms_norm',
#     'vector_shape': [1024, 128],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'self_attn__dummy_positions',
#   'node_op': 'get_attr',
#   'node_target': 'self_attn._dummy_positions',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []},
#  {'node_name': 'self_attn_rotary_emb',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.rotary_emb',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []},
#  {'node_name': 'self_attn_attn',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.attn',
#   'macro_op_count': 1,
#   'macro_op_types': ['FlashAttnOp'],
#   'sim_cycle': 1097605,
#   'sim_time_ns': 599784,
#   'trace_path': 'trace/qwen3_moe/node_007_self_attn_attn_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 5,
#     'input_ops': [],
#     'qk_bmm_shape': (36864, 16, 128, 128),
#     'sv_bmm_shape': (36864, 16, 128, 128),
#     'softmax_shape': (589824, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'}]},
#  {'node_name': 'self_attn_o_proj',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.o_proj',
#   'macro_op_count': 1,
#   'macro_op_types': ['MatMulOp'],
#   'sim_cycle': 147006,
#   'sim_time_ns': 80331,
#   'trace_path': 'trace/qwen3_moe/node_008_self_attn_o_proj_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 6,
#     'input_ops': [],
#     'dim': (1024, 8192, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'}]},
#  {'node_name': 'add',
#   'node_op': 'call_function',
#   'node_target': '<built-in function add>',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []},
#  {'node_name': 'post_attention_layernorm',
#   'node_op': 'call_module',
#   'node_target': 'post_attention_layernorm',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 500,
#   'sim_time_ns': 273,
#   'trace_path': 'trace/qwen3_moe/node_010_post_attention_layernorm_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 7,
#     'input_ops': [],
#     'vector_op_type': 'rms_norm',
#     'vector_shape': [1024, 4096],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'mlp',
#   'node_op': 'call_module',
#   'node_target': 'mlp',
#   'macro_op_count': 53,
#   'macro_op_types': ['MatMulOp',
#    'VectorOp',
#    'All2AllOp',
#    'MatMulOp',
#    'VectorOp',
#    'MatMulOp',
#    'MatMulOp',
#    'VectorOp',
#    'MatMulOp',
#    'MatMulOp',
#    'VectorOp',
#    'MatMulOp',
#    'MatMulOp',
#    'VectorOp',
#    'MatMulOp',
#    'MatMulOp',
#    'VectorOp',
#    'MatMulOp',
#    'MatMulOp',
#    'VectorOp',
#    'MatMulOp',
#    'MatMulOp',
#    'VectorOp',
#    'MatMulOp',
#    'MatMulOp',
#    'VectorOp',
#    'MatMulOp',
#    'MatMulOp',
#    'VectorOp',
#    'MatMulOp',
#    'MatMulOp',
#    'VectorOp',
#    'MatMulOp',
#    'MatMulOp',
#    'VectorOp',
#    'MatMulOp',
#    'MatMulOp',
#    'VectorOp',
#    'MatMulOp',
#    'MatMulOp',
#    'VectorOp',
#    'MatMulOp',
#    'MatMulOp',
#    'VectorOp',
#    'MatMulOp',
#    'MatMulOp',
#    'VectorOp',
#    'MatMulOp',
#    'MatMulOp',
#    'VectorOp',
#    'MatMulOp',
#    'All2AllOp',
#    'VectorOp'],
#   'sim_cycle': 798376,
#   'sim_time_ns': 436271,
#   'trace_path': 'trace/qwen3_moe/node_011_mlp_call_module.json',
#   'trace_event_count': 57,
#   'trace_complete_event_count': 53,
#   'trace_complete_event_categories': {'compute': 51, 'transfer': 2},
#   'macro_ops': [{'id': 8,
#     'input_ops': [],
#     'dim': (1024, 4096, 128),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 9,
#     'input_ops': [],
#     'vector_op_type': 'moe_topk_router',
#     'vector_shape': [1024, 128, 8],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 10,
#     'input_ops': [{'id': 9, 'type': 'VectorOp'}],
#     'num_gpus': 8,
#     'data_size': 8388608,
#     'weight_bits': 16,
#     'type': 'All2AllOp'},
#    {'id': 11,
#     'input_ops': [{'id': 10, 'type': 'All2AllOp'}],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 12,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 13,
#     'input_ops': [],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 14,
#     'input_ops': [],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 15,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 16,
#     'input_ops': [],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 17,
#     'input_ops': [],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 18,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 19,
#     'input_ops': [],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 20,
#     'input_ops': [],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 21,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 22,
#     'input_ops': [],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 23,
#     'input_ops': [],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 24,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 25,
#     'input_ops': [],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 26,
#     'input_ops': [],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 27,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 28,
#     'input_ops': [],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 29,
#     'input_ops': [],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 30,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 31,
#     'input_ops': [],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 32,
#     'input_ops': [],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 33,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 34,
#     'input_ops': [],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 35,
#     'input_ops': [],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 36,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 37,
#     'input_ops': [],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 38,
#     'input_ops': [],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 39,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 40,
#     'input_ops': [],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 41,
#     'input_ops': [],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 42,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 43,
#     'input_ops': [],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 44,
#     'input_ops': [],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 45,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 46,
#     'input_ops': [],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 47,
#     'input_ops': [],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 48,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 49,
#     'input_ops': [],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 50,
#     'input_ops': [],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 51,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 52,
#     'input_ops': [],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 53,
#     'input_ops': [],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 54,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 55,
#     'input_ops': [],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 56,
#     'input_ops': [],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 57,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 58,
#     'input_ops': [],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 59,
#     'input_ops': [{'id': 58, 'type': 'MatMulOp'}],
#     'num_gpus': 8,
#     'data_size': 8388608,
#     'weight_bits': 16,
#     'type': 'All2AllOp'},
#    {'id': 60,
#     'input_ops': [{'id': 59, 'type': 'All2AllOp'}],
#     'vector_op_type': 'moe_weighted_sum',
#     'vector_shape': [1024, 4096],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'add_1',
#   'node_op': 'call_function',
#   'node_target': '<built-in function add>',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []}]

# %%
non_empty_node_results = [result for result in node_sim_results if result["macro_op_count"] > 0]
empty_node_results = [result for result in node_sim_results if result["macro_op_count"] == 0]

assert len(node_sim_results) == len(all_graph_nodes)
assert full_sim_result["cycle"] > 0
assert full_sim_result["time_ns"] > 0
assert full_sim_result["trace_path"] is not None
assert full_sim_result["trace_event_count"] is not None
assert full_sim_result["trace_complete_event_count"] is not None
assert non_empty_node_results
assert all(result["sim_cycle"] is not None for result in non_empty_node_results)
assert all(result["sim_time_ns"] is not None for result in non_empty_node_results)
assert all(result["trace_path"] is not None for result in non_empty_node_results)
assert all(result["trace_event_count"] is not None for result in non_empty_node_results)
assert all(result["trace_complete_event_count"] is not None for result in non_empty_node_results)
assert all(result["sim_cycle"] is None for result in empty_node_results)
assert all(result["trace_path"] is None for result in empty_node_results)

full_sim_summary = {
    "macro_op_count": len(macro_op_list),
    "macro_op_type_summary": dict(macro_summary(macro_op_list)),
    "sim_cycle": full_sim_result["cycle"],
    "sim_time_ns": full_sim_result["time_ns"],
    "trace_path": full_sim_result["trace_path"],
    "trace_event_count": full_sim_result["trace_event_count"],
    "trace_complete_event_count": full_sim_result["trace_complete_event_count"],
    "trace_complete_event_categories": full_sim_result[
        "trace_complete_event_categories"
    ],
}

summary_rows = [
    {
        "node_name": result["node_name"],
        "node_op": result["node_op"],
        "node_target": result["node_target"],
        "macro_op_count": result["macro_op_count"],
        "macro_op_types": result["macro_op_types"],
        "sim_cycle": result["sim_cycle"],
        "sim_time_ns": result["sim_time_ns"],
        "trace_path": result["trace_path"],
        "trace_event_count": result["trace_event_count"],
        "trace_complete_event_count": result["trace_complete_event_count"],
        "trace_complete_event_categories": result["trace_complete_event_categories"],
    }
    for result in node_sim_results
]

{
    "full_simulation": full_sim_summary,
    "node_simulations": summary_rows,
}
# Out:
# {'full_simulation': {'macro_op_count': 60,
#   'macro_op_type_summary': {'VectorOp': 22,
#    'MatMulOp': 35,
#    'FlashAttnOp': 1,
#    'All2AllOp': 2},
#   'sim_cycle': 2210450,
#   'sim_time_ns': 1207896,
#   'trace_path': 'trace/qwen3_moe/full_simulation.json',
#   'trace_event_count': 64,
#   'trace_complete_event_count': 60,
#   'trace_complete_event_categories': {'compute': 58, 'transfer': 2}},
#  'node_simulations': [{'node_name': 'hidden_states',
#    'node_op': 'placeholder',
#    'node_target': 'hidden_states',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None},
#   {'node_name': 'input_layernorm',
#    'node_op': 'call_module',
#    'node_target': 'input_layernorm',
#    'macro_op_count': 1,
#    'macro_op_types': ['VectorOp'],
#    'sim_cycle': 500,
#    'sim_time_ns': 273,
#    'trace_path': 'trace/qwen3_moe/node_001_input_layernorm_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'self_attn_qkv_proj',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.qkv_proj',
#    'macro_op_count': 1,
#    'macro_op_types': ['MatMulOp'],
#    'sim_cycle': 166428,
#    'sim_time_ns': 90944,
#    'trace_path': 'trace/qwen3_moe/node_002_self_attn_qkv_proj_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'self_attn_q_norm',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.q_norm',
#    'macro_op_count': 1,
#    'macro_op_types': ['VectorOp'],
#    'sim_cycle': 19,
#    'sim_time_ns': 10,
#    'trace_path': 'trace/qwen3_moe/node_003_self_attn_q_norm_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'self_attn_k_norm',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.k_norm',
#    'macro_op_count': 1,
#    'macro_op_types': ['VectorOp'],
#    'sim_cycle': 19,
#    'sim_time_ns': 10,
#    'trace_path': 'trace/qwen3_moe/node_004_self_attn_k_norm_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'self_attn__dummy_positions',
#    'node_op': 'get_attr',
#    'node_target': 'self_attn._dummy_positions',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None},
#   {'node_name': 'self_attn_rotary_emb',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.rotary_emb',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None},
#   {'node_name': 'self_attn_attn',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.attn',
#    'macro_op_count': 1,
#    'macro_op_types': ['FlashAttnOp'],
#    'sim_cycle': 1097605,
#    'sim_time_ns': 599784,
#    'trace_path': 'trace/qwen3_moe/node_007_self_attn_attn_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'self_attn_o_proj',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.o_proj',
#    'macro_op_count': 1,
#    'macro_op_types': ['MatMulOp'],
#    'sim_cycle': 147006,
#    'sim_time_ns': 80331,
#    'trace_path': 'trace/qwen3_moe/node_008_self_attn_o_proj_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'add',
#    'node_op': 'call_function',
#    'node_target': '<built-in function add>',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None},
#   {'node_name': 'post_attention_layernorm',
#    'node_op': 'call_module',
#    'node_target': 'post_attention_layernorm',
#    'macro_op_count': 1,
#    'macro_op_types': ['VectorOp'],
#    'sim_cycle': 500,
#    'sim_time_ns': 273,
#    'trace_path': 'trace/qwen3_moe/node_010_post_attention_layernorm_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'mlp',
#    'node_op': 'call_module',
#    'node_target': 'mlp',
#    'macro_op_count': 53,
#    'macro_op_types': ['MatMulOp',
#     'VectorOp',
#     'All2AllOp',
#     'MatMulOp',
#     'VectorOp',
#     'MatMulOp',
#     'MatMulOp',
#     'VectorOp',
#     'MatMulOp',
#     'MatMulOp',
#     'VectorOp',
#     'MatMulOp',
#     'MatMulOp',
#     'VectorOp',
#     'MatMulOp',
#     'MatMulOp',
#     'VectorOp',
#     'MatMulOp',
#     'MatMulOp',
#     'VectorOp',
#     'MatMulOp',
#     'MatMulOp',
#     'VectorOp',
#     'MatMulOp',
#     'MatMulOp',
#     'VectorOp',
#     'MatMulOp',
#     'MatMulOp',
#     'VectorOp',
#     'MatMulOp',
#     'MatMulOp',
#     'VectorOp',
#     'MatMulOp',
#     'MatMulOp',
#     'VectorOp',
#     'MatMulOp',
#     'MatMulOp',
#     'VectorOp',
#     'MatMulOp',
#     'MatMulOp',
#     'VectorOp',
#     'MatMulOp',
#     'MatMulOp',
#     'VectorOp',
#     'MatMulOp',
#     'MatMulOp',
#     'VectorOp',
#     'MatMulOp',
#     'MatMulOp',
#     'VectorOp',
#     'MatMulOp',
#     'All2AllOp',
#     'VectorOp'],
#    'sim_cycle': 798376,
#    'sim_time_ns': 436271,
#    'trace_path': 'trace/qwen3_moe/node_011_mlp_call_module.json',
#    'trace_event_count': 57,
#    'trace_complete_event_count': 53,
#    'trace_complete_event_categories': {'compute': 51, 'transfer': 2}},
#   {'node_name': 'add_1',
#    'node_op': 'call_function',
#    'node_target': '<built-in function add>',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None}]}

# %%
print(kv_cache_state)
# Out:
# KVCacheState(total_kv_cache_size_per_layer=19327352832, kv_block_size_tokens=128, num_kv_blocks=73728, num_nand_pages_per_layer=4718592, num_hyper_pages_per_layer=1024)
