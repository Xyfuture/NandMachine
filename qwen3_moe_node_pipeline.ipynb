# %% [markdown]
# # Node-Level Frontend Pipeline For Qwen3 MoE
#
# 实现 Qwen3 MoE decoder layer 的最小前端全流程，并在 code gen pass 之后按 node 读取 `marco_op_list`，对每个 node 单独运行硬件仿真，同时对完整 `macro_op_list` 运行一次整体硬件仿真，并把 perf trace 输出到 `trace/qwen3_moe/` 目录。

# %% [markdown]
# ## 流程
# - 加载 `qwen3-moe-235B` model card 并初始化 `Qwen3MoEModelConfig`
# - 初始化 `NandConfig`、`MoEParallelConfig` 和 `InferenceConfig`
# - 初始化 `Qwen3MoEDecoderLayer`
# - 使用 `NxTracer` trace 得到计算图
# - 运行 `NormalizePass` 获得简化图
# - 用 `build_kv_cache_state` 构造 `KVCacheState`
# - 构造 `NxGraphMeta` 并写入 `graph.meta`
# - 运行 `CodeGenPass`，收集全局和 node 级别的 `marco_op_list`
# - 对完整 `macro_op_list` 运行一次硬件仿真，并把完整 trace 保存到 `trace/qwen3_moe/full_simulation.json`
# - 对每个 node 单独运行硬件仿真，并把 node trace 保存到 `trace/qwen3_moe/` 目录
# - 汇总完整仿真和 node 级别的 macro op、时延和 trace 信息

# %%
import json
import logging
import re
from collections import Counter
from dataclasses import fields, is_dataclass
from math import ceil
from pathlib import Path
from pprint import pprint

import torch
from Desim import SimSession
from torch.fx import GraphModule

from nandmachine.commands.macro import All2AllOp, FlashAttnOp, MacroOp, MatMulOp, VectorOp
from nandmachine.config.config import NandConfig
from nandmachine.config.hardware_config import get_device_or_raise
from nandmachine.config.inference_config import InferenceConfig, MoEParallelConfig
from nandmachine.config.model_config import Qwen3MoEModelConfig
from nandmachine.frontend.core.graph.base import NxGraphMeta, NxTracer
from nandmachine.frontend.core.passes.cod_gen import CodeGenPass
from nandmachine.frontend.core.passes.normalize import NormalizePass
from nandmachine.frontend.network.qwen3_moe import Qwen3MoEDecoderLayer
from nandmachine.frontend.utlis import build_kv_cache_state
from nandmachine.simulator.entry_point import run_sim
from nandmachine.simulator.hardware.xpu import xPU

MODEL_CARD_PATH = Path("model_cards/qwen3-moe-235B.json")
DEVICE_NAME = "H200_SXM"
COMPILE_MODE = "heuristic-GPU"
NUM_RANKS = 8
ATTN_DP_SIZE = 8
ATTN_TP_SIZE = 1
FFN_TP_SIZE = 1
FFN_EP_SIZE = 8
HBM_BANDWIDTH_GBPS = 3350
TRACE_DIR = Path("trace/qwen3_moe")
FULL_TRACE_FILE_NAME = "full_simulation.json"

assert MODEL_CARD_PATH.exists(), MODEL_CARD_PATH
assert NUM_RANKS > 0, NUM_RANKS
assert ATTN_DP_SIZE > 0, ATTN_DP_SIZE
assert ATTN_TP_SIZE > 0, ATTN_TP_SIZE
assert FFN_TP_SIZE > 0, FFN_TP_SIZE
assert FFN_EP_SIZE > 0, FFN_EP_SIZE


def node_summary(graph_module: GraphModule) -> list[tuple[str, str, str]]:
    return [(node.name, node.op, str(node.target)) for node in graph_module.graph.nodes]


def macro_summary(macro_op_list: list[object]) -> Counter:
    return Counter(type(op).__name__ for op in macro_op_list)


def node_info(node: torch.fx.Node) -> dict[str, object]:
    return {
        "node_name": node.name,
        "node_op": node.op,
        "node_target": str(node.target),
    }


def _serialize_value(value: object) -> object:
    if isinstance(value, MacroOp):
        return {
            "id": value.id,
            "type": type(value).__name__,
        }
    if isinstance(value, list):
        return [_serialize_value(item) for item in value]
    if isinstance(value, tuple):
        return tuple(_serialize_value(item) for item in value)
    return value


def macro_info(op: MacroOp) -> dict[str, object]:
    assert is_dataclass(op), type(op)
    payload = {field.name: _serialize_value(getattr(op, field.name)) for field in fields(op)}
    payload["type"] = type(op).__name__
    return payload


def _sanitize_trace_name(raw_name: str) -> str:
    return re.sub(r"[^0-9A-Za-z._-]+", "_", raw_name).strip("._")


def trace_file_path(node_index: int, node: torch.fx.Node) -> Path:
    file_name = _sanitize_trace_name(f"node_{node_index:03d}_{node.name}_{node.op}")
    return TRACE_DIR / f"{file_name}.json"


def full_trace_file_path() -> Path:
    return TRACE_DIR / FULL_TRACE_FILE_NAME


def run_macro_ops_with_trace(
    nand_config: NandConfig,
    commands: list[MacroOp],
    *,
    trace_path: Path,
    device_name: str,
    compile_mode: str,
    hbm_bandwidth_GBps: float,
) -> dict[str, object]:
    SimSession.reset()
    SimSession.init()

    hbm_bandwidth_bytes_per_sec = hbm_bandwidth_GBps * 10**9

    sim_xpu = xPU(
        nand_config,
        hbm_bandwidth_bytes_per_sec=hbm_bandwidth_bytes_per_sec,
        device_name=device_name,
        compile_mode=compile_mode,
        enable_trace=True,
    )
    sim_xpu.load_command(commands)
    SimSession.scheduler.run()

    final_time_ns = int(SimSession.sim_time.cycle)
    device = get_device_or_raise(device_name)
    final_cycle = ceil(final_time_ns * device.compute_module.clock_freq / 1e9)

    trace_path.parent.mkdir(parents=True, exist_ok=True)
    saved_trace_path = Path(sim_xpu.save_trace_file(str(trace_path)))

    tracer = sim_xpu.tracer
    assert tracer is not None
    complete_events = [event for event in tracer._events if event["ph"] == "X"]

    return {
        "cycle": final_cycle,
        "time_ns": final_time_ns,
        "trace_path": str(saved_trace_path),
        "trace_event_count": len(tracer._events),
        "trace_complete_event_count": len(complete_events),
        "trace_complete_event_categories": dict(
            Counter(event["cat"] for event in complete_events)
        ),
    }

# %%
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
)

model_card = json.loads(MODEL_CARD_PATH.read_text())
model_card.setdefault("attention_type", "gqa")
raw_model_config = type("Qwen3MoeConfig", (), model_card)()
model_config = Qwen3MoEModelConfig.from_config(raw_model_config)
nand_config = NandConfig(
    num_channels=6 * 8,
    num_plane=96,
    num_block=16, # 没什么用的参数
    num_pages=16, # 没什么用的参数
    tRead=4000, # ns
    tWrite=4000 * 10, # ns
    tErase=4000 * 100, # ns
    page_size=4, # KB
    sram_threshold=1024 * 80,  # KB  --  可以考虑之后统一改成 Bytes，统一所有的单位
)
parallel_config = MoEParallelConfig(
    num_ranks=NUM_RANKS,
    attn_dp_size=ATTN_DP_SIZE,
    attn_tp_size=ATTN_TP_SIZE,
    ffn_tp_size=FFN_TP_SIZE,
    ffn_ep_size=FFN_EP_SIZE,
)
inference_config = InferenceConfig(
    batch_size=1024,
    input_sequence_length=8*1024,
    output_sequence_length=1*1024,
    weight_bits=16,
    activation_bits=16,
    kv_cache_bits=16,
    kv_block_size_bytes=1024 * 256,
    memory_backend="nand",
    parallel_config=parallel_config,
)
kv_cache_state = build_kv_cache_state(nand_config, model_config, inference_config)
graph_meta = NxGraphMeta(
    nand_config=nand_config,
    model_config=model_config,
    inference_config=inference_config,
    kv_cache_state=kv_cache_state,
)
simulator_config = {
    "device_name": DEVICE_NAME,
    "compile_mode": COMPILE_MODE,
    "hbm_bandwidth_GBps": HBM_BANDWIDTH_GBPS,
}
hbm_bandwidth_bytes_per_sec = HBM_BANDWIDTH_GBPS * 10**9
runtime_simulator_config = {
    "device_name": simulator_config["device_name"],
    "compile_mode": simulator_config["compile_mode"],
    "hbm_bandwidth_GBps": simulator_config["hbm_bandwidth_GBps"],
}
TRACE_DIR.mkdir(parents=True, exist_ok=True)

print("HBM bandwidth (GBps):", HBM_BANDWIDTH_GBPS)
print("trace output dir:", TRACE_DIR)
print("full simulation trace path:", full_trace_file_path())
print("parallel config:", parallel_config)
print("simulator config:", simulator_config)
# Out:
# HBM bandwidth (GBps): 3350
# trace output dir: trace/qwen3_moe
# full simulation trace path: trace/qwen3_moe/full_simulation.json
# parallel config: MoEParallelConfig(num_ranks=8, attn_dp_size=8, attn_tp_size=1, ffn_tp_size=1, ffn_ep_size=8)
# simulator config: {'device_name': 'H200_SXM', 'compile_mode': 'heuristic-GPU', 'hbm_bandwidth_GBps': 3350}

# %%
with torch.device("meta"):
    model = Qwen3MoEDecoderLayer(raw_model_config, parallel_config)
    graph = NxTracer().trace(model)
    graph_module = GraphModule(model, graph)

NormalizePass().transform(graph_module)
graph_module.graph.meta = {CodeGenPass.GRAPH_META_KEY: graph_meta}
CodeGenPass().transform(graph_module)

all_graph_nodes = list(graph_module.graph.nodes)
all_node_infos = [node_info(node) for node in all_graph_nodes]
node_count_with_macro_ops = sum(1 for node in all_graph_nodes if "marco_op_list" in node.meta)
macro_op_list = graph_module.graph.meta[CodeGenPass.MACRO_OP_LIST_META_KEY]
vector_ops = [op for op in macro_op_list if isinstance(op, VectorOp)]
all_to_all_ops = [op for op in macro_op_list if isinstance(op, All2AllOp)]

print("normalized node count:", len(node_summary(graph_module)))
print("node count with macro op entries:", node_count_with_macro_ops)
print("global macro op count:", len(macro_op_list))
print("global macro op type summary:", dict(macro_summary(macro_op_list)))
print("vector op type summary:", dict(Counter(op.vector_op_type for op in vector_ops)))
print("all_to_all count:", len(all_to_all_ops))
print("all node infos:")
for current_node_info in all_node_infos:
    pprint(current_node_info)
# Out:
# 2026-04-09 23:40:33,757 - INFO - Processed node=input_layernorm generated_macro_ops=1
# 2026-04-09 23:40:33,757 - INFO - Processed node=self_attn_qkv_proj generated_macro_ops=3
# 2026-04-09 23:40:33,757 - INFO - Processed node=self_attn_q_norm generated_macro_ops=1
# 2026-04-09 23:40:33,757 - INFO - Processed node=self_attn_k_norm generated_macro_ops=1
# 2026-04-09 23:40:33,758 - INFO - Processed node=self_attn_rotary_emb generated_macro_ops=0
# 2026-04-09 23:40:33,791 - INFO - Processed node=self_attn_attn generated_macro_ops=384
# 2026-04-09 23:40:33,792 - INFO - Processed node=self_attn_o_proj generated_macro_ops=3
# 2026-04-09 23:40:33,792 - INFO - Processed node=post_attention_layernorm generated_macro_ops=1
# 2026-04-09 23:40:33,792 - INFO - Processed node=mlp generated_macro_ops=119
# normalized node count: 13
# node count with macro op entries: 9
# global macro op count: 513
# global macro op type summary: {'VectorOp': 22, 'SramPrefetch': 163, 'MatMulOp': 35, 'SramPrefetchRelease': 163, 'FlashAttnOp': 128, 'All2AllOp': 2}
# vector op type summary: {'rms_norm': 4, 'moe_topk_router': 1, 'silu_mul': 16, 'moe_weighted_sum': 1}
# all_to_all count: 2
# all node infos:
# {'node_name': 'hidden_states',
#  'node_op': 'placeholder',
#  'node_target': 'hidden_states'}
# {'node_name': 'input_layernorm',
#  'node_op': 'call_module',
#  'node_target': 'input_layernorm'}
# {'node_name': 'self_attn_qkv_proj',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.qkv_proj'}
# {'node_name': 'self_attn_q_norm',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.q_norm'}
# {'node_name': 'self_attn_k_norm',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.k_norm'}
# {'node_name': 'self_attn__dummy_positions',
#  'node_op': 'get_attr',
#  'node_target': 'self_attn._dummy_positions'}
# {'node_name': 'self_attn_rotary_emb',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.rotary_emb'}
# {'node_name': 'self_attn_attn',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.attn'}
# {'node_name': 'self_attn_o_proj',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.o_proj'}
# {'node_name': 'add',
#  'node_op': 'call_function',
#  'node_target': '<built-in function add>'}
# {'node_name': 'post_attention_layernorm',
#  'node_op': 'call_module',
#  'node_target': 'post_attention_layernorm'}
# {'node_name': 'mlp', 'node_op': 'call_module', 'node_target': 'mlp'}
# {'node_name': 'add_1',
#  'node_op': 'call_function',
#  'node_target': '<built-in function add>'}

# %%
print(graph_meta.batch_size)
print(graph_meta.global_batch_size)
# Out:
# 128
# 1024

# %%
assert macro_op_list
assert all_graph_nodes
assert any(isinstance(op, MatMulOp) for op in macro_op_list)
assert any(isinstance(op, FlashAttnOp) for op in macro_op_list)
assert any(isinstance(op, All2AllOp) for op in macro_op_list)
assert any(op.vector_op_type == "moe_topk_router" for op in vector_ops)
assert any(op.vector_op_type == "moe_weighted_sum" for op in vector_ops)
assert any(op.vector_op_type == "silu_mul" for op in vector_ops)
assert any(op.vector_op_type == "rms_norm" for op in vector_ops)
assert all(all(dim > 0 for dim in op.vector_shape) for op in vector_ops)

print("qwen3 moe node-level frontend pipeline completed successfully")
# Out:
# qwen3 moe node-level frontend pipeline completed successfully

# %%
print("=" * 120)
print("full simulation")
print("macro op count:", len(macro_op_list))
print("macro op type summary:", dict(macro_summary(macro_op_list)))

full_trace_path = full_trace_file_path()
full_sim_result = run_macro_ops_with_trace(
    nand_config,
    macro_op_list,
    trace_path=full_trace_path,
    **runtime_simulator_config,
)
assert full_sim_result["cycle"] > 0
assert full_sim_result["time_ns"] > 0
print("sim cycle:", full_sim_result["cycle"])
print("sim time ns:", full_sim_result["time_ns"])
print("trace path:", full_sim_result["trace_path"])
print("trace event count:", full_sim_result["trace_event_count"])
print("trace complete event count:", full_sim_result["trace_complete_event_count"])
print(
    "trace complete event categories:",
    full_sim_result["trace_complete_event_categories"],
)

full_run_sim_result = run_sim(
    nand_config,
    model_config,
    inference_config,
    macro_op_list,
    hbm_bandwidth_bytes_per_sec=hbm_bandwidth_bytes_per_sec,
    device_name=runtime_simulator_config["device_name"],
    compile_mode=runtime_simulator_config["compile_mode"],
)
print("run_sim result:")
pprint(
    {
        "layer_latency_ns": full_run_sim_result.layer_latency_ns,
        "model_latency_ns": full_run_sim_result.model_latency_ns,
        "model_throughput": full_run_sim_result.model_throughput,
        "kv_cache_total_size_GB": full_run_sim_result.kv_cache_total_size_GB,
    }
)

node_sim_results = []

for node_index, node in enumerate(all_graph_nodes):
    node_macro_ops = node.meta.get("marco_op_list", [])
    current_node_info = node_info(node)
    current_macro_summary = dict(macro_summary(node_macro_ops))

    print("=" * 120)
    print("node index:", node_index)
    print("node info:")
    pprint(current_node_info)
    print("macro op count:", len(node_macro_ops))
    print("macro op type summary:", current_macro_summary)

    serialized_macro_ops = [macro_info(op) for op in node_macro_ops]
    print("macro op details:")
    for macro_op_payload in serialized_macro_ops:
        pprint(macro_op_payload)

    if not node_macro_ops:
        print("simulation skipped because this node produced no macro ops")
        node_sim_results.append(
            {
                **current_node_info,
                "macro_op_count": 0,
                "macro_op_types": [],
                "sim_cycle": None,
                "sim_time_ns": None,
                "trace_path": None,
                "trace_event_count": None,
                "trace_complete_event_count": None,
                "trace_complete_event_categories": None,
                "macro_ops": serialized_macro_ops,
            }
        )
        continue

    current_trace_path = trace_file_path(node_index, node)
    sim_result = run_macro_ops_with_trace(
        nand_config,
        node_macro_ops,
        trace_path=current_trace_path,
        **runtime_simulator_config,
    )
    assert sim_result["cycle"] > 0
    assert sim_result["time_ns"] > 0
    print("sim cycle:", sim_result["cycle"])
    print("sim time ns:", sim_result["time_ns"])
    print("trace path:", sim_result["trace_path"])
    print("trace event count:", sim_result["trace_event_count"])
    print("trace complete event count:", sim_result["trace_complete_event_count"])
    print(
        "trace complete event categories:",
        sim_result["trace_complete_event_categories"],
    )

    node_sim_results.append(
        {
            **current_node_info,
            "macro_op_count": len(node_macro_ops),
            "macro_op_types": [type(op).__name__ for op in node_macro_ops],
            "sim_cycle": sim_result["cycle"],
            "sim_time_ns": sim_result["time_ns"],
            "trace_path": sim_result["trace_path"],
            "trace_event_count": sim_result["trace_event_count"],
            "trace_complete_event_count": sim_result["trace_complete_event_count"],
            "trace_complete_event_categories": sim_result[
                "trace_complete_event_categories"
            ],
            "macro_ops": serialized_macro_ops,
        }
    )
# Out:
# ========================================================================================================================
# full simulation
# macro op count: 513
# macro op type summary: {'VectorOp': 22, 'SramPrefetch': 163, 'MatMulOp': 35, 'SramPrefetchRelease': 163, 'FlashAttnOp': 128, 'All2AllOp': 2}
# VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 4096], weight_bits=16)
# MatMulOp(id=3, input_ops=[SramPrefetch(id=2, input_ops=[], num_prefetch_pages=18432), VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 4096], weight_bits=16)], dim=(128, 4096, 9216), weight_bits=16)
# VectorOp(id=5, input_ops=[MatMulOp(id=3, input_ops=[SramPrefetch(id=2, input_ops=[], num_prefetch_pages=18432), VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 4096], weight_bits=16)], dim=(128, 4096, 9216), weight_bits=16)], vector_op_type='rms_norm', vector_shape=[128, 128], weight_bits=16)
# VectorOp(id=6, input_ops=[VectorOp(id=5, input_ops=[MatMulOp(id=3, input_ops=[SramPrefetch(id=2, input_ops=[], num_prefetch_pages=18432), VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 4096], weight_bits=16)], dim=(128, 4096, 9216), weight_bits=16)], vector_op_type='rms_norm', vector_shape=[128, 128], weight_bits=16)], vector_op_type='rms_norm', vector_shape=[128, 128], weight_bits=16)
# FlashAttnOp(id=8, input_ops=[SramPrefetch(id=7, input_ops=[], num_prefetch_pages=4608), VectorOp(id=6, input_ops=[VectorOp(id=5, input_ops=[MatMulOp(id=3, input_ops=[SramPrefetch(id=2, input_ops=[], num_prefetch_pages=18432), VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 4096], weight_bits=16)], dim=(128, 4096, 9216), weight_bits=16)], vector_op_type='rms_norm', vector_shape=[128, 128], weight_bits=16)], vector_op_type='rms_norm', vector_shape=[128, 128], weight_bits=16)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=11, input_ops=[SramPrefetch(id=10, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=14, input_ops=[SramPrefetch(id=13, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=17, input_ops=[SramPrefetch(id=16, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=20, input_ops=[SramPrefetch(id=19, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=23, input_ops=[SramPrefetch(id=22, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=26, input_ops=[SramPrefetch(id=25, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=29, input_ops=[SramPrefetch(id=28, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=32, input_ops=[SramPrefetch(id=31, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=35, input_ops=[SramPrefetch(id=34, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=38, input_ops=[SramPrefetch(id=37, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=41, input_ops=[SramPrefetch(id=40, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=44, input_ops=[SramPrefetch(id=43, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=47, input_ops=[SramPrefetch(id=46, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=50, input_ops=[SramPrefetch(id=49, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=53, input_ops=[SramPrefetch(id=52, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=56, input_ops=[SramPrefetch(id=55, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=59, input_ops=[SramPrefetch(id=58, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=62, input_ops=[SramPrefetch(id=61, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=65, input_ops=[SramPrefetch(id=64, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=68, input_ops=[SramPrefetch(id=67, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=71, input_ops=[SramPrefetch(id=70, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=74, input_ops=[SramPrefetch(id=73, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=77, input_ops=[SramPrefetch(id=76, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=80, input_ops=[SramPrefetch(id=79, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=83, input_ops=[SramPrefetch(id=82, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=86, input_ops=[SramPrefetch(id=85, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=89, input_ops=[SramPrefetch(id=88, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=92, input_ops=[SramPrefetch(id=91, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=95, input_ops=[SramPrefetch(id=94, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=98, input_ops=[SramPrefetch(id=97, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=101, input_ops=[SramPrefetch(id=100, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=104, input_ops=[SramPrefetch(id=103, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=107, input_ops=[SramPrefetch(id=106, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=110, input_ops=[SramPrefetch(id=109, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=113, input_ops=[SramPrefetch(id=112, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=116, input_ops=[SramPrefetch(id=115, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=119, input_ops=[SramPrefetch(id=118, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=122, input_ops=[SramPrefetch(id=121, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=125, input_ops=[SramPrefetch(id=124, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=128, input_ops=[SramPrefetch(id=127, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=131, input_ops=[SramPrefetch(id=130, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=134, input_ops=[SramPrefetch(id=133, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=137, input_ops=[SramPrefetch(id=136, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=140, input_ops=[SramPrefetch(id=139, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=143, input_ops=[SramPrefetch(id=142, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=146, input_ops=[SramPrefetch(id=145, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=149, input_ops=[SramPrefetch(id=148, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=152, input_ops=[SramPrefetch(id=151, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=155, input_ops=[SramPrefetch(id=154, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=158, input_ops=[SramPrefetch(id=157, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=161, input_ops=[SramPrefetch(id=160, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=164, input_ops=[SramPrefetch(id=163, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=167, input_ops=[SramPrefetch(id=166, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=170, input_ops=[SramPrefetch(id=169, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=173, input_ops=[SramPrefetch(id=172, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=176, input_ops=[SramPrefetch(id=175, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=179, input_ops=[SramPrefetch(id=178, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=182, input_ops=[SramPrefetch(id=181, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=185, input_ops=[SramPrefetch(id=184, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=188, input_ops=[SramPrefetch(id=187, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=191, input_ops=[SramPrefetch(id=190, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=194, input_ops=[SramPrefetch(id=193, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=197, input_ops=[SramPrefetch(id=196, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=200, input_ops=[SramPrefetch(id=199, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=203, input_ops=[SramPrefetch(id=202, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=206, input_ops=[SramPrefetch(id=205, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=209, input_ops=[SramPrefetch(id=208, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=212, input_ops=[SramPrefetch(id=211, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=215, input_ops=[SramPrefetch(id=214, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=218, input_ops=[SramPrefetch(id=217, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=221, input_ops=[SramPrefetch(id=220, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=224, input_ops=[SramPrefetch(id=223, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=227, input_ops=[SramPrefetch(id=226, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=230, input_ops=[SramPrefetch(id=229, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=233, input_ops=[SramPrefetch(id=232, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=236, input_ops=[SramPrefetch(id=235, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=239, input_ops=[SramPrefetch(id=238, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=242, input_ops=[SramPrefetch(id=241, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=245, input_ops=[SramPrefetch(id=244, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=248, input_ops=[SramPrefetch(id=247, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=251, input_ops=[SramPrefetch(id=250, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=254, input_ops=[SramPrefetch(id=253, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=257, input_ops=[SramPrefetch(id=256, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=260, input_ops=[SramPrefetch(id=259, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=263, input_ops=[SramPrefetch(id=262, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=266, input_ops=[SramPrefetch(id=265, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=269, input_ops=[SramPrefetch(id=268, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=272, input_ops=[SramPrefetch(id=271, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=275, input_ops=[SramPrefetch(id=274, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=278, input_ops=[SramPrefetch(id=277, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=281, input_ops=[SramPrefetch(id=280, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=284, input_ops=[SramPrefetch(id=283, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=287, input_ops=[SramPrefetch(id=286, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=290, input_ops=[SramPrefetch(id=289, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=293, input_ops=[SramPrefetch(id=292, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=296, input_ops=[SramPrefetch(id=295, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=299, input_ops=[SramPrefetch(id=298, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=302, input_ops=[SramPrefetch(id=301, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=305, input_ops=[SramPrefetch(id=304, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=308, input_ops=[SramPrefetch(id=307, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=311, input_ops=[SramPrefetch(id=310, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=314, input_ops=[SramPrefetch(id=313, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=317, input_ops=[SramPrefetch(id=316, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=320, input_ops=[SramPrefetch(id=319, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=323, input_ops=[SramPrefetch(id=322, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=326, input_ops=[SramPrefetch(id=325, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=329, input_ops=[SramPrefetch(id=328, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=332, input_ops=[SramPrefetch(id=331, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=335, input_ops=[SramPrefetch(id=334, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=338, input_ops=[SramPrefetch(id=337, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=341, input_ops=[SramPrefetch(id=340, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=344, input_ops=[SramPrefetch(id=343, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=347, input_ops=[SramPrefetch(id=346, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=350, input_ops=[SramPrefetch(id=349, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=353, input_ops=[SramPrefetch(id=352, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=356, input_ops=[SramPrefetch(id=355, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=359, input_ops=[SramPrefetch(id=358, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=362, input_ops=[SramPrefetch(id=361, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=365, input_ops=[SramPrefetch(id=364, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=368, input_ops=[SramPrefetch(id=367, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=371, input_ops=[SramPrefetch(id=370, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=374, input_ops=[SramPrefetch(id=373, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=377, input_ops=[SramPrefetch(id=376, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=380, input_ops=[SramPrefetch(id=379, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=383, input_ops=[SramPrefetch(id=382, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=386, input_ops=[SramPrefetch(id=385, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=389, input_ops=[SramPrefetch(id=388, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# MatMulOp(id=392, input_ops=[SramPrefetch(id=391, input_ops=[], num_prefetch_pages=16384), FlashAttnOp(id=389, input_ops=[SramPrefetch(id=388, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)], dim=(128, 8192, 4096), weight_bits=16)
# VectorOp(id=394, input_ops=[MatMulOp(id=392, input_ops=[SramPrefetch(id=391, input_ops=[], num_prefetch_pages=16384), FlashAttnOp(id=389, input_ops=[SramPrefetch(id=388, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)], dim=(128, 8192, 4096), weight_bits=16)], vector_op_type='rms_norm', vector_shape=[128, 4096], weight_bits=16)
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 302, in dispatch_control
#     await self.process_control(msg)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 308, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 302, in dispatch_control
#     await self.process_control(msg)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 308, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 302, in dispatch_control
#     await self.process_control(msg)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 308, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# MatMulOp(id=396, input_ops=[SramPrefetch(id=395, input_ops=[], num_prefetch_pages=256), VectorOp(id=394, input_ops=[MatMulOp(id=392, input_ops=[SramPrefetch(id=391, input_ops=[], num_prefetch_pages=16384), FlashAttnOp(id=389, input_ops=[SramPrefetch(id=388, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)], dim=(128, 8192, 4096), weight_bits=16)], vector_op_type='rms_norm', vector_shape=[128, 4096], weight_bits=16)], dim=(128, 4096, 128), weight_bits=16)
# VectorOp(id=398, input_ops=[], vector_op_type='moe_topk_router', vector_shape=[128, 128, 8], weight_bits=16)
# MatMulOp(id=401, input_ops=[SramPrefetch(id=400, input_ops=[], num_prefetch_pages=6144), All2AllOp(id=399, input_ops=[VectorOp(id=398, input_ops=[], vector_op_type='moe_topk_router', vector_shape=[128, 128, 8], weight_bits=16)], num_gpus=8, data_size=1048576, weight_bits=16)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=403, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=405, input_ops=[SramPrefetch(id=404, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=408, input_ops=[SramPrefetch(id=407, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=410, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=412, input_ops=[SramPrefetch(id=411, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=415, input_ops=[SramPrefetch(id=414, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=417, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=419, input_ops=[SramPrefetch(id=418, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=422, input_ops=[SramPrefetch(id=421, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=424, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=426, input_ops=[SramPrefetch(id=425, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=429, input_ops=[SramPrefetch(id=428, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=431, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=433, input_ops=[SramPrefetch(id=432, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=436, input_ops=[SramPrefetch(id=435, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=438, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=440, input_ops=[SramPrefetch(id=439, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=443, input_ops=[SramPrefetch(id=442, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=445, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=447, input_ops=[SramPrefetch(id=446, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=450, input_ops=[SramPrefetch(id=449, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=452, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=454, input_ops=[SramPrefetch(id=453, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=457, input_ops=[SramPrefetch(id=456, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=459, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=461, input_ops=[SramPrefetch(id=460, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=464, input_ops=[SramPrefetch(id=463, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=466, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=468, input_ops=[SramPrefetch(id=467, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=471, input_ops=[SramPrefetch(id=470, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=473, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=475, input_ops=[SramPrefetch(id=474, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=478, input_ops=[SramPrefetch(id=477, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=480, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=482, input_ops=[SramPrefetch(id=481, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=485, input_ops=[SramPrefetch(id=484, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=487, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=489, input_ops=[SramPrefetch(id=488, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=492, input_ops=[SramPrefetch(id=491, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=494, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=496, input_ops=[SramPrefetch(id=495, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=499, input_ops=[SramPrefetch(id=498, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=501, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=503, input_ops=[SramPrefetch(id=502, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=506, input_ops=[SramPrefetch(id=505, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=508, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=510, input_ops=[SramPrefetch(id=509, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# VectorOp(id=513, input_ops=[All2AllOp(id=512, input_ops=[MatMulOp(id=510, input_ops=[SramPrefetch(id=509, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)], num_gpus=8, data_size=1048576, weight_bits=16)], vector_op_type='moe_weighted_sum', vector_shape=[128, 4096], weight_bits=16)
# sim cycle: 1398192
# sim time ns: 764039
# trace path: trace/qwen3_moe/full_simulation.json
# trace event count: 353
# trace complete event count: 349
# trace complete event categories: {'compute': 185, 'prefetch': 162, 'transfer': 2}
# VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 4096], weight_bits=16)
# MatMulOp(id=3, input_ops=[SramPrefetch(id=2, input_ops=[], num_prefetch_pages=18432), VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 4096], weight_bits=16)], dim=(128, 4096, 9216), weight_bits=16)
# VectorOp(id=5, input_ops=[MatMulOp(id=3, input_ops=[SramPrefetch(id=2, input_ops=[], num_prefetch_pages=18432), VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 4096], weight_bits=16)], dim=(128, 4096, 9216), weight_bits=16)], vector_op_type='rms_norm', vector_shape=[128, 128], weight_bits=16)
# VectorOp(id=6, input_ops=[VectorOp(id=5, input_ops=[MatMulOp(id=3, input_ops=[SramPrefetch(id=2, input_ops=[], num_prefetch_pages=18432), VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 4096], weight_bits=16)], dim=(128, 4096, 9216), weight_bits=16)], vector_op_type='rms_norm', vector_shape=[128, 128], weight_bits=16)], vector_op_type='rms_norm', vector_shape=[128, 128], weight_bits=16)
# FlashAttnOp(id=8, input_ops=[SramPrefetch(id=7, input_ops=[], num_prefetch_pages=4608), VectorOp(id=6, input_ops=[VectorOp(id=5, input_ops=[MatMulOp(id=3, input_ops=[SramPrefetch(id=2, input_ops=[], num_prefetch_pages=18432), VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 4096], weight_bits=16)], dim=(128, 4096, 9216), weight_bits=16)], vector_op_type='rms_norm', vector_shape=[128, 128], weight_bits=16)], vector_op_type='rms_norm', vector_shape=[128, 128], weight_bits=16)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=11, input_ops=[SramPrefetch(id=10, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=14, input_ops=[SramPrefetch(id=13, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=17, input_ops=[SramPrefetch(id=16, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=20, input_ops=[SramPrefetch(id=19, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=23, input_ops=[SramPrefetch(id=22, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=26, input_ops=[SramPrefetch(id=25, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=29, input_ops=[SramPrefetch(id=28, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=32, input_ops=[SramPrefetch(id=31, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=35, input_ops=[SramPrefetch(id=34, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=38, input_ops=[SramPrefetch(id=37, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=41, input_ops=[SramPrefetch(id=40, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=44, input_ops=[SramPrefetch(id=43, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=47, input_ops=[SramPrefetch(id=46, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=50, input_ops=[SramPrefetch(id=49, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=53, input_ops=[SramPrefetch(id=52, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=56, input_ops=[SramPrefetch(id=55, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=59, input_ops=[SramPrefetch(id=58, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=62, input_ops=[SramPrefetch(id=61, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=65, input_ops=[SramPrefetch(id=64, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=68, input_ops=[SramPrefetch(id=67, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=71, input_ops=[SramPrefetch(id=70, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=74, input_ops=[SramPrefetch(id=73, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=77, input_ops=[SramPrefetch(id=76, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=80, input_ops=[SramPrefetch(id=79, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=83, input_ops=[SramPrefetch(id=82, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=86, input_ops=[SramPrefetch(id=85, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=89, input_ops=[SramPrefetch(id=88, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=92, input_ops=[SramPrefetch(id=91, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=95, input_ops=[SramPrefetch(id=94, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=98, input_ops=[SramPrefetch(id=97, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=101, input_ops=[SramPrefetch(id=100, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=104, input_ops=[SramPrefetch(id=103, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=107, input_ops=[SramPrefetch(id=106, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=110, input_ops=[SramPrefetch(id=109, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=113, input_ops=[SramPrefetch(id=112, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=116, input_ops=[SramPrefetch(id=115, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=119, input_ops=[SramPrefetch(id=118, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=122, input_ops=[SramPrefetch(id=121, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# FlashAttnOp(id=125, input_ops=[SramPrefetch(id=124, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(288, 16, 128, 128), sv_bmm_shape=(288, 16, 128, 128), softmax_shape=(4608, 128), weight_bits=16)
# ...
#  'type': 'SramPrefetchRelease'}
# {'id': 431,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'id': 432, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (64, 1536, 4096),
#  'id': 433,
#  'input_ops': [{'id': 432, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 434,
#  'input_ops': [{'id': 433, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 435, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (64, 4096, 3072),
#  'id': 436,
#  'input_ops': [{'id': 435, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 437,
#  'input_ops': [{'id': 436, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 438,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'id': 439, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (64, 1536, 4096),
#  'id': 440,
#  'input_ops': [{'id': 439, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 441,
#  'input_ops': [{'id': 440, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 442, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (64, 4096, 3072),
#  'id': 443,
#  'input_ops': [{'id': 442, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 444,
#  'input_ops': [{'id': 443, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 445,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'id': 446, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (64, 1536, 4096),
#  'id': 447,
#  'input_ops': [{'id': 446, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 448,
#  'input_ops': [{'id': 447, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 449, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (64, 4096, 3072),
#  'id': 450,
#  'input_ops': [{'id': 449, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 451,
#  'input_ops': [{'id': 450, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 452,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'id': 453, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (64, 1536, 4096),
#  'id': 454,
#  'input_ops': [{'id': 453, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 455,
#  'input_ops': [{'id': 454, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 456, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (64, 4096, 3072),
#  'id': 457,
#  'input_ops': [{'id': 456, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 458,
#  'input_ops': [{'id': 457, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 459,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'id': 460, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (64, 1536, 4096),
#  'id': 461,
#  'input_ops': [{'id': 460, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 462,
#  'input_ops': [{'id': 461, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 463, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (64, 4096, 3072),
#  'id': 464,
#  'input_ops': [{'id': 463, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 465,
#  'input_ops': [{'id': 464, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 466,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'id': 467, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (64, 1536, 4096),
#  'id': 468,
#  'input_ops': [{'id': 467, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 469,
#  'input_ops': [{'id': 468, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 470, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (64, 4096, 3072),
#  'id': 471,
#  'input_ops': [{'id': 470, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 472,
#  'input_ops': [{'id': 471, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 473,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'id': 474, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (64, 1536, 4096),
#  'id': 475,
#  'input_ops': [{'id': 474, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 476,
#  'input_ops': [{'id': 475, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 477, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (64, 4096, 3072),
#  'id': 478,
#  'input_ops': [{'id': 477, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 479,
#  'input_ops': [{'id': 478, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 480,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'id': 481, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (64, 1536, 4096),
#  'id': 482,
#  'input_ops': [{'id': 481, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 483,
#  'input_ops': [{'id': 482, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 484, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (64, 4096, 3072),
#  'id': 485,
#  'input_ops': [{'id': 484, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 486,
#  'input_ops': [{'id': 485, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 487,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'id': 488, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (64, 1536, 4096),
#  'id': 489,
#  'input_ops': [{'id': 488, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 490,
#  'input_ops': [{'id': 489, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 491, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (64, 4096, 3072),
#  'id': 492,
#  'input_ops': [{'id': 491, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 493,
#  'input_ops': [{'id': 492, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 494,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'id': 495, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (64, 1536, 4096),
#  'id': 496,
#  'input_ops': [{'id': 495, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 497,
#  'input_ops': [{'id': 496, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 498, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (64, 4096, 3072),
#  'id': 499,
#  'input_ops': [{'id': 498, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 500,
#  'input_ops': [{'id': 499, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 501,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'id': 502, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (64, 1536, 4096),
#  'id': 503,
#  'input_ops': [{'id': 502, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 504,
#  'input_ops': [{'id': 503, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 505, 'input_ops': [], 'num_prefetch_pages': 6144, 'type': 'SramPrefetch'}
# {'dim': (64, 4096, 3072),
#  'id': 506,
#  'input_ops': [{'id': 505, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 507,
#  'input_ops': [{'id': 506, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 508,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [64, 1536],
#  'weight_bits': 16}
# {'id': 509, 'input_ops': [], 'num_prefetch_pages': 3072, 'type': 'SramPrefetch'}
# {'dim': (64, 1536, 4096),
#  'id': 510,
#  'input_ops': [{'id': 509, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 511,
#  'input_ops': [{'id': 510, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'data_size': 1048576,
#  'id': 512,
#  'input_ops': [{'id': 510, 'type': 'MatMulOp'}],
#  'num_gpus': 8,
#  'type': 'All2AllOp',
#  'weight_bits': 16}
# {'id': 513,
#  'input_ops': [{'id': 512, 'type': 'All2AllOp'}],
#  'type': 'VectorOp',
#  'vector_op_type': 'moe_weighted_sum',
#  'vector_shape': [128, 4096],
#  'weight_bits': 16}
# MatMulOp(id=396, input_ops=[SramPrefetch(id=395, input_ops=[], num_prefetch_pages=256)], dim=(128, 4096, 128), weight_bits=16)
# VectorOp(id=398, input_ops=[], vector_op_type='moe_topk_router', vector_shape=[128, 128, 8], weight_bits=16)
# MatMulOp(id=401, input_ops=[SramPrefetch(id=400, input_ops=[], num_prefetch_pages=6144), All2AllOp(id=399, input_ops=[VectorOp(id=398, input_ops=[], vector_op_type='moe_topk_router', vector_shape=[128, 128, 8], weight_bits=16)], num_gpus=8, data_size=1048576, weight_bits=16)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=403, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=405, input_ops=[SramPrefetch(id=404, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=408, input_ops=[SramPrefetch(id=407, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=410, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=412, input_ops=[SramPrefetch(id=411, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=415, input_ops=[SramPrefetch(id=414, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=417, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=419, input_ops=[SramPrefetch(id=418, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=422, input_ops=[SramPrefetch(id=421, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=424, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=426, input_ops=[SramPrefetch(id=425, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=429, input_ops=[SramPrefetch(id=428, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=431, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=433, input_ops=[SramPrefetch(id=432, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=436, input_ops=[SramPrefetch(id=435, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=438, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=440, input_ops=[SramPrefetch(id=439, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=443, input_ops=[SramPrefetch(id=442, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=445, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=447, input_ops=[SramPrefetch(id=446, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=450, input_ops=[SramPrefetch(id=449, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=452, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=454, input_ops=[SramPrefetch(id=453, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=457, input_ops=[SramPrefetch(id=456, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=459, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=461, input_ops=[SramPrefetch(id=460, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=464, input_ops=[SramPrefetch(id=463, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=466, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=468, input_ops=[SramPrefetch(id=467, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=471, input_ops=[SramPrefetch(id=470, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=473, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=475, input_ops=[SramPrefetch(id=474, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=478, input_ops=[SramPrefetch(id=477, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=480, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=482, input_ops=[SramPrefetch(id=481, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=485, input_ops=[SramPrefetch(id=484, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=487, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=489, input_ops=[SramPrefetch(id=488, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=492, input_ops=[SramPrefetch(id=491, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=494, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=496, input_ops=[SramPrefetch(id=495, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=499, input_ops=[SramPrefetch(id=498, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=501, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=503, input_ops=[SramPrefetch(id=502, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# MatMulOp(id=506, input_ops=[SramPrefetch(id=505, input_ops=[], num_prefetch_pages=6144)], dim=(64, 4096, 3072), weight_bits=16)
# VectorOp(id=508, input_ops=[], vector_op_type='silu_mul', vector_shape=[64, 1536], weight_bits=16)
# MatMulOp(id=510, input_ops=[SramPrefetch(id=509, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)
# VectorOp(id=513, input_ops=[All2AllOp(id=512, input_ops=[MatMulOp(id=510, input_ops=[SramPrefetch(id=509, input_ops=[], num_prefetch_pages=3072)], dim=(64, 1536, 4096), weight_bits=16)], num_gpus=8, data_size=1048576, weight_bits=16)], vector_op_type='moe_weighted_sum', vector_shape=[128, 4096], weight_bits=16)
# sim cycle: 349329
# sim time ns: 190890
# trace path: trace/qwen3_moe/node_011_mlp_call_module.json
# trace event count: 89
# trace complete event count: 85
# trace complete event categories: {'compute': 51, 'prefetch': 32, 'transfer': 2}
# ========================================================================================================================
# node index: 12
# node info:
# {'node_name': 'add_1',
#  'node_op': 'call_function',
#  'node_target': '<built-in function add>'}
# macro op count: 0
# macro op type summary: {}
# macro op details:
# simulation skipped because this node produced no macro ops

# %%
node_sim_results
# Out:
# [{'node_name': 'hidden_states',
#   'node_op': 'placeholder',
#   'node_target': 'hidden_states',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []},
#  {'node_name': 'input_layernorm',
#   'node_op': 'call_module',
#   'node_target': 'input_layernorm',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 65,
#   'sim_time_ns': 35,
#   'trace_path': 'trace/qwen3_moe/node_001_input_layernorm_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 1,
#     'input_ops': [],
#     'vector_op_type': 'rms_norm',
#     'vector_shape': [128, 4096],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'self_attn_qkv_proj',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.qkv_proj',
#   'macro_op_count': 3,
#   'macro_op_types': ['SramPrefetch', 'MatMulOp', 'SramPrefetchRelease'],
#   'sim_cycle': 30589,
#   'sim_time_ns': 16715,
#   'trace_path': 'trace/qwen3_moe/node_002_self_attn_qkv_proj_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 2,
#     'input_ops': [],
#     'num_prefetch_pages': 18432,
#     'type': 'SramPrefetch'},
#    {'id': 3,
#     'input_ops': [{'id': 2, 'type': 'SramPrefetch'}],
#     'dim': (128, 4096, 9216),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 4,
#     'input_ops': [{'id': 3, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'}]},
#  {'node_name': 'self_attn_q_norm',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.q_norm',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 6,
#   'sim_time_ns': 3,
#   'trace_path': 'trace/qwen3_moe/node_003_self_attn_q_norm_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 5,
#     'input_ops': [],
#     'vector_op_type': 'rms_norm',
#     'vector_shape': [128, 128],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'self_attn_k_norm',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.k_norm',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 6,
#   'sim_time_ns': 3,
#   'trace_path': 'trace/qwen3_moe/node_004_self_attn_k_norm_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 6,
#     'input_ops': [],
#     'vector_op_type': 'rms_norm',
#     'vector_shape': [128, 128],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'self_attn__dummy_positions',
#   'node_op': 'get_attr',
#   'node_target': 'self_attn._dummy_positions',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []},
#  {'node_name': 'self_attn_rotary_emb',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.rotary_emb',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []},
#  {'node_name': 'self_attn_attn',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.attn',
#   'macro_op_count': 384,
#   'macro_op_types': ['SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease'],
#   'sim_cycle': 990601,
#   'sim_time_ns': 541312,
#   'trace_path': 'trace/qwen3_moe/node_007_self_attn_attn_call_module.json',
#   'trace_event_count': 259,
#   'trace_complete_event_count': 255,
#   'trace_complete_event_categories': {'prefetch': 127, 'compute': 128},
#   'macro_ops': [{'id': 7,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 8,
#     'input_ops': [{'id': 7, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 9,
#     'input_ops': [{'id': 8, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 10,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 11,
#     'input_ops': [{'id': 10, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 12,
#     'input_ops': [{'id': 11, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 13,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 14,
#     'input_ops': [{'id': 13, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 15,
#     'input_ops': [{'id': 14, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 16,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 17,
#     'input_ops': [{'id': 16, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 18,
#     'input_ops': [{'id': 17, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 19,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 20,
#     'input_ops': [{'id': 19, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 21,
#     'input_ops': [{'id': 20, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 22,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 23,
#     'input_ops': [{'id': 22, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 24,
#     'input_ops': [{'id': 23, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 25,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 26,
#     'input_ops': [{'id': 25, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 27,
#     'input_ops': [{'id': 26, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 28,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 29,
#     'input_ops': [{'id': 28, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 30,
#     'input_ops': [{'id': 29, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 31,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 32,
#     'input_ops': [{'id': 31, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 33,
#     'input_ops': [{'id': 32, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 34,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 35,
#     'input_ops': [{'id': 34, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 36,
#     'input_ops': [{'id': 35, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 37,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 38,
#     'input_ops': [{'id': 37, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 39,
#     'input_ops': [{'id': 38, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 40,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 41,
#     'input_ops': [{'id': 40, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 42,
#     'input_ops': [{'id': 41, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 43,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 44,
#     'input_ops': [{'id': 43, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 45,
#     'input_ops': [{'id': 44, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 46,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 47,
#     'input_ops': [{'id': 46, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 48,
#     'input_ops': [{'id': 47, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 49,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 50,
#     'input_ops': [{'id': 49, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 51,
#     'input_ops': [{'id': 50, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 52,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 53,
#     'input_ops': [{'id': 52, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 54,
#     'input_ops': [{'id': 53, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 55,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 56,
#     'input_ops': [{'id': 55, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 57,
#     'input_ops': [{'id': 56, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 58,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 59,
#     'input_ops': [{'id': 58, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 60,
#     'input_ops': [{'id': 59, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 61,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 62,
#     'input_ops': [{'id': 61, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 63,
#     'input_ops': [{'id': 62, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 64,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 65,
#     'input_ops': [{'id': 64, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 66,
#     'input_ops': [{'id': 65, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 67,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 68,
#     'input_ops': [{'id': 67, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 69,
#     'input_ops': [{'id': 68, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 70,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 71,
#     'input_ops': [{'id': 70, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 72,
#     'input_ops': [{'id': 71, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 73,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 74,
#     'input_ops': [{'id': 73, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 75,
#     'input_ops': [{'id': 74, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 76,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 77,
#     'input_ops': [{'id': 76, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 78,
#     'input_ops': [{'id': 77, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 79,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 80,
#     'input_ops': [{'id': 79, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 81,
#     'input_ops': [{'id': 80, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 82,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 83,
#     'input_ops': [{'id': 82, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 84,
#     'input_ops': [{'id': 83, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 85,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 86,
#     'input_ops': [{'id': 85, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 87,
#     'input_ops': [{'id': 86, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 88,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 89,
#     'input_ops': [{'id': 88, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 90,
#     'input_ops': [{'id': 89, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 91,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 92,
#     'input_ops': [{'id': 91, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 93,
#     'input_ops': [{'id': 92, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 94,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 95,
#     'input_ops': [{'id': 94, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 96,
#     'input_ops': [{'id': 95, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 97,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 98,
#     'input_ops': [{'id': 97, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 99,
#     'input_ops': [{'id': 98, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 100,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 101,
#     'input_ops': [{'id': 100, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 102,
#     'input_ops': [{'id': 101, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 103,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 104,
#     'input_ops': [{'id': 103, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 105,
#     'input_ops': [{'id': 104, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 106,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 107,
#     'input_ops': [{'id': 106, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 108,
#     'input_ops': [{'id': 107, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 109,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 110,
#     'input_ops': [{'id': 109, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 111,
#     'input_ops': [{'id': 110, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 112,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 113,
#     'input_ops': [{'id': 112, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 114,
#     'input_ops': [{'id': 113, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 115,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 116,
#     'input_ops': [{'id': 115, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 117,
#     'input_ops': [{'id': 116, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 118,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 119,
#     'input_ops': [{'id': 118, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 120,
#     'input_ops': [{'id': 119, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 121,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 122,
#     'input_ops': [{'id': 121, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 123,
#     'input_ops': [{'id': 122, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 124,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 125,
#     'input_ops': [{'id': 124, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 126,
#     'input_ops': [{'id': 125, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 127,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 128,
#     'input_ops': [{'id': 127, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 129,
#     'input_ops': [{'id': 128, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 130,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 131,
#     'input_ops': [{'id': 130, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 132,
#     'input_ops': [{'id': 131, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 133,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 134,
#     'input_ops': [{'id': 133, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 135,
#     'input_ops': [{'id': 134, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 136,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 137,
#     'input_ops': [{'id': 136, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 138,
#     'input_ops': [{'id': 137, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 139,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 140,
#     'input_ops': [{'id': 139, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 141,
#     'input_ops': [{'id': 140, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 142,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 143,
#     'input_ops': [{'id': 142, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 144,
#     'input_ops': [{'id': 143, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 145,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 146,
#     'input_ops': [{'id': 145, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 147,
#     'input_ops': [{'id': 146, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 148,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 149,
#     'input_ops': [{'id': 148, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 150,
#     'input_ops': [{'id': 149, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 151,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 152,
#     'input_ops': [{'id': 151, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 153,
#     'input_ops': [{'id': 152, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 154,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 155,
#     'input_ops': [{'id': 154, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 156,
#     'input_ops': [{'id': 155, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 157,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 158,
#     'input_ops': [{'id': 157, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 159,
#     'input_ops': [{'id': 158, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 160,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 161,
#     'input_ops': [{'id': 160, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 162,
#     'input_ops': [{'id': 161, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 163,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 164,
#     'input_ops': [{'id': 163, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 165,
#     'input_ops': [{'id': 164, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 166,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 167,
#     'input_ops': [{'id': 166, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 168,
#     'input_ops': [{'id': 167, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 169,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 170,
#     'input_ops': [{'id': 169, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 171,
#     'input_ops': [{'id': 170, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 172,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 173,
#     'input_ops': [{'id': 172, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 174,
#     'input_ops': [{'id': 173, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 175,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 176,
#     'input_ops': [{'id': 175, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 177,
#     'input_ops': [{'id': 176, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 178,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 179,
#     'input_ops': [{'id': 178, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 180,
#     'input_ops': [{'id': 179, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 181,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 182,
#     'input_ops': [{'id': 181, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 183,
#     'input_ops': [{'id': 182, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 184,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 185,
#     'input_ops': [{'id': 184, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 186,
#     'input_ops': [{'id': 185, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 187,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 188,
#     'input_ops': [{'id': 187, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 189,
#     'input_ops': [{'id': 188, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 190,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 191,
#     'input_ops': [{'id': 190, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 192,
#     'input_ops': [{'id': 191, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 193,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 194,
#     'input_ops': [{'id': 193, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 195,
#     'input_ops': [{'id': 194, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 196,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 197,
#     'input_ops': [{'id': 196, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 198,
#     'input_ops': [{'id': 197, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 199,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 200,
#     'input_ops': [{'id': 199, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 201,
#     'input_ops': [{'id': 200, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 202,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 203,
#     'input_ops': [{'id': 202, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 204,
#     'input_ops': [{'id': 203, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 205,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 206,
#     'input_ops': [{'id': 205, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 207,
#     'input_ops': [{'id': 206, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 208,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 209,
#     'input_ops': [{'id': 208, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 210,
#     'input_ops': [{'id': 209, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 211,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 212,
#     'input_ops': [{'id': 211, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 213,
#     'input_ops': [{'id': 212, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 214,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 215,
#     'input_ops': [{'id': 214, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 216,
#     'input_ops': [{'id': 215, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 217,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 218,
#     'input_ops': [{'id': 217, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 219,
#     'input_ops': [{'id': 218, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 220,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 221,
#     'input_ops': [{'id': 220, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 222,
#     'input_ops': [{'id': 221, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 223,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 224,
#     'input_ops': [{'id': 223, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 225,
#     'input_ops': [{'id': 224, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 226,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 227,
#     'input_ops': [{'id': 226, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 228,
#     'input_ops': [{'id': 227, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 229,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 230,
#     'input_ops': [{'id': 229, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 231,
#     'input_ops': [{'id': 230, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 232,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 233,
#     'input_ops': [{'id': 232, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 234,
#     'input_ops': [{'id': 233, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 235,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 236,
#     'input_ops': [{'id': 235, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 237,
#     'input_ops': [{'id': 236, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 238,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 239,
#     'input_ops': [{'id': 238, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 240,
#     'input_ops': [{'id': 239, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 241,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 242,
#     'input_ops': [{'id': 241, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 243,
#     'input_ops': [{'id': 242, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 244,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 245,
#     'input_ops': [{'id': 244, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 246,
#     'input_ops': [{'id': 245, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 247,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 248,
#     'input_ops': [{'id': 247, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 249,
#     'input_ops': [{'id': 248, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 250,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 251,
#     'input_ops': [{'id': 250, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (288, 16, 128, 128),
#     'sv_bmm_shape': (288, 16, 128, 128),
#     'softmax_shape': (4608, 128),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 252,
#     'input_ops': [{'id': 251, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 253,
# ...
#    'VectorOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'VectorOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'VectorOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'VectorOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'VectorOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'VectorOp',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'All2AllOp',
#    'VectorOp'],
#   'sim_cycle': 349329,
#   'sim_time_ns': 190890,
#   'trace_path': 'trace/qwen3_moe/node_011_mlp_call_module.json',
#   'trace_event_count': 89,
#   'trace_complete_event_count': 85,
#   'trace_complete_event_categories': {'compute': 51,
#    'prefetch': 32,
#    'transfer': 2},
#   'macro_ops': [{'id': 395,
#     'input_ops': [],
#     'num_prefetch_pages': 256,
#     'type': 'SramPrefetch'},
#    {'id': 396,
#     'input_ops': [{'id': 395, 'type': 'SramPrefetch'}],
#     'dim': (128, 4096, 128),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 397,
#     'input_ops': [{'id': 396, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 398,
#     'input_ops': [],
#     'vector_op_type': 'moe_topk_router',
#     'vector_shape': [128, 128, 8],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 399,
#     'input_ops': [{'id': 398, 'type': 'VectorOp'}],
#     'num_gpus': 8,
#     'data_size': 1048576,
#     'weight_bits': 16,
#     'type': 'All2AllOp'},
#    {'id': 400,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 401,
#     'input_ops': [{'id': 400, 'type': 'SramPrefetch'},
#      {'id': 399, 'type': 'All2AllOp'}],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 402,
#     'input_ops': [{'id': 401, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 403,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 404,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 405,
#     'input_ops': [{'id': 404, 'type': 'SramPrefetch'}],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 406,
#     'input_ops': [{'id': 405, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 407,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 408,
#     'input_ops': [{'id': 407, 'type': 'SramPrefetch'}],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 409,
#     'input_ops': [{'id': 408, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 410,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 411,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 412,
#     'input_ops': [{'id': 411, 'type': 'SramPrefetch'}],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 413,
#     'input_ops': [{'id': 412, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 414,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 415,
#     'input_ops': [{'id': 414, 'type': 'SramPrefetch'}],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 416,
#     'input_ops': [{'id': 415, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 417,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 418,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 419,
#     'input_ops': [{'id': 418, 'type': 'SramPrefetch'}],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 420,
#     'input_ops': [{'id': 419, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 421,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 422,
#     'input_ops': [{'id': 421, 'type': 'SramPrefetch'}],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 423,
#     'input_ops': [{'id': 422, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 424,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 425,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 426,
#     'input_ops': [{'id': 425, 'type': 'SramPrefetch'}],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 427,
#     'input_ops': [{'id': 426, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 428,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 429,
#     'input_ops': [{'id': 428, 'type': 'SramPrefetch'}],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 430,
#     'input_ops': [{'id': 429, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 431,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 432,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 433,
#     'input_ops': [{'id': 432, 'type': 'SramPrefetch'}],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 434,
#     'input_ops': [{'id': 433, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 435,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 436,
#     'input_ops': [{'id': 435, 'type': 'SramPrefetch'}],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 437,
#     'input_ops': [{'id': 436, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 438,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 439,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 440,
#     'input_ops': [{'id': 439, 'type': 'SramPrefetch'}],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 441,
#     'input_ops': [{'id': 440, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 442,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 443,
#     'input_ops': [{'id': 442, 'type': 'SramPrefetch'}],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 444,
#     'input_ops': [{'id': 443, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 445,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 446,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 447,
#     'input_ops': [{'id': 446, 'type': 'SramPrefetch'}],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 448,
#     'input_ops': [{'id': 447, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 449,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 450,
#     'input_ops': [{'id': 449, 'type': 'SramPrefetch'}],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 451,
#     'input_ops': [{'id': 450, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 452,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 453,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 454,
#     'input_ops': [{'id': 453, 'type': 'SramPrefetch'}],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 455,
#     'input_ops': [{'id': 454, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 456,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 457,
#     'input_ops': [{'id': 456, 'type': 'SramPrefetch'}],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 458,
#     'input_ops': [{'id': 457, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 459,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 460,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 461,
#     'input_ops': [{'id': 460, 'type': 'SramPrefetch'}],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 462,
#     'input_ops': [{'id': 461, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 463,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 464,
#     'input_ops': [{'id': 463, 'type': 'SramPrefetch'}],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 465,
#     'input_ops': [{'id': 464, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 466,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 467,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 468,
#     'input_ops': [{'id': 467, 'type': 'SramPrefetch'}],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 469,
#     'input_ops': [{'id': 468, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 470,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 471,
#     'input_ops': [{'id': 470, 'type': 'SramPrefetch'}],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 472,
#     'input_ops': [{'id': 471, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 473,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 474,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 475,
#     'input_ops': [{'id': 474, 'type': 'SramPrefetch'}],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 476,
#     'input_ops': [{'id': 475, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 477,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 478,
#     'input_ops': [{'id': 477, 'type': 'SramPrefetch'}],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 479,
#     'input_ops': [{'id': 478, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 480,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 481,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 482,
#     'input_ops': [{'id': 481, 'type': 'SramPrefetch'}],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 483,
#     'input_ops': [{'id': 482, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 484,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 485,
#     'input_ops': [{'id': 484, 'type': 'SramPrefetch'}],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 486,
#     'input_ops': [{'id': 485, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 487,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 488,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 489,
#     'input_ops': [{'id': 488, 'type': 'SramPrefetch'}],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 490,
#     'input_ops': [{'id': 489, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 491,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 492,
#     'input_ops': [{'id': 491, 'type': 'SramPrefetch'}],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 493,
#     'input_ops': [{'id': 492, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 494,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 495,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 496,
#     'input_ops': [{'id': 495, 'type': 'SramPrefetch'}],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 497,
#     'input_ops': [{'id': 496, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 498,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 499,
#     'input_ops': [{'id': 498, 'type': 'SramPrefetch'}],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 500,
#     'input_ops': [{'id': 499, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 501,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 502,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 503,
#     'input_ops': [{'id': 502, 'type': 'SramPrefetch'}],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 504,
#     'input_ops': [{'id': 503, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 505,
#     'input_ops': [],
#     'num_prefetch_pages': 6144,
#     'type': 'SramPrefetch'},
#    {'id': 506,
#     'input_ops': [{'id': 505, 'type': 'SramPrefetch'}],
#     'dim': (64, 4096, 3072),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 507,
#     'input_ops': [{'id': 506, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 508,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [64, 1536],
#     'weight_bits': 16,
#     'type': 'VectorOp'},
#    {'id': 509,
#     'input_ops': [],
#     'num_prefetch_pages': 3072,
#     'type': 'SramPrefetch'},
#    {'id': 510,
#     'input_ops': [{'id': 509, 'type': 'SramPrefetch'}],
#     'dim': (64, 1536, 4096),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 511,
#     'input_ops': [{'id': 510, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 512,
#     'input_ops': [{'id': 510, 'type': 'MatMulOp'}],
#     'num_gpus': 8,
#     'data_size': 1048576,
#     'weight_bits': 16,
#     'type': 'All2AllOp'},
#    {'id': 513,
#     'input_ops': [{'id': 512, 'type': 'All2AllOp'}],
#     'vector_op_type': 'moe_weighted_sum',
#     'vector_shape': [128, 4096],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'add_1',
#   'node_op': 'call_function',
#   'node_target': '<built-in function add>',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []}]

# %%
non_empty_node_results = [result for result in node_sim_results if result["macro_op_count"] > 0]
empty_node_results = [result for result in node_sim_results if result["macro_op_count"] == 0]

assert len(node_sim_results) == len(all_graph_nodes)
assert full_sim_result["cycle"] > 0
assert full_sim_result["time_ns"] > 0
assert full_sim_result["trace_path"] is not None
assert full_sim_result["trace_event_count"] is not None
assert full_sim_result["trace_complete_event_count"] is not None
assert non_empty_node_results
assert all(result["sim_cycle"] is not None for result in non_empty_node_results)
assert all(result["sim_time_ns"] is not None for result in non_empty_node_results)
assert all(result["trace_path"] is not None for result in non_empty_node_results)
assert all(result["trace_event_count"] is not None for result in non_empty_node_results)
assert all(result["trace_complete_event_count"] is not None for result in non_empty_node_results)
assert all(result["sim_cycle"] is None for result in empty_node_results)
assert all(result["trace_path"] is None for result in empty_node_results)

full_sim_summary = {
    "macro_op_count": len(macro_op_list),
    "macro_op_type_summary": dict(macro_summary(macro_op_list)),
    "sim_cycle": full_sim_result["cycle"],
    "sim_time_ns": full_sim_result["time_ns"],
    "trace_path": full_sim_result["trace_path"],
    "trace_event_count": full_sim_result["trace_event_count"],
    "trace_complete_event_count": full_sim_result["trace_complete_event_count"],
    "trace_complete_event_categories": full_sim_result[
        "trace_complete_event_categories"
    ],
}
run_sim_summary = {
    "layer_latency_ns": full_run_sim_result.layer_latency_ns,
    "model_latency_ns": full_run_sim_result.model_latency_ns,
    "model_throughput": full_run_sim_result.model_throughput,
    "kv_cache_total_size_GB": full_run_sim_result.kv_cache_total_size_GB,
}

summary_rows = [
    {
        "node_name": result["node_name"],
        "node_op": result["node_op"],
        "node_target": result["node_target"],
        "macro_op_count": result["macro_op_count"],
        "macro_op_types": result["macro_op_types"],
        "sim_cycle": result["sim_cycle"],
        "sim_time_ns": result["sim_time_ns"],
        "trace_path": result["trace_path"],
        "trace_event_count": result["trace_event_count"],
        "trace_complete_event_count": result["trace_complete_event_count"],
        "trace_complete_event_categories": result["trace_complete_event_categories"],
    }
    for result in node_sim_results
]

{
    "full_simulation": full_sim_summary,
    "run_simulation": run_sim_summary,
    "node_simulations": summary_rows,
}
# Out:
# {'full_simulation': {'macro_op_count': 513,
#   'macro_op_type_summary': {'VectorOp': 22,
#    'SramPrefetch': 163,
#    'MatMulOp': 35,
#    'SramPrefetchRelease': 163,
#    'FlashAttnOp': 128,
#    'All2AllOp': 2},
#   'sim_cycle': 1398192,
#   'sim_time_ns': 764039,
#   'trace_path': 'trace/qwen3_moe/full_simulation.json',
#   'trace_event_count': 353,
#   'trace_complete_event_count': 349,
#   'trace_complete_event_categories': {'compute': 185,
#    'prefetch': 162,
#    'transfer': 2}},
#  'run_simulation': {'layer_latency_ns': 764039,
#   'model_latency_ns': 71819666,
#   'model_throughput': 14257.933196180556,
#   'kv_cache_total_size_GB': 1692.0},
#  'node_simulations': [{'node_name': 'hidden_states',
#    'node_op': 'placeholder',
#    'node_target': 'hidden_states',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None},
#   {'node_name': 'input_layernorm',
#    'node_op': 'call_module',
#    'node_target': 'input_layernorm',
#    'macro_op_count': 1,
#    'macro_op_types': ['VectorOp'],
#    'sim_cycle': 65,
#    'sim_time_ns': 35,
#    'trace_path': 'trace/qwen3_moe/node_001_input_layernorm_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'self_attn_qkv_proj',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.qkv_proj',
#    'macro_op_count': 3,
#    'macro_op_types': ['SramPrefetch', 'MatMulOp', 'SramPrefetchRelease'],
#    'sim_cycle': 30589,
#    'sim_time_ns': 16715,
#    'trace_path': 'trace/qwen3_moe/node_002_self_attn_qkv_proj_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'self_attn_q_norm',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.q_norm',
#    'macro_op_count': 1,
#    'macro_op_types': ['VectorOp'],
#    'sim_cycle': 6,
#    'sim_time_ns': 3,
#    'trace_path': 'trace/qwen3_moe/node_003_self_attn_q_norm_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'self_attn_k_norm',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.k_norm',
#    'macro_op_count': 1,
#    'macro_op_types': ['VectorOp'],
#    'sim_cycle': 6,
#    'sim_time_ns': 3,
#    'trace_path': 'trace/qwen3_moe/node_004_self_attn_k_norm_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'self_attn__dummy_positions',
#    'node_op': 'get_attr',
#    'node_target': 'self_attn._dummy_positions',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None},
#   {'node_name': 'self_attn_rotary_emb',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.rotary_emb',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None},
#   {'node_name': 'self_attn_attn',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.attn',
#    'macro_op_count': 384,
#    'macro_op_types': ['SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease'],
#    'sim_cycle': 990601,
#    'sim_time_ns': 541312,
#    'trace_path': 'trace/qwen3_moe/node_007_self_attn_attn_call_module.json',
#    'trace_event_count': 259,
#    'trace_complete_event_count': 255,
#    'trace_complete_event_categories': {'prefetch': 127, 'compute': 128}},
#   {'node_name': 'self_attn_o_proj',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.o_proj',
#    'macro_op_count': 3,
#    'macro_op_types': ['SramPrefetch', 'MatMulOp', 'SramPrefetchRelease'],
#    'sim_cycle': 27535,
#    'sim_time_ns': 15046,
#    'trace_path': 'trace/qwen3_moe/node_008_self_attn_o_proj_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'add',
#    'node_op': 'call_function',
#    'node_target': '<built-in function add>',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None},
#   {'node_name': 'post_attention_layernorm',
#    'node_op': 'call_module',
#    'node_target': 'post_attention_layernorm',
#    'macro_op_count': 1,
#    'macro_op_types': ['VectorOp'],
#    'sim_cycle': 65,
#    'sim_time_ns': 35,
#    'trace_path': 'trace/qwen3_moe/node_010_post_attention_layernorm_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'mlp',
#    'node_op': 'call_module',
#    'node_target': 'mlp',
#    'macro_op_count': 119,
#    'macro_op_types': ['SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'All2AllOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'VectorOp',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'All2AllOp',
#     'VectorOp'],
#    'sim_cycle': 349329,
#    'sim_time_ns': 190890,
#    'trace_path': 'trace/qwen3_moe/node_011_mlp_call_module.json',
#    'trace_event_count': 89,
#    'trace_complete_event_count': 85,
#    'trace_complete_event_categories': {'compute': 51,
#     'prefetch': 32,
#     'transfer': 2}},
#   {'node_name': 'add_1',
#    'node_op': 'call_function',
#    'node_target': '<built-in function add>',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None}]}

# %%
print(kv_cache_state)
# Out:
# KVCacheState(total_kv_cache_size_per_layer=19327352832, kv_block_size_tokens=128, num_kv_blocks=73728, num_nand_pages_per_layer=4718592, num_hyper_pages_per_layer=1024, is_imbalance=False)
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 302, in dispatch_control
#     await self.process_control(msg)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 308, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 302, in dispatch_control
#     await self.process_control(msg)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 308, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 302, in dispatch_control
#     await self.process_control(msg)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 308, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 302, in dispatch_control
#     await self.process_control(msg)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 308, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 302, in dispatch_control
#     await self.process_control(msg)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 308, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 302, in dispatch_control
#     await self.process_control(msg)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 308, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 302, in dispatch_control
#     await self.process_control(msg)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 308, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 302, in dispatch_control
#     await self.process_control(msg)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 308, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 302, in dispatch_control
#     await self.process_control(msg)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 308, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 302, in dispatch_control
#     await self.process_control(msg)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 308, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 302, in dispatch_control
#     await self.process_control(msg)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 308, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 302, in dispatch_control
#     await self.process_control(msg)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 308, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/machine/lib/python3.12/site-packages/jupyter_client/session.py", line 998, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
