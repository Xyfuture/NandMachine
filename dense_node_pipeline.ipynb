# %% [markdown]
# # Node-Level Frontend Pipeline For Llama 405B
#
# 实现 Llama 405B decoder layer 的最小前端全流程，并在 code gen pass 之后按 node 读取 `marco_op_list`，对每个 node 单独运行硬件仿真，同时对完整 `macro_op_list` 运行一次整体硬件仿真，并把 perf trace 输出到 `trace/dense/` 目录。

# %% [markdown]
# ## 流程
# - 加载 `llama-405B` model card 并初始化 `LlamaModelConfig`
# - 初始化 `NandConfig`、`InferenceConfig`，支持配置 `TP_SIZE`
# - 初始化 `LlamaDecoderLayer`
# - 使用 `NxTracer` trace 得到计算图
# - 运行 `NormalizePass` 获得简化图
# - 用 `build_kv_cache_state` 构造 `KVCacheState`
# - 构造 `NxGraphMeta` 并写入 `graph.meta`
# - 运行 `CodeGenPass`，收集全局和 node 级别的 `marco_op_list`
# - 对完整 `macro_op_list` 运行一次硬件仿真，并把完整 trace 保存到 `trace/dense/full_simulation.json`
# - 对每个 node 单独运行硬件仿真，并把 node trace 保存到 `trace/dense/` 目录
# - 汇总完整仿真和 node 级别的 macro op、时延和 trace 信息

# %%
import json
import logging
import re
from collections import Counter
from dataclasses import fields, is_dataclass
from math import ceil
from pathlib import Path
from pprint import pprint

import torch
from Desim import SimSession
from torch.fx import GraphModule

from nandmachine.commands.macro import AllReduceOp, FlashAttnOp, MacroOp, MatMulOp, VectorOp
from nandmachine.config.config import NandConfig
from nandmachine.config.hardware_config import get_device_or_raise
from nandmachine.config.inference_config import DenseParallelConfig, InferenceConfig
from nandmachine.config.model_config import LlamaModelConfig
from nandmachine.frontend.core.graph.base import NxGraphMeta, NxTracer
from nandmachine.frontend.core.passes.cod_gen import CodeGenPass
from nandmachine.frontend.core.passes.normalize import NormalizePass
from nandmachine.frontend.network.llama import LlamaDecoderLayer
from nandmachine.frontend.utlis import build_kv_cache_state
from nandmachine.simulator.hardware.xpu import xPU

MODEL_CARD_PATH = Path("model_cards/llama-405B.json")
DEVICE_NAME = "H100_SXM"
COMPILE_MODE = "heuristic-GPU"
TP_SIZE = 8
HBM_BANDWIDTH_GBPS = 3350
TRACE_DIR = Path("trace/dense")
FULL_TRACE_FILE_NAME = "full_simulation.json"

assert MODEL_CARD_PATH.exists(), MODEL_CARD_PATH
assert TP_SIZE > 0, TP_SIZE


def node_summary(graph_module: GraphModule) -> list[tuple[str, str, str]]:
    return [(node.name, node.op, str(node.target)) for node in graph_module.graph.nodes]


def macro_summary(macro_op_list: list[object]) -> Counter:
    return Counter(type(op).__name__ for op in macro_op_list)


def node_info(node: torch.fx.Node) -> dict[str, object]:
    return {
        "node_name": node.name,
        "node_op": node.op,
        "node_target": str(node.target),
    }


def _serialize_value(value: object) -> object:
    if isinstance(value, MacroOp):
        return {
            "id": value.id,
            "type": type(value).__name__,
        }
    if isinstance(value, list):
        return [_serialize_value(item) for item in value]
    if isinstance(value, tuple):
        return tuple(_serialize_value(item) for item in value)
    return value


def macro_info(op: MacroOp) -> dict[str, object]:
    assert is_dataclass(op), type(op)
    payload = {field.name: _serialize_value(getattr(op, field.name)) for field in fields(op)}
    payload["type"] = type(op).__name__
    return payload


def _sanitize_trace_name(raw_name: str) -> str:
    return re.sub(r"[^0-9A-Za-z._-]+", "_", raw_name).strip("._")


def trace_file_path(node_index: int, node: torch.fx.Node) -> Path:
    file_name = _sanitize_trace_name(f"node_{node_index:03d}_{node.name}_{node.op}")
    return TRACE_DIR / f"{file_name}.json"


def full_trace_file_path() -> Path:
    return TRACE_DIR / FULL_TRACE_FILE_NAME


def run_macro_ops_with_trace(
    nand_config: NandConfig,
    commands: list[MacroOp],
    *,
    trace_path: Path,
    device_name: str,
    compile_mode: str,
    hbm_bandwidth_GBps: float,
) -> dict[str, object]:
    SimSession.reset()
    SimSession.init()

    hbm_bandwidth_bytes_per_sec = hbm_bandwidth_GBps * 10**9

    sim_xpu = xPU(
        nand_config,
        hbm_bandwidth_bytes_per_sec=hbm_bandwidth_bytes_per_sec,
        device_name=device_name,
        compile_mode=compile_mode,
        enable_trace=True,
    )
    sim_xpu.load_command(commands)
    SimSession.scheduler.run()

    final_time_ns = int(SimSession.sim_time.cycle)
    device = get_device_or_raise(device_name)
    final_cycle = ceil(final_time_ns * device.compute_module.clock_freq / 1e9)

    trace_path.parent.mkdir(parents=True, exist_ok=True)
    saved_trace_path = Path(sim_xpu.save_trace_file(str(trace_path)))

    tracer = sim_xpu.tracer
    assert tracer is not None
    complete_events = [event for event in tracer._events if event["ph"] == "X"]

    return {
        "cycle": final_cycle,
        "time_ns": final_time_ns,
        "trace_path": str(saved_trace_path),
        "trace_event_count": len(tracer._events),
        "trace_complete_event_count": len(complete_events),
        "trace_complete_event_categories": dict(
            Counter(event["cat"] for event in complete_events)
        ),
    }

# %%
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
)

model_config = LlamaModelConfig.from_dict(json.loads(MODEL_CARD_PATH.read_text()))
nand_config = NandConfig(
    num_channels=6 * 8,
    num_plane=96,
    num_block=16, # 没什么用的参数
    num_pages=16, # 没什么用的参数
    tRead=4000, # ns
    tWrite=4000 * 10, # ns
    tErase=4000 * 100, # ns
    page_size=4, # KB
    sram_threshold=1024 * 80,  # KB  --  可以考虑之后统一改成 Bytes，统一所有的单位
)
parallel_config = DenseParallelConfig(
    num_ranks=TP_SIZE,
    tp_size=TP_SIZE,
    dp_size=1,
)
inference_config = InferenceConfig(
    batch_size=128, # 总的 batch size
    input_sequence_length=8096,
    output_sequence_length=1024,
    weight_bits=16,
    activation_bits=16,
    kv_cache_bits=16,
    kv_block_size_bytes=1024 * 256,  # bytes
    memory_backend="nand",
    parallel_config=parallel_config,
)
kv_cache_state = build_kv_cache_state(nand_config, model_config, inference_config)
graph_meta = NxGraphMeta(
    nand_config=nand_config,
    model_config=model_config,
    inference_config=inference_config,
    kv_cache_state=kv_cache_state,
)
simulator_config = {
    "device_name": DEVICE_NAME,
    "compile_mode": COMPILE_MODE,
    "hbm_bandwidth_GBps": HBM_BANDWIDTH_GBPS,
}
runtime_simulator_config = {
    "device_name": simulator_config["device_name"],
    "compile_mode": simulator_config["compile_mode"],
    "hbm_bandwidth_GBps": simulator_config["hbm_bandwidth_GBps"],
}
TRACE_DIR.mkdir(parents=True, exist_ok=True)

print("HBM bandwidth (GBps):", HBM_BANDWIDTH_GBPS)
print("trace output dir:", TRACE_DIR)
print("full simulation trace path:", full_trace_file_path())
# Out:
# HBM bandwidth (GBps): 3350
# trace output dir: trace/dense
# full simulation trace path: trace/dense/full_simulation.json

# %%
with torch.device("meta"):
    model = LlamaDecoderLayer(model_config, tp_size=TP_SIZE)
    graph = NxTracer().trace(model)
    graph_module = GraphModule(model, graph)

NormalizePass().transform(graph_module)
graph_module.graph.meta = {CodeGenPass.GRAPH_META_KEY: graph_meta}
CodeGenPass().transform(graph_module)

all_graph_nodes = list(graph_module.graph.nodes)
all_node_infos = [node_info(node) for node in all_graph_nodes]
node_count_with_macro_ops = sum(1 for node in all_graph_nodes if "marco_op_list" in node.meta)
macro_op_list = graph_module.graph.meta[CodeGenPass.MACRO_OP_LIST_META_KEY]
vector_ops = [op for op in macro_op_list if isinstance(op, VectorOp)]

print("normalized node count:", len(node_summary(graph_module)))
print("node count with macro op entries:", node_count_with_macro_ops)
print("global macro op count:", len(macro_op_list))
print("global macro op type summary:", dict(macro_summary(macro_op_list)))
print("all node infos:")
for current_node_info in all_node_infos:
    pprint(current_node_info)
# Out:
# 2026-04-05 16:53:38,613 - INFO - Processed node=input_layernorm generated_macro_ops=1
# 2026-04-05 16:53:38,613 - INFO - Processed node=self_attn_qkv_proj generated_macro_ops=3
# 2026-04-05 16:53:38,614 - INFO - Processed node=self_attn_rotary_emb generated_macro_ops=0
# 2026-04-05 16:53:38,615 - INFO - Processed node=self_attn_attn generated_macro_ops=96
# 2026-04-05 16:53:38,615 - INFO - Processed node=self_attn_o_proj generated_macro_ops=4
# 2026-04-05 16:53:38,615 - INFO - Processed node=post_attention_layernorm generated_macro_ops=1
# 2026-04-05 16:53:38,615 - INFO - Processed node=mlp_gate_up_proj generated_macro_ops=18
# 2026-04-05 16:53:38,615 - INFO - Processed node=mlp_act_fn generated_macro_ops=1
# 2026-04-05 16:53:38,616 - INFO - Processed node=mlp_down_proj generated_macro_ops=10
# normalized node count: 13
# node count with macro op entries: 9
# global macro op count: 134
# global macro op type summary: {'VectorOp': 3, 'SramPrefetch': 43, 'MatMulOp': 11, 'SramPrefetchRelease': 43, 'FlashAttnOp': 32, 'AllReduceOp': 2}
# all node infos:
# {'node_name': 'hidden_states',
#  'node_op': 'placeholder',
#  'node_target': 'hidden_states'}
# {'node_name': 'input_layernorm',
#  'node_op': 'call_module',
#  'node_target': 'input_layernorm'}
# {'node_name': 'self_attn_qkv_proj',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.qkv_proj'}
# {'node_name': 'self_attn__dummy_positions',
#  'node_op': 'get_attr',
#  'node_target': 'self_attn._dummy_positions'}
# {'node_name': 'self_attn_rotary_emb',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.rotary_emb'}
# {'node_name': 'self_attn_attn',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.attn'}
# {'node_name': 'self_attn_o_proj',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.o_proj'}
# {'node_name': 'add',
#  'node_op': 'call_function',
#  'node_target': '<built-in function add>'}
# {'node_name': 'post_attention_layernorm',
#  'node_op': 'call_module',
#  'node_target': 'post_attention_layernorm'}
# {'node_name': 'mlp_gate_up_proj',
#  'node_op': 'call_module',
#  'node_target': 'mlp.gate_up_proj'}
# {'node_name': 'mlp_act_fn',
#  'node_op': 'call_module',
#  'node_target': 'mlp.act_fn'}
# {'node_name': 'mlp_down_proj',
#  'node_op': 'call_module',
#  'node_target': 'mlp.down_proj'}
# {'node_name': 'add_1',
#  'node_op': 'call_function',
#  'node_target': '<built-in function add>'}

# %%
assert macro_op_list
assert all_graph_nodes
assert node_count_with_macro_ops > 0
assert any(isinstance(op, MatMulOp) for op in macro_op_list)
assert any(isinstance(op, FlashAttnOp) for op in macro_op_list)
assert any(op.vector_op_type == "rms_norm" for op in vector_ops)
assert any(op.vector_op_type == "silu_mul" for op in vector_ops)
assert all(all(dim > 0 for dim in op.vector_shape) for op in vector_ops)
if TP_SIZE > 1:
    assert any(isinstance(op, AllReduceOp) for op in macro_op_list)

print("dense node-level frontend pipeline completed successfully")
# Out:
# dense node-level frontend pipeline completed successfully

# %%
print("=" * 120)
print("full simulation")
print("macro op count:", len(macro_op_list))
print("macro op type summary:", dict(macro_summary(macro_op_list)))

full_trace_path = full_trace_file_path()
full_sim_result = run_macro_ops_with_trace(
    nand_config,
    macro_op_list,
    trace_path=full_trace_path,
    **runtime_simulator_config,
)
assert full_sim_result["cycle"] > 0
assert full_sim_result["time_ns"] > 0
print("sim cycle:", full_sim_result["cycle"])
print("sim time ns:", full_sim_result["time_ns"])
print("trace path:", full_sim_result["trace_path"])
print("trace event count:", full_sim_result["trace_event_count"])
print("trace complete event count:", full_sim_result["trace_complete_event_count"])
print(
    "trace complete event categories:",
    full_sim_result["trace_complete_event_categories"],
)

node_sim_results = []

for node_index, node in enumerate(all_graph_nodes):
    node_macro_ops = node.meta.get("marco_op_list", [])
    current_node_info = node_info(node)
    current_macro_summary = dict(macro_summary(node_macro_ops))

    print("=" * 120)
    print("node index:", node_index)
    print("node info:")
    pprint(current_node_info)
    print("macro op count:", len(node_macro_ops))
    print("macro op type summary:", current_macro_summary)

    serialized_macro_ops = [macro_info(op) for op in node_macro_ops]
    print("macro op details:")
    for macro_op_payload in serialized_macro_ops:
        pprint(macro_op_payload)

    if not node_macro_ops:
        print("simulation skipped because this node produced no macro ops")
        node_sim_results.append(
            {
                **current_node_info,
                "macro_op_count": 0,
                "macro_op_types": [],
                "sim_cycle": None,
                "sim_time_ns": None,
                "trace_path": None,
                "trace_event_count": None,
                "trace_complete_event_count": None,
                "trace_complete_event_categories": None,
                "macro_ops": serialized_macro_ops,
            }
        )
        continue

    current_trace_path = trace_file_path(node_index, node)
    sim_result = run_macro_ops_with_trace(
        nand_config,
        node_macro_ops,
        trace_path=current_trace_path,
        **runtime_simulator_config,
    )
    assert sim_result["cycle"] > 0
    assert sim_result["time_ns"] > 0
    print("sim cycle:", sim_result["cycle"])
    print("sim time ns:", sim_result["time_ns"])
    print("trace path:", sim_result["trace_path"])
    print("trace event count:", sim_result["trace_event_count"])
    print("trace complete event count:", sim_result["trace_complete_event_count"])
    print(
        "trace complete event categories:",
        sim_result["trace_complete_event_categories"],
    )

    node_sim_results.append(
        {
            **current_node_info,
            "macro_op_count": len(node_macro_ops),
            "macro_op_types": [type(op).__name__ for op in node_macro_ops],
            "sim_cycle": sim_result["cycle"],
            "sim_time_ns": sim_result["time_ns"],
            "trace_path": sim_result["trace_path"],
            "trace_event_count": sim_result["trace_event_count"],
            "trace_complete_event_count": sim_result["trace_complete_event_count"],
            "trace_complete_event_categories": sim_result[
                "trace_complete_event_categories"
            ],
            "macro_ops": serialized_macro_ops,
        }
    )
# Out:
# ========================================================================================================================
# full simulation
# macro op count: 134
# macro op type summary: {'VectorOp': 3, 'SramPrefetch': 43, 'MatMulOp': 11, 'SramPrefetchRelease': 43, 'FlashAttnOp': 32, 'AllReduceOp': 2}
# VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 16384], weight_bits=16)
# MatMulOp(id=3, input_ops=[SramPrefetch(id=2, input_ops=[], num_prefetch_pages=18432), VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 16384], weight_bits=16)], dim=(128, 16384, 2304), weight_bits=16)
# FlashAttnOp(id=6, input_ops=[SramPrefetch(id=5, input_ops=[], num_prefetch_pages=4608), MatMulOp(id=3, input_ops=[SramPrefetch(id=2, input_ops=[], num_prefetch_pages=18432), VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 16384], weight_bits=16)], dim=(128, 16384, 2304), weight_bits=16)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=9, input_ops=[SramPrefetch(id=8, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=12, input_ops=[SramPrefetch(id=11, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=15, input_ops=[SramPrefetch(id=14, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=18, input_ops=[SramPrefetch(id=17, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=21, input_ops=[SramPrefetch(id=20, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=24, input_ops=[SramPrefetch(id=23, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=27, input_ops=[SramPrefetch(id=26, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=30, input_ops=[SramPrefetch(id=29, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=33, input_ops=[SramPrefetch(id=32, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=36, input_ops=[SramPrefetch(id=35, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=39, input_ops=[SramPrefetch(id=38, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=42, input_ops=[SramPrefetch(id=41, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=45, input_ops=[SramPrefetch(id=44, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=48, input_ops=[SramPrefetch(id=47, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=51, input_ops=[SramPrefetch(id=50, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=54, input_ops=[SramPrefetch(id=53, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=57, input_ops=[SramPrefetch(id=56, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=60, input_ops=[SramPrefetch(id=59, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=63, input_ops=[SramPrefetch(id=62, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=66, input_ops=[SramPrefetch(id=65, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=69, input_ops=[SramPrefetch(id=68, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=72, input_ops=[SramPrefetch(id=71, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=75, input_ops=[SramPrefetch(id=74, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=78, input_ops=[SramPrefetch(id=77, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=81, input_ops=[SramPrefetch(id=80, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=84, input_ops=[SramPrefetch(id=83, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=87, input_ops=[SramPrefetch(id=86, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=90, input_ops=[SramPrefetch(id=89, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=93, input_ops=[SramPrefetch(id=92, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=96, input_ops=[SramPrefetch(id=95, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=99, input_ops=[SramPrefetch(id=98, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# MatMulOp(id=102, input_ops=[SramPrefetch(id=101, input_ops=[], num_prefetch_pages=16384), FlashAttnOp(id=99, input_ops=[SramPrefetch(id=98, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)], dim=(128, 2048, 16384), weight_bits=16)
# VectorOp(id=105, input_ops=[AllReduceOp(id=104, input_ops=[MatMulOp(id=102, input_ops=[SramPrefetch(id=101, input_ops=[], num_prefetch_pages=16384), FlashAttnOp(id=99, input_ops=[SramPrefetch(id=98, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)], dim=(128, 2048, 16384), weight_bits=16)], num_ranks=8, data_size=4194304, weight_bits=16)], vector_op_type='rms_norm', vector_shape=[128, 16384], weight_bits=16)
# MatMulOp(id=107, input_ops=[SramPrefetch(id=106, input_ops=[], num_prefetch_pages=20480), VectorOp(id=105, input_ops=[AllReduceOp(id=104, input_ops=[MatMulOp(id=102, input_ops=[SramPrefetch(id=101, input_ops=[], num_prefetch_pages=16384), FlashAttnOp(id=99, input_ops=[SramPrefetch(id=98, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)], dim=(128, 2048, 16384), weight_bits=16)], num_ranks=8, data_size=4194304, weight_bits=16)], vector_op_type='rms_norm', vector_shape=[128, 16384], weight_bits=16)], dim=(128, 16384, 2560), weight_bits=16)
# MatMulOp(id=110, input_ops=[SramPrefetch(id=109, input_ops=[], num_prefetch_pages=20480)], dim=(128, 16384, 2560), weight_bits=16)
# MatMulOp(id=113, input_ops=[SramPrefetch(id=112, input_ops=[], num_prefetch_pages=20480)], dim=(128, 16384, 2560), weight_bits=16)
# MatMulOp(id=116, input_ops=[SramPrefetch(id=115, input_ops=[], num_prefetch_pages=20480)], dim=(128, 16384, 2560), weight_bits=16)
# MatMulOp(id=119, input_ops=[SramPrefetch(id=118, input_ops=[], num_prefetch_pages=20480)], dim=(128, 16384, 2560), weight_bits=16)
# MatMulOp(id=122, input_ops=[SramPrefetch(id=121, input_ops=[], num_prefetch_pages=4096)], dim=(128, 16384, 512), weight_bits=16)
# VectorOp(id=124, input_ops=[MatMulOp(id=122, input_ops=[SramPrefetch(id=121, input_ops=[], num_prefetch_pages=4096)], dim=(128, 16384, 512), weight_bits=16)], vector_op_type='silu_mul', vector_shape=[128, 6656], weight_bits=16)
# MatMulOp(id=126, input_ops=[SramPrefetch(id=125, input_ops=[], num_prefetch_pages=20479), VectorOp(id=124, input_ops=[MatMulOp(id=122, input_ops=[SramPrefetch(id=121, input_ops=[], num_prefetch_pages=4096)], dim=(128, 16384, 512), weight_bits=16)], vector_op_type='silu_mul', vector_shape=[128, 6656], weight_bits=16)], dim=(128, 6656, 6301), weight_bits=16)
# MatMulOp(id=129, input_ops=[SramPrefetch(id=128, input_ops=[], num_prefetch_pages=20479)], dim=(128, 6656, 6301), weight_bits=16)
# MatMulOp(id=132, input_ops=[SramPrefetch(id=131, input_ops=[], num_prefetch_pages=12292)], dim=(128, 6656, 3782), weight_bits=16)
# sim cycle: 1207427
# sim time ns: 659796
# trace path: trace/dense/full_simulation.json
# trace event count: 95
# trace complete event count: 91
# trace complete event categories: {'compute': 46, 'prefetch': 43, 'transfer': 2}
# ========================================================================================================================
# node index: 0
# node info:
# {'node_name': 'hidden_states',
#  'node_op': 'placeholder',
#  'node_target': 'hidden_states'}
# macro op count: 0
# macro op type summary: {}
# macro op details:
# simulation skipped because this node produced no macro ops
# ========================================================================================================================
# node index: 1
# node info:
# {'node_name': 'input_layernorm',
#  'node_op': 'call_module',
#  'node_target': 'input_layernorm'}
# macro op count: 1
# macro op type summary: {'VectorOp': 1}
# macro op details:
# {'id': 1,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'rms_norm',
#  'vector_shape': [128, 16384],
#  'weight_bits': 16}
# VectorOp(id=1, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 16384], weight_bits=16)
# sim cycle: 251
# sim time ns: 137
# trace path: trace/dense/node_001_input_layernorm_call_module.json
# trace event count: 5
# trace complete event count: 1
# trace complete event categories: {'compute': 1}
# ========================================================================================================================
# node index: 2
# node info:
# {'node_name': 'self_attn_qkv_proj',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.qkv_proj'}
# macro op count: 3
# macro op type summary: {'SramPrefetch': 1, 'MatMulOp': 1, 'SramPrefetchRelease': 1}
# macro op details:
# {'id': 2, 'input_ops': [], 'num_prefetch_pages': 18432, 'type': 'SramPrefetch'}
# {'dim': (128, 16384, 2304),
#  'id': 3,
#  'input_ops': [{'id': 2, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 4,
#  'input_ops': [{'id': 3, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# MatMulOp(id=3, input_ops=[SramPrefetch(id=2, input_ops=[], num_prefetch_pages=18432)], dim=(128, 16384, 2304), weight_bits=16)
# sim cycle: 60323
# sim time ns: 32963
# trace path: trace/dense/node_002_self_attn_qkv_proj_call_module.json
# trace event count: 6
# trace complete event count: 2
# trace complete event categories: {'prefetch': 1, 'compute': 1}
# ========================================================================================================================
# node index: 3
# node info:
# {'node_name': 'self_attn__dummy_positions',
#  'node_op': 'get_attr',
#  'node_target': 'self_attn._dummy_positions'}
# macro op count: 0
# macro op type summary: {}
# macro op details:
# simulation skipped because this node produced no macro ops
# ========================================================================================================================
# node index: 4
# node info:
# {'node_name': 'self_attn_rotary_emb',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.rotary_emb'}
# macro op count: 0
# macro op type summary: {}
# macro op details:
# simulation skipped because this node produced no macro ops
# ========================================================================================================================
# node index: 5
# node info:
# {'node_name': 'self_attn_attn',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.attn'}
# macro op count: 96
# macro op type summary: {'SramPrefetch': 32, 'FlashAttnOp': 32, 'SramPrefetchRelease': 32}
# macro op details:
# {'id': 5, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 6,
#  'input_ops': [{'id': 5, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 7,
#  'input_ops': [{'id': 6, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 8, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 9,
#  'input_ops': [{'id': 8, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 10,
#  'input_ops': [{'id': 9, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 11, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 12,
#  'input_ops': [{'id': 11, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 13,
#  'input_ops': [{'id': 12, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 14, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 15,
#  'input_ops': [{'id': 14, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 16,
#  'input_ops': [{'id': 15, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 17, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 18,
#  'input_ops': [{'id': 17, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 19,
#  'input_ops': [{'id': 18, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 20, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 21,
#  'input_ops': [{'id': 20, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 22,
#  'input_ops': [{'id': 21, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 23, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 24,
#  'input_ops': [{'id': 23, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 25,
#  'input_ops': [{'id': 24, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 26, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 27,
#  'input_ops': [{'id': 26, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 28,
#  'input_ops': [{'id': 27, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 29, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 30,
#  'input_ops': [{'id': 29, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 31,
#  'input_ops': [{'id': 30, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 32, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 33,
#  'input_ops': [{'id': 32, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 34,
#  'input_ops': [{'id': 33, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 35, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 36,
#  'input_ops': [{'id': 35, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 37,
#  'input_ops': [{'id': 36, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 38, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 39,
#  'input_ops': [{'id': 38, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 40,
#  'input_ops': [{'id': 39, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 41, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 42,
#  'input_ops': [{'id': 41, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 43,
#  'input_ops': [{'id': 42, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 44, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 45,
#  'input_ops': [{'id': 44, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 46,
#  'input_ops': [{'id': 45, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 47, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 48,
#  'input_ops': [{'id': 47, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 49,
#  'input_ops': [{'id': 48, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 50, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 51,
#  'input_ops': [{'id': 50, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 52,
#  'input_ops': [{'id': 51, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 53, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 54,
#  'input_ops': [{'id': 53, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 55,
#  'input_ops': [{'id': 54, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 56, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 57,
#  'input_ops': [{'id': 56, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 58,
#  'input_ops': [{'id': 57, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 59, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 60,
#  'input_ops': [{'id': 59, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 61,
#  'input_ops': [{'id': 60, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 62, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 63,
#  'input_ops': [{'id': 62, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 64,
#  'input_ops': [{'id': 63, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 65, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 66,
#  'input_ops': [{'id': 65, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 67,
#  'input_ops': [{'id': 66, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 68, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 69,
#  'input_ops': [{'id': 68, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 70,
#  'input_ops': [{'id': 69, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 71, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 72,
#  'input_ops': [{'id': 71, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 73,
#  'input_ops': [{'id': 72, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 74, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 75,
#  'input_ops': [{'id': 74, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 76,
#  'input_ops': [{'id': 75, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 77, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 78,
#  'input_ops': [{'id': 77, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 79,
#  'input_ops': [{'id': 78, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 80, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 81,
#  'input_ops': [{'id': 80, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 82,
#  'input_ops': [{'id': 81, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 83, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 84,
#  'input_ops': [{'id': 83, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 85,
#  'input_ops': [{'id': 84, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 86, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 87,
#  'input_ops': [{'id': 86, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 88,
#  'input_ops': [{'id': 87, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 89, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 90,
#  'input_ops': [{'id': 89, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 91,
#  'input_ops': [{'id': 90, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 92, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 93,
#  'input_ops': [{'id': 92, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 94,
#  'input_ops': [{'id': 93, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 95, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 96,
#  'input_ops': [{'id': 95, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 97,
#  'input_ops': [{'id': 96, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 98, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 99,
#  'input_ops': [{'id': 98, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 100,
#  'input_ops': [{'id': 99, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# FlashAttnOp(id=6, input_ops=[SramPrefetch(id=5, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=9, input_ops=[SramPrefetch(id=8, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=12, input_ops=[SramPrefetch(id=11, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=15, input_ops=[SramPrefetch(id=14, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=18, input_ops=[SramPrefetch(id=17, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=21, input_ops=[SramPrefetch(id=20, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=24, input_ops=[SramPrefetch(id=23, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=27, input_ops=[SramPrefetch(id=26, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=30, input_ops=[SramPrefetch(id=29, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=33, input_ops=[SramPrefetch(id=32, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=36, input_ops=[SramPrefetch(id=35, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=39, input_ops=[SramPrefetch(id=38, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=42, input_ops=[SramPrefetch(id=41, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=45, input_ops=[SramPrefetch(id=44, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=48, input_ops=[SramPrefetch(id=47, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=51, input_ops=[SramPrefetch(id=50, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=54, input_ops=[SramPrefetch(id=53, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=57, input_ops=[SramPrefetch(id=56, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=60, input_ops=[SramPrefetch(id=59, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=63, input_ops=[SramPrefetch(id=62, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=66, input_ops=[SramPrefetch(id=65, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=69, input_ops=[SramPrefetch(id=68, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=72, input_ops=[SramPrefetch(id=71, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=75, input_ops=[SramPrefetch(id=74, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=78, input_ops=[SramPrefetch(id=77, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=81, input_ops=[SramPrefetch(id=80, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=84, input_ops=[SramPrefetch(id=83, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=87, input_ops=[SramPrefetch(id=86, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=90, input_ops=[SramPrefetch(id=89, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=93, input_ops=[SramPrefetch(id=92, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=96, input_ops=[SramPrefetch(id=95, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=99, input_ops=[SramPrefetch(id=98, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# sim cycle: 282088
# sim time ns: 154146
# trace path: trace/dense/node_005_self_attn_attn_call_module.json
# trace event count: 68
# trace complete event count: 64
# trace complete event categories: {'prefetch': 32, 'compute': 32}
# ========================================================================================================================
# node index: 6
# node info:
# {'node_name': 'self_attn_o_proj',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.o_proj'}
# macro op count: 4
# macro op type summary: {'SramPrefetch': 1, 'MatMulOp': 1, 'SramPrefetchRelease': 1, 'AllReduceOp': 1}
# macro op details:
# {'id': 101,
#  'input_ops': [],
#  'num_prefetch_pages': 16384,
#  'type': 'SramPrefetch'}
# {'dim': (128, 2048, 16384),
#  'id': 102,
#  'input_ops': [{'id': 101, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 103,
#  'input_ops': [{'id': 102, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'data_size': 4194304,
#  'id': 104,
#  'input_ops': [{'id': 102, 'type': 'MatMulOp'}],
#  'num_ranks': 8,
#  'type': 'AllReduceOp',
#  'weight_bits': 16}
# MatMulOp(id=102, input_ops=[SramPrefetch(id=101, input_ops=[], num_prefetch_pages=16384)], dim=(128, 2048, 16384), weight_bits=16)
# sim cycle: 340185
# sim time ns: 185893
# trace path: trace/dense/node_006_self_attn_o_proj_call_module.json
# trace event count: 7
# trace complete event count: 3
# trace complete event categories: {'prefetch': 1, 'compute': 1, 'transfer': 1}
# ========================================================================================================================
# node index: 7
# node info:
# {'node_name': 'add',
#  'node_op': 'call_function',
#  'node_target': '<built-in function add>'}
# macro op count: 0
# macro op type summary: {}
# macro op details:
# simulation skipped because this node produced no macro ops
# ========================================================================================================================
# node index: 8
# node info:
# {'node_name': 'post_attention_layernorm',
#  'node_op': 'call_module',
#  'node_target': 'post_attention_layernorm'}
# macro op count: 1
# macro op type summary: {'VectorOp': 1}
# macro op details:
# {'id': 105,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'rms_norm',
#  'vector_shape': [128, 16384],
#  'weight_bits': 16}
# VectorOp(id=105, input_ops=[], vector_op_type='rms_norm', vector_shape=[128, 16384], weight_bits=16)
# sim cycle: 251
# sim time ns: 137
# trace path: trace/dense/node_008_post_attention_layernorm_call_module.json
# trace event count: 5
# trace complete event count: 1
# trace complete event categories: {'compute': 1}
# ========================================================================================================================
# node index: 9
# node info:
# {'node_name': 'mlp_gate_up_proj',
#  'node_op': 'call_module',
#  'node_target': 'mlp.gate_up_proj'}
# macro op count: 18
# macro op type summary: {'SramPrefetch': 6, 'MatMulOp': 6, 'SramPrefetchRelease': 6}
# macro op details:
# {'id': 106,
#  'input_ops': [],
#  'num_prefetch_pages': 20480,
#  'type': 'SramPrefetch'}
# {'dim': (128, 16384, 2560),
#  'id': 107,
#  'input_ops': [{'id': 106, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 108,
#  'input_ops': [{'id': 107, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 109,
#  'input_ops': [],
#  'num_prefetch_pages': 20480,
#  'type': 'SramPrefetch'}
# {'dim': (128, 16384, 2560),
#  'id': 110,
#  'input_ops': [{'id': 109, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 111,
#  'input_ops': [{'id': 110, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 112,
#  'input_ops': [],
#  'num_prefetch_pages': 20480,
#  'type': 'SramPrefetch'}
# {'dim': (128, 16384, 2560),
#  'id': 113,
#  'input_ops': [{'id': 112, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 114,
#  'input_ops': [{'id': 113, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 115,
#  'input_ops': [],
#  'num_prefetch_pages': 20480,
#  'type': 'SramPrefetch'}
# {'dim': (128, 16384, 2560),
#  'id': 116,
#  'input_ops': [{'id': 115, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 117,
#  'input_ops': [{'id': 116, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 118,
#  'input_ops': [],
#  'num_prefetch_pages': 20480,
#  'type': 'SramPrefetch'}
# {'dim': (128, 16384, 2560),
#  'id': 119,
#  'input_ops': [{'id': 118, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 120,
#  'input_ops': [{'id': 119, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 121, 'input_ops': [], 'num_prefetch_pages': 4096, 'type': 'SramPrefetch'}
# {'dim': (128, 16384, 512),
#  'id': 122,
#  'input_ops': [{'id': 121, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 123,
#  'input_ops': [{'id': 122, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# MatMulOp(id=107, input_ops=[SramPrefetch(id=106, input_ops=[], num_prefetch_pages=20480)], dim=(128, 16384, 2560), weight_bits=16)
# MatMulOp(id=110, input_ops=[SramPrefetch(id=109, input_ops=[], num_prefetch_pages=20480)], dim=(128, 16384, 2560), weight_bits=16)
# MatMulOp(id=113, input_ops=[SramPrefetch(id=112, input_ops=[], num_prefetch_pages=20480)], dim=(128, 16384, 2560), weight_bits=16)
# MatMulOp(id=116, input_ops=[SramPrefetch(id=115, input_ops=[], num_prefetch_pages=20480)], dim=(128, 16384, 2560), weight_bits=16)
# MatMulOp(id=119, input_ops=[SramPrefetch(id=118, input_ops=[], num_prefetch_pages=20480)], dim=(128, 16384, 2560), weight_bits=16)
# MatMulOp(id=122, input_ops=[SramPrefetch(id=121, input_ops=[], num_prefetch_pages=4096)], dim=(128, 16384, 512), weight_bits=16)
# sim cycle: 211964
# sim time ns: 115827
# trace path: trace/dense/node_009_mlp_gate_up_proj_call_module.json
# trace event count: 16
# trace complete event count: 12
# trace complete event categories: {'prefetch': 6, 'compute': 6}
# ========================================================================================================================
# node index: 10
# node info:
# {'node_name': 'mlp_act_fn',
#  'node_op': 'call_module',
#  'node_target': 'mlp.act_fn'}
# macro op count: 1
# macro op type summary: {'VectorOp': 1}
# macro op details:
# {'id': 124,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [128, 6656],
#  'weight_bits': 16}
# VectorOp(id=124, input_ops=[], vector_op_type='silu_mul', vector_shape=[128, 6656], weight_bits=16)
# sim cycle: 520
# sim time ns: 284
# trace path: trace/dense/node_010_mlp_act_fn_call_module.json
# trace event count: 5
# trace complete event count: 1
# trace complete event categories: {'compute': 1}
# ========================================================================================================================
# node index: 11
# node info:
# {'node_name': 'mlp_down_proj',
#  'node_op': 'call_module',
#  'node_target': 'mlp.down_proj'}
# macro op count: 10
# macro op type summary: {'SramPrefetch': 3, 'MatMulOp': 3, 'SramPrefetchRelease': 3, 'AllReduceOp': 1}
# macro op details:
# {'id': 125,
#  'input_ops': [],
#  'num_prefetch_pages': 20479,
#  'type': 'SramPrefetch'}
# {'dim': (128, 6656, 6301),
#  'id': 126,
#  'input_ops': [{'id': 125, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 127,
#  'input_ops': [{'id': 126, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 128,
#  'input_ops': [],
#  'num_prefetch_pages': 20479,
#  'type': 'SramPrefetch'}
# {'dim': (128, 6656, 6301),
#  'id': 129,
#  'input_ops': [{'id': 128, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 130,
#  'input_ops': [{'id': 129, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 131,
#  'input_ops': [],
#  'num_prefetch_pages': 12292,
#  'type': 'SramPrefetch'}
# {'dim': (128, 6656, 3782),
#  'id': 132,
#  'input_ops': [{'id': 131, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 133,
#  'input_ops': [{'id': 132, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'data_size': 4194304,
#  'id': 134,
#  'input_ops': [{'id': 126, 'type': 'MatMulOp'},
#                {'id': 129, 'type': 'MatMulOp'},
#                {'id': 132, 'type': 'MatMulOp'}],
#  'num_ranks': 8,
#  'type': 'AllReduceOp',
#  'weight_bits': 16}
# MatMulOp(id=126, input_ops=[SramPrefetch(id=125, input_ops=[], num_prefetch_pages=20479)], dim=(128, 6656, 6301), weight_bits=16)
# MatMulOp(id=129, input_ops=[SramPrefetch(id=128, input_ops=[], num_prefetch_pages=20479)], dim=(128, 6656, 6301), weight_bits=16)
# MatMulOp(id=132, input_ops=[SramPrefetch(id=131, input_ops=[], num_prefetch_pages=12292)], dim=(128, 6656, 3782), weight_bits=16)
# sim cycle: 410523
# sim time ns: 224329
# trace path: trace/dense/node_011_mlp_down_proj_call_module.json
# trace event count: 11
# trace complete event count: 7
# trace complete event categories: {'prefetch': 3, 'compute': 3, 'transfer': 1}
# ========================================================================================================================
# node index: 12
# node info:
# {'node_name': 'add_1',
#  'node_op': 'call_function',
#  'node_target': '<built-in function add>'}
# macro op count: 0
# macro op type summary: {}
# macro op details:
# simulation skipped because this node produced no macro ops

# %%
node_sim_results
# Out:
# [{'node_name': 'hidden_states',
#   'node_op': 'placeholder',
#   'node_target': 'hidden_states',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []},
#  {'node_name': 'input_layernorm',
#   'node_op': 'call_module',
#   'node_target': 'input_layernorm',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 251,
#   'sim_time_ns': 137,
#   'trace_path': 'trace/dense/node_001_input_layernorm_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 1,
#     'input_ops': [],
#     'vector_op_type': 'rms_norm',
#     'vector_shape': [128, 16384],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'self_attn_qkv_proj',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.qkv_proj',
#   'macro_op_count': 3,
#   'macro_op_types': ['SramPrefetch', 'MatMulOp', 'SramPrefetchRelease'],
#   'sim_cycle': 60323,
#   'sim_time_ns': 32963,
#   'trace_path': 'trace/dense/node_002_self_attn_qkv_proj_call_module.json',
#   'trace_event_count': 6,
#   'trace_complete_event_count': 2,
#   'trace_complete_event_categories': {'prefetch': 1, 'compute': 1},
#   'macro_ops': [{'id': 2,
#     'input_ops': [],
#     'num_prefetch_pages': 18432,
#     'type': 'SramPrefetch'},
#    {'id': 3,
#     'input_ops': [{'id': 2, 'type': 'SramPrefetch'}],
#     'dim': (128, 16384, 2304),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 4,
#     'input_ops': [{'id': 3, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'}]},
#  {'node_name': 'self_attn__dummy_positions',
#   'node_op': 'get_attr',
#   'node_target': 'self_attn._dummy_positions',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []},
#  {'node_name': 'self_attn_rotary_emb',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.rotary_emb',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []},
#  {'node_name': 'self_attn_attn',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.attn',
#   'macro_op_count': 96,
#   'macro_op_types': ['SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease'],
#   'sim_cycle': 282088,
#   'sim_time_ns': 154146,
#   'trace_path': 'trace/dense/node_005_self_attn_attn_call_module.json',
#   'trace_event_count': 68,
#   'trace_complete_event_count': 64,
#   'trace_complete_event_categories': {'prefetch': 32, 'compute': 32},
#   'macro_ops': [{'id': 5,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 6,
#     'input_ops': [{'id': 5, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 7,
#     'input_ops': [{'id': 6, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 8,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 9,
#     'input_ops': [{'id': 8, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 10,
#     'input_ops': [{'id': 9, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 11,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 12,
#     'input_ops': [{'id': 11, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 13,
#     'input_ops': [{'id': 12, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 14,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 15,
#     'input_ops': [{'id': 14, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 16,
#     'input_ops': [{'id': 15, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 17,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 18,
#     'input_ops': [{'id': 17, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 19,
#     'input_ops': [{'id': 18, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 20,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 21,
#     'input_ops': [{'id': 20, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 22,
#     'input_ops': [{'id': 21, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 23,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 24,
#     'input_ops': [{'id': 23, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 25,
#     'input_ops': [{'id': 24, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 26,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 27,
#     'input_ops': [{'id': 26, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 28,
#     'input_ops': [{'id': 27, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 29,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 30,
#     'input_ops': [{'id': 29, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 31,
#     'input_ops': [{'id': 30, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 32,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 33,
#     'input_ops': [{'id': 32, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 34,
#     'input_ops': [{'id': 33, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 35,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 36,
#     'input_ops': [{'id': 35, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 37,
#     'input_ops': [{'id': 36, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 38,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 39,
#     'input_ops': [{'id': 38, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 40,
#     'input_ops': [{'id': 39, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 41,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 42,
#     'input_ops': [{'id': 41, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 43,
#     'input_ops': [{'id': 42, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 44,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 45,
#     'input_ops': [{'id': 44, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 46,
#     'input_ops': [{'id': 45, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 47,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 48,
#     'input_ops': [{'id': 47, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 49,
#     'input_ops': [{'id': 48, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 50,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 51,
#     'input_ops': [{'id': 50, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 52,
#     'input_ops': [{'id': 51, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 53,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 54,
#     'input_ops': [{'id': 53, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 55,
#     'input_ops': [{'id': 54, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 56,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 57,
#     'input_ops': [{'id': 56, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 58,
#     'input_ops': [{'id': 57, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 59,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 60,
#     'input_ops': [{'id': 59, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 61,
#     'input_ops': [{'id': 60, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 62,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 63,
#     'input_ops': [{'id': 62, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 64,
#     'input_ops': [{'id': 63, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 65,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 66,
#     'input_ops': [{'id': 65, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 67,
#     'input_ops': [{'id': 66, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 68,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 69,
#     'input_ops': [{'id': 68, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 70,
#     'input_ops': [{'id': 69, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 71,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 72,
#     'input_ops': [{'id': 71, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 73,
#     'input_ops': [{'id': 72, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 74,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 75,
#     'input_ops': [{'id': 74, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 76,
#     'input_ops': [{'id': 75, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 77,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 78,
#     'input_ops': [{'id': 77, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 79,
#     'input_ops': [{'id': 78, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 80,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 81,
#     'input_ops': [{'id': 80, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 82,
#     'input_ops': [{'id': 81, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 83,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 84,
#     'input_ops': [{'id': 83, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 85,
#     'input_ops': [{'id': 84, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 86,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 87,
#     'input_ops': [{'id': 86, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 88,
#     'input_ops': [{'id': 87, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 89,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 90,
#     'input_ops': [{'id': 89, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 91,
#     'input_ops': [{'id': 90, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 92,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 93,
#     'input_ops': [{'id': 92, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 94,
#     'input_ops': [{'id': 93, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 95,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 96,
#     'input_ops': [{'id': 95, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 97,
#     'input_ops': [{'id': 96, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 98,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 99,
#     'input_ops': [{'id': 98, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 100,
#     'input_ops': [{'id': 99, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'}]},
#  {'node_name': 'self_attn_o_proj',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.o_proj',
#   'macro_op_count': 4,
#   'macro_op_types': ['SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'AllReduceOp'],
#   'sim_cycle': 340185,
#   'sim_time_ns': 185893,
#   'trace_path': 'trace/dense/node_006_self_attn_o_proj_call_module.json',
#   'trace_event_count': 7,
#   'trace_complete_event_count': 3,
#   'trace_complete_event_categories': {'prefetch': 1,
#    'compute': 1,
#    'transfer': 1},
#   'macro_ops': [{'id': 101,
#     'input_ops': [],
#     'num_prefetch_pages': 16384,
#     'type': 'SramPrefetch'},
#    {'id': 102,
#     'input_ops': [{'id': 101, 'type': 'SramPrefetch'}],
#     'dim': (128, 2048, 16384),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 103,
#     'input_ops': [{'id': 102, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 104,
#     'input_ops': [{'id': 102, 'type': 'MatMulOp'}],
#     'num_ranks': 8,
#     'data_size': 4194304,
#     'weight_bits': 16,
#     'type': 'AllReduceOp'}]},
#  {'node_name': 'add',
#   'node_op': 'call_function',
#   'node_target': '<built-in function add>',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []},
#  {'node_name': 'post_attention_layernorm',
#   'node_op': 'call_module',
#   'node_target': 'post_attention_layernorm',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 251,
#   'sim_time_ns': 137,
#   'trace_path': 'trace/dense/node_008_post_attention_layernorm_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 105,
#     'input_ops': [],
#     'vector_op_type': 'rms_norm',
#     'vector_shape': [128, 16384],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'mlp_gate_up_proj',
#   'node_op': 'call_module',
#   'node_target': 'mlp.gate_up_proj',
#   'macro_op_count': 18,
#   'macro_op_types': ['SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease'],
#   'sim_cycle': 211964,
#   'sim_time_ns': 115827,
#   'trace_path': 'trace/dense/node_009_mlp_gate_up_proj_call_module.json',
#   'trace_event_count': 16,
#   'trace_complete_event_count': 12,
#   'trace_complete_event_categories': {'prefetch': 6, 'compute': 6},
#   'macro_ops': [{'id': 106,
#     'input_ops': [],
#     'num_prefetch_pages': 20480,
#     'type': 'SramPrefetch'},
#    {'id': 107,
#     'input_ops': [{'id': 106, 'type': 'SramPrefetch'}],
#     'dim': (128, 16384, 2560),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 108,
#     'input_ops': [{'id': 107, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 109,
#     'input_ops': [],
#     'num_prefetch_pages': 20480,
#     'type': 'SramPrefetch'},
#    {'id': 110,
#     'input_ops': [{'id': 109, 'type': 'SramPrefetch'}],
#     'dim': (128, 16384, 2560),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 111,
#     'input_ops': [{'id': 110, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 112,
#     'input_ops': [],
#     'num_prefetch_pages': 20480,
#     'type': 'SramPrefetch'},
#    {'id': 113,
#     'input_ops': [{'id': 112, 'type': 'SramPrefetch'}],
#     'dim': (128, 16384, 2560),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 114,
#     'input_ops': [{'id': 113, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 115,
#     'input_ops': [],
#     'num_prefetch_pages': 20480,
#     'type': 'SramPrefetch'},
#    {'id': 116,
#     'input_ops': [{'id': 115, 'type': 'SramPrefetch'}],
#     'dim': (128, 16384, 2560),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 117,
#     'input_ops': [{'id': 116, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 118,
#     'input_ops': [],
#     'num_prefetch_pages': 20480,
#     'type': 'SramPrefetch'},
#    {'id': 119,
#     'input_ops': [{'id': 118, 'type': 'SramPrefetch'}],
#     'dim': (128, 16384, 2560),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 120,
#     'input_ops': [{'id': 119, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 121,
#     'input_ops': [],
#     'num_prefetch_pages': 4096,
#     'type': 'SramPrefetch'},
#    {'id': 122,
#     'input_ops': [{'id': 121, 'type': 'SramPrefetch'}],
#     'dim': (128, 16384, 512),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 123,
#     'input_ops': [{'id': 122, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'}]},
#  {'node_name': 'mlp_act_fn',
#   'node_op': 'call_module',
#   'node_target': 'mlp.act_fn',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 520,
#   'sim_time_ns': 284,
#   'trace_path': 'trace/dense/node_010_mlp_act_fn_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 124,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [128, 6656],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'mlp_down_proj',
#   'node_op': 'call_module',
#   'node_target': 'mlp.down_proj',
#   'macro_op_count': 10,
#   'macro_op_types': ['SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'AllReduceOp'],
#   'sim_cycle': 410523,
#   'sim_time_ns': 224329,
#   'trace_path': 'trace/dense/node_011_mlp_down_proj_call_module.json',
#   'trace_event_count': 11,
#   'trace_complete_event_count': 7,
#   'trace_complete_event_categories': {'prefetch': 3,
#    'compute': 3,
#    'transfer': 1},
#   'macro_ops': [{'id': 125,
#     'input_ops': [],
#     'num_prefetch_pages': 20479,
#     'type': 'SramPrefetch'},
#    {'id': 126,
#     'input_ops': [{'id': 125, 'type': 'SramPrefetch'}],
#     'dim': (128, 6656, 6301),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 127,
#     'input_ops': [{'id': 126, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 128,
#     'input_ops': [],
#     'num_prefetch_pages': 20479,
#     'type': 'SramPrefetch'},
#    {'id': 129,
#     'input_ops': [{'id': 128, 'type': 'SramPrefetch'}],
#     'dim': (128, 6656, 6301),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 130,
#     'input_ops': [{'id': 129, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 131,
#     'input_ops': [],
#     'num_prefetch_pages': 12292,
#     'type': 'SramPrefetch'},
#    {'id': 132,
#     'input_ops': [{'id': 131, 'type': 'SramPrefetch'}],
#     'dim': (128, 6656, 3782),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 133,
#     'input_ops': [{'id': 132, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 134,
#     'input_ops': [{'id': 126, 'type': 'MatMulOp'},
#      {'id': 129, 'type': 'MatMulOp'},
#      {'id': 132, 'type': 'MatMulOp'}],
#     'num_ranks': 8,
#     'data_size': 4194304,
#     'weight_bits': 16,
#     'type': 'AllReduceOp'}]},
#  {'node_name': 'add_1',
#   'node_op': 'call_function',
#   'node_target': '<built-in function add>',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []}]

# %%
non_empty_node_results = [result for result in node_sim_results if result["macro_op_count"] > 0]
empty_node_results = [result for result in node_sim_results if result["macro_op_count"] == 0]

assert len(node_sim_results) == len(all_graph_nodes)
assert full_sim_result["cycle"] > 0
assert full_sim_result["time_ns"] > 0
assert full_sim_result["trace_path"] is not None
assert full_sim_result["trace_event_count"] is not None
assert full_sim_result["trace_complete_event_count"] is not None
assert non_empty_node_results
assert all(result["sim_cycle"] is not None for result in non_empty_node_results)
assert all(result["sim_time_ns"] is not None for result in non_empty_node_results)
assert all(result["trace_path"] is not None for result in non_empty_node_results)
assert all(result["trace_event_count"] is not None for result in non_empty_node_results)
assert all(result["trace_complete_event_count"] is not None for result in non_empty_node_results)
assert all(result["sim_cycle"] is None for result in empty_node_results)
assert all(result["trace_path"] is None for result in empty_node_results)

full_sim_summary = {
    "macro_op_count": len(macro_op_list),
    "macro_op_type_summary": dict(macro_summary(macro_op_list)),
    "sim_cycle": full_sim_result["cycle"],
    "sim_time_ns": full_sim_result["time_ns"],
    "trace_path": full_sim_result["trace_path"],
    "trace_event_count": full_sim_result["trace_event_count"],
    "trace_complete_event_count": full_sim_result["trace_complete_event_count"],
    "trace_complete_event_categories": full_sim_result[
        "trace_complete_event_categories"
    ],
}

summary_rows = [
    {
        "node_name": result["node_name"],
        "node_op": result["node_op"],
        "node_target": result["node_target"],
        "macro_op_count": result["macro_op_count"],
        "macro_op_types": result["macro_op_types"],
        "sim_cycle": result["sim_cycle"],
        "sim_time_ns": result["sim_time_ns"],
        "trace_path": result["trace_path"],
        "trace_event_count": result["trace_event_count"],
        "trace_complete_event_count": result["trace_complete_event_count"],
        "trace_complete_event_categories": result["trace_complete_event_categories"],
    }
    for result in node_sim_results
]

{
    "full_simulation": full_sim_summary,
    "node_simulations": summary_rows,
}
# Out:
# {'full_simulation': {'macro_op_count': 134,
#   'macro_op_type_summary': {'VectorOp': 3,
#    'SramPrefetch': 43,
#    'MatMulOp': 11,
#    'SramPrefetchRelease': 43,
#    'FlashAttnOp': 32,
#    'AllReduceOp': 2},
#   'sim_cycle': 1207427,
#   'sim_time_ns': 659796,
#   'trace_path': 'trace/dense/full_simulation.json',
#   'trace_event_count': 95,
#   'trace_complete_event_count': 91,
#   'trace_complete_event_categories': {'compute': 46,
#    'prefetch': 43,
#    'transfer': 2}},
#  'node_simulations': [{'node_name': 'hidden_states',
#    'node_op': 'placeholder',
#    'node_target': 'hidden_states',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None},
#   {'node_name': 'input_layernorm',
#    'node_op': 'call_module',
#    'node_target': 'input_layernorm',
#    'macro_op_count': 1,
#    'macro_op_types': ['VectorOp'],
#    'sim_cycle': 251,
#    'sim_time_ns': 137,
#    'trace_path': 'trace/dense/node_001_input_layernorm_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'self_attn_qkv_proj',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.qkv_proj',
#    'macro_op_count': 3,
#    'macro_op_types': ['SramPrefetch', 'MatMulOp', 'SramPrefetchRelease'],
#    'sim_cycle': 60323,
#    'sim_time_ns': 32963,
#    'trace_path': 'trace/dense/node_002_self_attn_qkv_proj_call_module.json',
#    'trace_event_count': 6,
#    'trace_complete_event_count': 2,
#    'trace_complete_event_categories': {'prefetch': 1, 'compute': 1}},
#   {'node_name': 'self_attn__dummy_positions',
#    'node_op': 'get_attr',
#    'node_target': 'self_attn._dummy_positions',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None},
#   {'node_name': 'self_attn_rotary_emb',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.rotary_emb',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None},
#   {'node_name': 'self_attn_attn',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.attn',
#    'macro_op_count': 96,
#    'macro_op_types': ['SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease'],
#    'sim_cycle': 282088,
#    'sim_time_ns': 154146,
#    'trace_path': 'trace/dense/node_005_self_attn_attn_call_module.json',
#    'trace_event_count': 68,
#    'trace_complete_event_count': 64,
#    'trace_complete_event_categories': {'prefetch': 32, 'compute': 32}},
#   {'node_name': 'self_attn_o_proj',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.o_proj',
#    'macro_op_count': 4,
#    'macro_op_types': ['SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'AllReduceOp'],
#    'sim_cycle': 340185,
#    'sim_time_ns': 185893,
#    'trace_path': 'trace/dense/node_006_self_attn_o_proj_call_module.json',
#    'trace_event_count': 7,
#    'trace_complete_event_count': 3,
#    'trace_complete_event_categories': {'prefetch': 1,
#     'compute': 1,
#     'transfer': 1}},
#   {'node_name': 'add',
#    'node_op': 'call_function',
#    'node_target': '<built-in function add>',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None},
#   {'node_name': 'post_attention_layernorm',
#    'node_op': 'call_module',
#    'node_target': 'post_attention_layernorm',
#    'macro_op_count': 1,
#    'macro_op_types': ['VectorOp'],
#    'sim_cycle': 251,
#    'sim_time_ns': 137,
#    'trace_path': 'trace/dense/node_008_post_attention_layernorm_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'mlp_gate_up_proj',
#    'node_op': 'call_module',
#    'node_target': 'mlp.gate_up_proj',
#    'macro_op_count': 18,
#    'macro_op_types': ['SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease'],
#    'sim_cycle': 211964,
#    'sim_time_ns': 115827,
#    'trace_path': 'trace/dense/node_009_mlp_gate_up_proj_call_module.json',
#    'trace_event_count': 16,
#    'trace_complete_event_count': 12,
#    'trace_complete_event_categories': {'prefetch': 6, 'compute': 6}},
#   {'node_name': 'mlp_act_fn',
#    'node_op': 'call_module',
#    'node_target': 'mlp.act_fn',
#    'macro_op_count': 1,
#    'macro_op_types': ['VectorOp'],
#    'sim_cycle': 520,
#    'sim_time_ns': 284,
#    'trace_path': 'trace/dense/node_010_mlp_act_fn_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'mlp_down_proj',
#    'node_op': 'call_module',
#    'node_target': 'mlp.down_proj',
#    'macro_op_count': 10,
#    'macro_op_types': ['SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'AllReduceOp'],
#    'sim_cycle': 410523,
#    'sim_time_ns': 224329,
#    'trace_path': 'trace/dense/node_011_mlp_down_proj_call_module.json',
#    'trace_event_count': 11,
#    'trace_complete_event_count': 7,
#    'trace_complete_event_categories': {'prefetch': 3,
#     'compute': 3,
#     'transfer': 1}},
#   {'node_name': 'add_1',
#    'node_op': 'call_function',
#    'node_target': '<built-in function add>',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None}]}

# %%
print(kv_cache_state)
# Out:
# KVCacheState(total_kv_cache_size_per_layer=4781506560, kv_block_size_tokens=64, num_kv_blocks=18240, num_nand_pages_per_layer=1167360, num_hyper_pages_per_layer=254)
