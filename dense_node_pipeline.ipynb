# %% [markdown]
# # Node-Level Frontend Pipeline For Llama 405B
#
# 实现 Llama 405B decoder layer 的最小前端全流程，并在 code gen pass 之后按 node 读取 `marco_op_list`，对每个 node 单独运行硬件仿真，并在每个 node 结束后输出 perf trace 到 `trace/` 目录。

# %% [markdown]
# ## 流程
# - 加载 `llama-405B` model card 并初始化 `LlamaModelConfig`
# - 初始化 `NandConfig`、`InferenceConfig`，支持配置 `TP_SIZE`
# - 初始化 `LlamaDecoderLayer`
# - 使用 `NxTracer` trace 得到计算图
# - 运行 `NormalizePass` 获得简化图
# - 用 `build_kv_cache_state` 构造 `KVCacheState`
# - 构造 `NxGraphMeta` 并写入 `graph.meta`
# - 运行 `CodeGenPass`，收集全局和 node 级别的 `marco_op_list`
# - 对每个 node 单独运行硬件仿真，并把 trace 保存到 `trace/` 目录
# - 汇总 node 级别的 macro op、时延和 trace 信息

# %%
import json
import logging
import re
from collections import Counter
from dataclasses import fields, is_dataclass
from math import ceil
from pathlib import Path
from pprint import pprint

import torch
from Desim import SimSession
from torch.fx import GraphModule

from nandmachine.commands.macro import AllReduceOp, FlashAttnOp, MacroOp, MatMulOp, VectorOp
from nandmachine.config.config import NandConfig
from nandmachine.config.hardware_config import get_device_or_raise
from nandmachine.config.inference_config import DenseParallelConfig, InferenceConfig
from nandmachine.config.model_config import LlamaModelConfig
from nandmachine.frontend.core.graph.base import NxGraphMeta, NxTracer
from nandmachine.frontend.core.passes.cod_gen import CodeGenPass
from nandmachine.frontend.core.passes.normalize import NormalizePass
from nandmachine.frontend.network.llama import LlamaDecoderLayer
from nandmachine.frontend.utlis import build_kv_cache_state
from nandmachine.simulator.hardware.xpu import xPU

MODEL_CARD_PATH = Path("model_cards/llama-405B.json")
DEVICE_NAME = "H100_SXM"
COMPILE_MODE = "heuristic-GPU"
TP_SIZE = 8
TRACE_DIR = Path("trace")

assert MODEL_CARD_PATH.exists(), MODEL_CARD_PATH
assert TP_SIZE > 0, TP_SIZE


def node_summary(graph_module: GraphModule) -> list[tuple[str, str, str]]:
    return [(node.name, node.op, str(node.target)) for node in graph_module.graph.nodes]


def macro_summary(macro_op_list: list[object]) -> Counter:
    return Counter(type(op).__name__ for op in macro_op_list)


def node_info(node: torch.fx.Node) -> dict[str, object]:
    return {
        "node_name": node.name,
        "node_op": node.op,
        "node_target": str(node.target),
    }


def _serialize_value(value: object) -> object:
    if isinstance(value, MacroOp):
        return {
            "id": value.id,
            "type": type(value).__name__,
        }
    if isinstance(value, list):
        return [_serialize_value(item) for item in value]
    if isinstance(value, tuple):
        return tuple(_serialize_value(item) for item in value)
    return value


def macro_info(op: MacroOp) -> dict[str, object]:
    assert is_dataclass(op), type(op)
    payload = {field.name: _serialize_value(getattr(op, field.name)) for field in fields(op)}
    payload["type"] = type(op).__name__
    return payload


def trace_file_path(node_index: int, node: torch.fx.Node) -> Path:
    raw_name = f"{node_index:03d}_{node.name}_{node.op}"
    file_name = re.sub(r"[^0-9A-Za-z._-]+", "_", raw_name).strip("._")
    return TRACE_DIR / f"{file_name}.json"


def run_macro_ops_with_trace(
    nand_config: NandConfig,
    commands: list[MacroOp],
    *,
    trace_path: Path,
    device_name: str,
    compile_mode: str,
    hbm_bandwidth_bytes_per_sec: float,
) -> dict[str, object]:
    SimSession.reset()
    SimSession.init()

    sim_xpu = xPU(
        nand_config,
        hbm_bandwidth_bytes_per_sec=hbm_bandwidth_bytes_per_sec,
        device_name=device_name,
        compile_mode=compile_mode,
        enable_trace=True,
    )
    sim_xpu.load_command(commands)
    SimSession.scheduler.run()

    final_time_ns = int(SimSession.sim_time.cycle)
    device = get_device_or_raise(device_name)
    final_cycle = ceil(final_time_ns * device.compute_module.clock_freq / 1e9)

    trace_path.parent.mkdir(parents=True, exist_ok=True)
    saved_trace_path = Path(sim_xpu.save_trace_file(str(trace_path)))

    tracer = sim_xpu.tracer
    assert tracer is not None
    complete_events = [event for event in tracer._events if event["ph"] == "X"]

    return {
        "cycle": final_cycle,
        "time_ns": final_time_ns,
        "trace_path": str(saved_trace_path),
        "trace_event_count": len(tracer._events),
        "trace_complete_event_count": len(complete_events),
        "trace_complete_event_categories": dict(
            Counter(event["cat"] for event in complete_events)
        ),
    }

# %%
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
)

model_config = LlamaModelConfig.from_dict(json.loads(MODEL_CARD_PATH.read_text()))
nand_config = NandConfig(
    num_channels=6 * 8,
    num_plane=96,
    num_block=16, # 没什么用的参数
    num_pages=16, # 没什么用的参数
    tRead=4000, # ns
    tWrite=4000 * 10, # ns
    tErase=4000 * 100, # ns
    page_size=4, # KB
    sram_threshold=1024 * 80,  # KB  --  可以考虑之后统一改成 Bytes，统一所有的单位
)
parallel_config = DenseParallelConfig(
    num_ranks=TP_SIZE,
    tp_size=TP_SIZE,
    dp_size=1,
)
inference_config = InferenceConfig(
    batch_size=128, # 总的 batch size
    input_sequence_length=8096,
    output_sequence_length=1024,
    weight_bits=16,
    activation_bits=16,
    kv_cache_bits=16,
    kv_block_size_bytes=1024 * 256,  # bytes
    memory_backend="nand",
    parallel_config=parallel_config,
)
kv_cache_state = build_kv_cache_state(nand_config, model_config, inference_config)
graph_meta = NxGraphMeta(
    nand_config=nand_config,
    model_config=model_config,
    inference_config=inference_config,
    kv_cache_state=kv_cache_state,
)
simulator_config = {
    "device_name": DEVICE_NAME,
    "compile_mode": COMPILE_MODE,
}
simulator_config["hbm_bandwidth_bytes_per_sec"] = get_device_or_raise(
    simulator_config["device_name"]
).io_module.bandwidth
runtime_simulator_config = {
    "device_name": simulator_config["device_name"],
    "compile_mode": simulator_config["compile_mode"],
    "hbm_bandwidth_bytes_per_sec": simulator_config["hbm_bandwidth_bytes_per_sec"],
}
TRACE_DIR.mkdir(parents=True, exist_ok=True)

print("trace output dir:", TRACE_DIR)
# Out:
# trace output dir: trace

# %%
with torch.device("meta"):
    model = LlamaDecoderLayer(model_config, tp_size=TP_SIZE)
    graph = NxTracer().trace(model)
    graph_module = GraphModule(model, graph)

NormalizePass().transform(graph_module)
graph_module.graph.meta = {CodeGenPass.GRAPH_META_KEY: graph_meta}
CodeGenPass().transform(graph_module)

macro_op_list = graph_module.graph.meta[CodeGenPass.MACRO_OP_LIST_META_KEY]
vector_ops = [op for op in macro_op_list if isinstance(op, VectorOp)]
node_macro_op_entries = []

for node in graph_module.graph.nodes:
    if "marco_op_list" not in node.meta:
        continue
    node_macro_op_entries.append((node, node.meta["marco_op_list"]))

print("normalized node count:", len(node_summary(graph_module)))
print("node count with macro op entries:", len(node_macro_op_entries))
print("global macro op count:", len(macro_op_list))
print("global macro op type summary:", dict(macro_summary(macro_op_list)))
# Out:
# 2026-04-04 13:53:39,997 - INFO - Processed node=input_layernorm generated_macro_ops=1
# 2026-04-04 13:53:39,997 - INFO - Processed node=self_attn_qkv_proj generated_macro_ops=3
# 2026-04-04 13:53:39,998 - INFO - Processed node=self_attn_rotary_emb generated_macro_ops=0
# 2026-04-04 13:53:39,998 - INFO - Processed node=self_attn_attn generated_macro_ops=12
# 2026-04-04 13:53:39,998 - INFO - Processed node=self_attn_o_proj generated_macro_ops=4
# 2026-04-04 13:53:39,999 - INFO - Processed node=post_attention_layernorm generated_macro_ops=1
# 2026-04-04 13:53:39,999 - INFO - Processed node=mlp_gate_up_proj generated_macro_ops=18
# 2026-04-04 13:53:40,000 - INFO - Processed node=mlp_act_fn generated_macro_ops=1
# 2026-04-04 13:53:40,000 - INFO - Processed node=mlp_down_proj generated_macro_ops=10
# normalized node count: 13
# node count with macro op entries: 9
# global macro op count: 50
# global macro op type summary: {'VectorOp': 3, 'SramPrefetch': 15, 'MatMulOp': 11, 'SramPrefetchRelease': 15, 'FlashAttnOp': 4, 'AllReduceOp': 2}

# %%
assert macro_op_list
assert node_macro_op_entries
assert any(isinstance(op, MatMulOp) for op in macro_op_list)
assert any(isinstance(op, FlashAttnOp) for op in macro_op_list)
assert any(op.vector_op_type == "rms_norm" for op in vector_ops)
assert any(op.vector_op_type == "silu_mul" for op in vector_ops)
assert all(all(dim > 0 for dim in op.vector_shape) for op in vector_ops)
if TP_SIZE > 1:
    assert any(isinstance(op, AllReduceOp) for op in macro_op_list)

print("llama node-level frontend pipeline completed successfully")
# Out:
# llama node-level frontend pipeline completed successfully

# %%
node_sim_results = []

for node_index, (node, node_macro_ops) in enumerate(node_macro_op_entries):
    current_node_info = node_info(node)
    current_macro_summary = dict(macro_summary(node_macro_ops))

    print("=" * 120)
    print("node index:", node_index)
    print("node info:")
    pprint(current_node_info)
    print("macro op count:", len(node_macro_ops))
    print("macro op type summary:", current_macro_summary)

    serialized_macro_ops = [macro_info(op) for op in node_macro_ops]
    print("macro op details:")
    for macro_op_payload in serialized_macro_ops:
        pprint(macro_op_payload)

    if not node_macro_ops:
        print("simulation skipped because this node produced no macro ops")
        node_sim_results.append(
            {
                **current_node_info,
                "macro_op_count": 0,
                "macro_op_types": [],
                "sim_cycle": None,
                "sim_time_ns": None,
                "trace_path": None,
                "trace_event_count": None,
                "trace_complete_event_count": None,
                "trace_complete_event_categories": None,
                "macro_ops": serialized_macro_ops,
            }
        )
        continue

    current_trace_path = trace_file_path(node_index, node)
    sim_result = run_macro_ops_with_trace(
        nand_config,
        node_macro_ops,
        trace_path=current_trace_path,
        **runtime_simulator_config,
    )
    assert sim_result["cycle"] > 0
    assert sim_result["time_ns"] > 0
    print("sim cycle:", sim_result["cycle"])
    print("sim time ns:", sim_result["time_ns"])
    print("trace path:", sim_result["trace_path"])
    print("trace event count:", sim_result["trace_event_count"])
    print("trace complete event count:", sim_result["trace_complete_event_count"])
    print(
        "trace complete event categories:",
        sim_result["trace_complete_event_categories"],
    )

    node_sim_results.append(
        {
            **current_node_info,
            "macro_op_count": len(node_macro_ops),
            "macro_op_types": [type(op).__name__ for op in node_macro_ops],
            "sim_cycle": sim_result["cycle"],
            "sim_time_ns": sim_result["time_ns"],
            "trace_path": sim_result["trace_path"],
            "trace_event_count": sim_result["trace_event_count"],
            "trace_complete_event_count": sim_result["trace_complete_event_count"],
            "trace_complete_event_categories": sim_result[
                "trace_complete_event_categories"
            ],
            "macro_ops": serialized_macro_ops,
        }
    )
# Out:
# ========================================================================================================================
# node index: 0
# node info:
# {'node_name': 'input_layernorm',
#  'node_op': 'call_module',
#  'node_target': 'input_layernorm'}
# macro op count: 1
# macro op type summary: {'VectorOp': 1}
# macro op details:
# {'id': 1,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'rms_norm',
#  'vector_shape': [128, 16384],
#  'weight_bits': 16}
# sim cycle: 251
# sim time ns: 137
# trace path: trace/000_input_layernorm_call_module.json
# trace event count: 5
# trace complete event count: 1
# trace complete event categories: {'compute': 1}
# ========================================================================================================================
# node index: 1
# node info:
# {'node_name': 'self_attn_qkv_proj',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.qkv_proj'}
# macro op count: 3
# macro op type summary: {'SramPrefetch': 1, 'MatMulOp': 1, 'SramPrefetchRelease': 1}
# macro op details:
# {'id': 2, 'input_ops': [], 'num_prefetch_pages': 18432, 'type': 'SramPrefetch'}
# {'dim': (128, 16384, 2304),
#  'id': 3,
#  'input_ops': [{'id': 2, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 4,
#  'input_ops': [{'id': 3, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# sim cycle: 60323
# sim time ns: 32963
# trace path: trace/001_self_attn_qkv_proj_call_module.json
# trace event count: 6
# trace complete event count: 2
# trace complete event categories: {'prefetch': 1, 'compute': 1}
# ========================================================================================================================
# node index: 2
# node info:
# {'node_name': 'self_attn_rotary_emb',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.rotary_emb'}
# macro op count: 0
# macro op type summary: {}
# macro op details:
# simulation skipped because this node produced no macro ops
# ========================================================================================================================
# node index: 3
# node info:
# {'node_name': 'self_attn_attn',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.attn'}
# macro op count: 12
# macro op type summary: {'SramPrefetch': 4, 'FlashAttnOp': 4, 'SramPrefetchRelease': 4}
# macro op details:
# {'id': 5, 'input_ops': [], 'num_prefetch_pages': 96, 'type': 'SramPrefetch'}
# {'id': 6,
#  'input_ops': [{'id': 5, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 7,
#  'input_ops': [{'id': 6, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 8, 'input_ops': [], 'num_prefetch_pages': 96, 'type': 'SramPrefetch'}
# {'id': 9,
#  'input_ops': [{'id': 8, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 10,
#  'input_ops': [{'id': 9, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 11, 'input_ops': [], 'num_prefetch_pages': 96, 'type': 'SramPrefetch'}
# {'id': 12,
#  'input_ops': [{'id': 11, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 13,
#  'input_ops': [{'id': 12, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 14, 'input_ops': [], 'num_prefetch_pages': 96, 'type': 'SramPrefetch'}
# {'id': 15,
#  'input_ops': [{'id': 14, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 16,
#  'input_ops': [{'id': 15, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# sim cycle: 41670
# sim time ns: 22770
# trace path: trace/003_self_attn_attn_call_module.json
# trace event count: 12
# trace complete event count: 8
# trace complete event categories: {'prefetch': 4, 'compute': 4}
# ========================================================================================================================
# node index: 4
# node info:
# {'node_name': 'self_attn_o_proj',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.o_proj'}
# macro op count: 4
# macro op type summary: {'SramPrefetch': 1, 'MatMulOp': 1, 'SramPrefetchRelease': 1, 'AllReduceOp': 1}
# macro op details:
# {'id': 17, 'input_ops': [], 'num_prefetch_pages': 16384, 'type': 'SramPrefetch'}
# {'dim': (128, 2048, 16384),
#  'id': 18,
#  'input_ops': [{'id': 17, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 19,
#  'input_ops': [{'id': 18, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'data_size': 4194304,
#  'id': 20,
#  'input_ops': [{'id': 18, 'type': 'MatMulOp'}],
#  'num_ranks': 8,
#  'type': 'AllReduceOp',
#  'weight_bits': 16}
# sim cycle: 343438
# sim time ns: 187671
# trace path: trace/004_self_attn_o_proj_call_module.json
# trace event count: 7
# trace complete event count: 3
# trace complete event categories: {'prefetch': 1, 'compute': 1, 'transfer': 1}
# ========================================================================================================================
# node index: 5
# node info:
# {'node_name': 'post_attention_layernorm',
#  'node_op': 'call_module',
#  'node_target': 'post_attention_layernorm'}
# macro op count: 1
# macro op type summary: {'VectorOp': 1}
# macro op details:
# {'id': 21,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'rms_norm',
#  'vector_shape': [128, 16384],
#  'weight_bits': 16}
# sim cycle: 251
# sim time ns: 137
# trace path: trace/005_post_attention_layernorm_call_module.json
# trace event count: 5
# trace complete event count: 1
# trace complete event categories: {'compute': 1}
# ========================================================================================================================
# node index: 6
# node info:
# {'node_name': 'mlp_gate_up_proj',
#  'node_op': 'call_module',
#  'node_target': 'mlp.gate_up_proj'}
# macro op count: 18
# macro op type summary: {'SramPrefetch': 6, 'MatMulOp': 6, 'SramPrefetchRelease': 6}
# macro op details:
# {'id': 22, 'input_ops': [], 'num_prefetch_pages': 20480, 'type': 'SramPrefetch'}
# {'dim': (128, 16384, 2560),
#  'id': 23,
#  'input_ops': [{'id': 22, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 24,
#  'input_ops': [{'id': 23, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 25, 'input_ops': [], 'num_prefetch_pages': 20480, 'type': 'SramPrefetch'}
# {'dim': (128, 16384, 2560),
#  'id': 26,
#  'input_ops': [{'id': 25, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 27,
#  'input_ops': [{'id': 26, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 28, 'input_ops': [], 'num_prefetch_pages': 20480, 'type': 'SramPrefetch'}
# {'dim': (128, 16384, 2560),
#  'id': 29,
#  'input_ops': [{'id': 28, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 30,
#  'input_ops': [{'id': 29, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 31, 'input_ops': [], 'num_prefetch_pages': 20480, 'type': 'SramPrefetch'}
# {'dim': (128, 16384, 2560),
#  'id': 32,
#  'input_ops': [{'id': 31, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 33,
#  'input_ops': [{'id': 32, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 34, 'input_ops': [], 'num_prefetch_pages': 20480, 'type': 'SramPrefetch'}
# {'dim': (128, 16384, 2560),
#  'id': 35,
#  'input_ops': [{'id': 34, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 36,
#  'input_ops': [{'id': 35, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 37, 'input_ops': [], 'num_prefetch_pages': 4096, 'type': 'SramPrefetch'}
# {'dim': (128, 16384, 512),
#  'id': 38,
#  'input_ops': [{'id': 37, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 39,
#  'input_ops': [{'id': 38, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# sim cycle: 224845
# sim time ns: 122866
# trace path: trace/006_mlp_gate_up_proj_call_module.json
# trace event count: 16
# trace complete event count: 12
# trace complete event categories: {'prefetch': 6, 'compute': 6}
# ========================================================================================================================
# node index: 7
# node info:
# {'node_name': 'mlp_act_fn',
#  'node_op': 'call_module',
#  'node_target': 'mlp.act_fn'}
# macro op count: 1
# macro op type summary: {'VectorOp': 1}
# macro op details:
# {'id': 40,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [128, 6656],
#  'weight_bits': 16}
# sim cycle: 520
# sim time ns: 284
# trace path: trace/007_mlp_act_fn_call_module.json
# trace event count: 5
# trace complete event count: 1
# trace complete event categories: {'compute': 1}
# ========================================================================================================================
# node index: 8
# node info:
# {'node_name': 'mlp_down_proj',
#  'node_op': 'call_module',
#  'node_target': 'mlp.down_proj'}
# macro op count: 10
# macro op type summary: {'SramPrefetch': 3, 'MatMulOp': 3, 'SramPrefetchRelease': 3, 'AllReduceOp': 1}
# macro op details:
# {'id': 41, 'input_ops': [], 'num_prefetch_pages': 20479, 'type': 'SramPrefetch'}
# {'dim': (128, 6656, 6301),
#  'id': 42,
#  'input_ops': [{'id': 41, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 43,
#  'input_ops': [{'id': 42, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 44, 'input_ops': [], 'num_prefetch_pages': 20479, 'type': 'SramPrefetch'}
# {'dim': (128, 6656, 6301),
#  'id': 45,
#  'input_ops': [{'id': 44, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 46,
#  'input_ops': [{'id': 45, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 47, 'input_ops': [], 'num_prefetch_pages': 12292, 'type': 'SramPrefetch'}
# {'dim': (128, 6656, 3782),
#  'id': 48,
#  'input_ops': [{'id': 47, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 49,
#  'input_ops': [{'id': 48, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'data_size': 4194304,
#  'id': 50,
#  'input_ops': [{'id': 42, 'type': 'MatMulOp'},
#                {'id': 45, 'type': 'MatMulOp'},
#                {'id': 48, 'type': 'MatMulOp'}],
#  'num_ranks': 8,
#  'type': 'AllReduceOp',
#  'weight_bits': 16}
# sim cycle: 416084
# sim time ns: 227368
# trace path: trace/008_mlp_down_proj_call_module.json
# trace event count: 11
# trace complete event count: 7
# trace complete event categories: {'prefetch': 3, 'compute': 3, 'transfer': 1}

# %%
node_sim_results
# Out:
# [{'node_name': 'input_layernorm',
#   'node_op': 'call_module',
#   'node_target': 'input_layernorm',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 251,
#   'sim_time_ns': 137,
#   'trace_path': 'trace/000_input_layernorm_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 1,
#     'input_ops': [],
#     'vector_op_type': 'rms_norm',
#     'vector_shape': [128, 16384],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'self_attn_qkv_proj',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.qkv_proj',
#   'macro_op_count': 3,
#   'macro_op_types': ['SramPrefetch', 'MatMulOp', 'SramPrefetchRelease'],
#   'sim_cycle': 60323,
#   'sim_time_ns': 32963,
#   'trace_path': 'trace/001_self_attn_qkv_proj_call_module.json',
#   'trace_event_count': 6,
#   'trace_complete_event_count': 2,
#   'trace_complete_event_categories': {'prefetch': 1, 'compute': 1},
#   'macro_ops': [{'id': 2,
#     'input_ops': [],
#     'num_prefetch_pages': 18432,
#     'type': 'SramPrefetch'},
#    {'id': 3,
#     'input_ops': [{'id': 2, 'type': 'SramPrefetch'}],
#     'dim': (128, 16384, 2304),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 4,
#     'input_ops': [{'id': 3, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'}]},
#  {'node_name': 'self_attn_rotary_emb',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.rotary_emb',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []},
#  {'node_name': 'self_attn_attn',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.attn',
#   'macro_op_count': 12,
#   'macro_op_types': ['SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease'],
#   'sim_cycle': 41670,
#   'sim_time_ns': 22770,
#   'trace_path': 'trace/003_self_attn_attn_call_module.json',
#   'trace_event_count': 12,
#   'trace_complete_event_count': 8,
#   'trace_complete_event_categories': {'prefetch': 4, 'compute': 4},
#   'macro_ops': [{'id': 5,
#     'input_ops': [],
#     'num_prefetch_pages': 96,
#     'type': 'SramPrefetch'},
#    {'id': 6,
#     'input_ops': [{'id': 5, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 7,
#     'input_ops': [{'id': 6, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 8,
#     'input_ops': [],
#     'num_prefetch_pages': 96,
#     'type': 'SramPrefetch'},
#    {'id': 9,
#     'input_ops': [{'id': 8, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 10,
#     'input_ops': [{'id': 9, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 11,
#     'input_ops': [],
#     'num_prefetch_pages': 96,
#     'type': 'SramPrefetch'},
#    {'id': 12,
#     'input_ops': [{'id': 11, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 13,
#     'input_ops': [{'id': 12, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 14,
#     'input_ops': [],
#     'num_prefetch_pages': 96,
#     'type': 'SramPrefetch'},
#    {'id': 15,
#     'input_ops': [{'id': 14, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 16,
#     'input_ops': [{'id': 15, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'}]},
#  {'node_name': 'self_attn_o_proj',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.o_proj',
#   'macro_op_count': 4,
#   'macro_op_types': ['SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'AllReduceOp'],
#   'sim_cycle': 343438,
#   'sim_time_ns': 187671,
#   'trace_path': 'trace/004_self_attn_o_proj_call_module.json',
#   'trace_event_count': 7,
#   'trace_complete_event_count': 3,
#   'trace_complete_event_categories': {'prefetch': 1,
#    'compute': 1,
#    'transfer': 1},
#   'macro_ops': [{'id': 17,
#     'input_ops': [],
#     'num_prefetch_pages': 16384,
#     'type': 'SramPrefetch'},
#    {'id': 18,
#     'input_ops': [{'id': 17, 'type': 'SramPrefetch'}],
#     'dim': (128, 2048, 16384),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 19,
#     'input_ops': [{'id': 18, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 20,
#     'input_ops': [{'id': 18, 'type': 'MatMulOp'}],
#     'num_ranks': 8,
#     'data_size': 4194304,
#     'weight_bits': 16,
#     'type': 'AllReduceOp'}]},
#  {'node_name': 'post_attention_layernorm',
#   'node_op': 'call_module',
#   'node_target': 'post_attention_layernorm',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 251,
#   'sim_time_ns': 137,
#   'trace_path': 'trace/005_post_attention_layernorm_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 21,
#     'input_ops': [],
#     'vector_op_type': 'rms_norm',
#     'vector_shape': [128, 16384],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'mlp_gate_up_proj',
#   'node_op': 'call_module',
#   'node_target': 'mlp.gate_up_proj',
#   'macro_op_count': 18,
#   'macro_op_types': ['SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease'],
#   'sim_cycle': 224845,
#   'sim_time_ns': 122866,
#   'trace_path': 'trace/006_mlp_gate_up_proj_call_module.json',
#   'trace_event_count': 16,
#   'trace_complete_event_count': 12,
#   'trace_complete_event_categories': {'prefetch': 6, 'compute': 6},
#   'macro_ops': [{'id': 22,
#     'input_ops': [],
#     'num_prefetch_pages': 20480,
#     'type': 'SramPrefetch'},
#    {'id': 23,
#     'input_ops': [{'id': 22, 'type': 'SramPrefetch'}],
#     'dim': (128, 16384, 2560),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 24,
#     'input_ops': [{'id': 23, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 25,
#     'input_ops': [],
#     'num_prefetch_pages': 20480,
#     'type': 'SramPrefetch'},
#    {'id': 26,
#     'input_ops': [{'id': 25, 'type': 'SramPrefetch'}],
#     'dim': (128, 16384, 2560),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 27,
#     'input_ops': [{'id': 26, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 28,
#     'input_ops': [],
#     'num_prefetch_pages': 20480,
#     'type': 'SramPrefetch'},
#    {'id': 29,
#     'input_ops': [{'id': 28, 'type': 'SramPrefetch'}],
#     'dim': (128, 16384, 2560),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 30,
#     'input_ops': [{'id': 29, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 31,
#     'input_ops': [],
#     'num_prefetch_pages': 20480,
#     'type': 'SramPrefetch'},
#    {'id': 32,
#     'input_ops': [{'id': 31, 'type': 'SramPrefetch'}],
#     'dim': (128, 16384, 2560),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 33,
#     'input_ops': [{'id': 32, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 34,
#     'input_ops': [],
#     'num_prefetch_pages': 20480,
#     'type': 'SramPrefetch'},
#    {'id': 35,
#     'input_ops': [{'id': 34, 'type': 'SramPrefetch'}],
#     'dim': (128, 16384, 2560),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 36,
#     'input_ops': [{'id': 35, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 37,
#     'input_ops': [],
#     'num_prefetch_pages': 4096,
#     'type': 'SramPrefetch'},
#    {'id': 38,
#     'input_ops': [{'id': 37, 'type': 'SramPrefetch'}],
#     'dim': (128, 16384, 512),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 39,
#     'input_ops': [{'id': 38, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'}]},
#  {'node_name': 'mlp_act_fn',
#   'node_op': 'call_module',
#   'node_target': 'mlp.act_fn',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 520,
#   'sim_time_ns': 284,
#   'trace_path': 'trace/007_mlp_act_fn_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 40,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [128, 6656],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'mlp_down_proj',
#   'node_op': 'call_module',
#   'node_target': 'mlp.down_proj',
#   'macro_op_count': 10,
#   'macro_op_types': ['SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'AllReduceOp'],
#   'sim_cycle': 416084,
#   'sim_time_ns': 227368,
#   'trace_path': 'trace/008_mlp_down_proj_call_module.json',
#   'trace_event_count': 11,
#   'trace_complete_event_count': 7,
#   'trace_complete_event_categories': {'prefetch': 3,
#    'compute': 3,
#    'transfer': 1},
#   'macro_ops': [{'id': 41,
#     'input_ops': [],
#     'num_prefetch_pages': 20479,
#     'type': 'SramPrefetch'},
#    {'id': 42,
#     'input_ops': [{'id': 41, 'type': 'SramPrefetch'}],
#     'dim': (128, 6656, 6301),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 43,
#     'input_ops': [{'id': 42, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 44,
#     'input_ops': [],
#     'num_prefetch_pages': 20479,
#     'type': 'SramPrefetch'},
#    {'id': 45,
#     'input_ops': [{'id': 44, 'type': 'SramPrefetch'}],
#     'dim': (128, 6656, 6301),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 46,
#     'input_ops': [{'id': 45, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 47,
#     'input_ops': [],
#     'num_prefetch_pages': 12292,
#     'type': 'SramPrefetch'},
#    {'id': 48,
#     'input_ops': [{'id': 47, 'type': 'SramPrefetch'}],
#     'dim': (128, 6656, 3782),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 49,
#     'input_ops': [{'id': 48, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 50,
#     'input_ops': [{'id': 42, 'type': 'MatMulOp'},
#      {'id': 45, 'type': 'MatMulOp'},
#      {'id': 48, 'type': 'MatMulOp'}],
#     'num_ranks': 8,
#     'data_size': 4194304,
#     'weight_bits': 16,
#     'type': 'AllReduceOp'}]}]

# %%
non_empty_node_results = [result for result in node_sim_results if result["macro_op_count"] > 0]

assert non_empty_node_results
assert all(result["sim_cycle"] is not None for result in non_empty_node_results)
assert all(result["sim_time_ns"] is not None for result in non_empty_node_results)
assert all(result["trace_path"] is not None for result in non_empty_node_results)
assert all(result["trace_event_count"] is not None for result in non_empty_node_results)
assert all(result["trace_complete_event_count"] is not None for result in non_empty_node_results)

summary_rows = [
    {
        "node_name": result["node_name"],
        "node_op": result["node_op"],
        "node_target": result["node_target"],
        "macro_op_count": result["macro_op_count"],
        "macro_op_types": result["macro_op_types"],
        "sim_cycle": result["sim_cycle"],
        "sim_time_ns": result["sim_time_ns"],
        "trace_path": result["trace_path"],
        "trace_event_count": result["trace_event_count"],
        "trace_complete_event_count": result["trace_complete_event_count"],
        "trace_complete_event_categories": result["trace_complete_event_categories"],
    }
    for result in node_sim_results
]

summary_rows
# Out:
# [{'node_name': 'input_layernorm',
#   'node_op': 'call_module',
#   'node_target': 'input_layernorm',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 251,
#   'sim_time_ns': 137,
#   'trace_path': 'trace/000_input_layernorm_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1}},
#  {'node_name': 'self_attn_qkv_proj',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.qkv_proj',
#   'macro_op_count': 3,
#   'macro_op_types': ['SramPrefetch', 'MatMulOp', 'SramPrefetchRelease'],
#   'sim_cycle': 60323,
#   'sim_time_ns': 32963,
#   'trace_path': 'trace/001_self_attn_qkv_proj_call_module.json',
#   'trace_event_count': 6,
#   'trace_complete_event_count': 2,
#   'trace_complete_event_categories': {'prefetch': 1, 'compute': 1}},
#  {'node_name': 'self_attn_rotary_emb',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.rotary_emb',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None},
#  {'node_name': 'self_attn_attn',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.attn',
#   'macro_op_count': 12,
#   'macro_op_types': ['SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease'],
#   'sim_cycle': 41670,
#   'sim_time_ns': 22770,
#   'trace_path': 'trace/003_self_attn_attn_call_module.json',
#   'trace_event_count': 12,
#   'trace_complete_event_count': 8,
#   'trace_complete_event_categories': {'prefetch': 4, 'compute': 4}},
#  {'node_name': 'self_attn_o_proj',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.o_proj',
#   'macro_op_count': 4,
#   'macro_op_types': ['SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'AllReduceOp'],
#   'sim_cycle': 343438,
#   'sim_time_ns': 187671,
#   'trace_path': 'trace/004_self_attn_o_proj_call_module.json',
#   'trace_event_count': 7,
#   'trace_complete_event_count': 3,
#   'trace_complete_event_categories': {'prefetch': 1,
#    'compute': 1,
#    'transfer': 1}},
#  {'node_name': 'post_attention_layernorm',
#   'node_op': 'call_module',
#   'node_target': 'post_attention_layernorm',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 251,
#   'sim_time_ns': 137,
#   'trace_path': 'trace/005_post_attention_layernorm_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1}},
#  {'node_name': 'mlp_gate_up_proj',
#   'node_op': 'call_module',
#   'node_target': 'mlp.gate_up_proj',
#   'macro_op_count': 18,
#   'macro_op_types': ['SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease'],
#   'sim_cycle': 224845,
#   'sim_time_ns': 122866,
#   'trace_path': 'trace/006_mlp_gate_up_proj_call_module.json',
#   'trace_event_count': 16,
#   'trace_complete_event_count': 12,
#   'trace_complete_event_categories': {'prefetch': 6, 'compute': 6}},
#  {'node_name': 'mlp_act_fn',
#   'node_op': 'call_module',
#   'node_target': 'mlp.act_fn',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 520,
#   'sim_time_ns': 284,
#   'trace_path': 'trace/007_mlp_act_fn_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1}},
#  {'node_name': 'mlp_down_proj',
#   'node_op': 'call_module',
#   'node_target': 'mlp.down_proj',
#   'macro_op_count': 10,
#   'macro_op_types': ['SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'AllReduceOp'],
#   'sim_cycle': 416084,
#   'sim_time_ns': 227368,
#   'trace_path': 'trace/008_mlp_down_proj_call_module.json',
#   'trace_event_count': 11,
#   'trace_complete_event_count': 7,
#   'trace_complete_event_categories': {'prefetch': 3,
#    'compute': 3,
#    'transfer': 1}}]
