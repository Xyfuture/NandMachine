# %% [markdown]
# # Node-Level Frontend Pipeline For Llama 405B
#
# 实现 Llama 405B decoder layer 的最小前端全流程，并在 code gen pass 之后按 node 读取 `marco_op_list`，对每个 node 单独运行硬件仿真，同时对完整 `macro_op_list` 运行一次整体硬件仿真，并把 perf trace 输出到 `trace/dense/` 目录。

# %% [markdown]
# ## 流程
# - 加载 `llama-405B` model card 并初始化 `LlamaModelConfig`
# - 初始化 `NandConfig`、`InferenceConfig`，支持配置 `TP_SIZE`
# - 初始化 `LlamaDecoderLayer`
# - 使用 `NxTracer` trace 得到计算图
# - 运行 `NormalizePass` 获得简化图
# - 用 `build_kv_cache_state` 构造 `KVCacheState`
# - 构造 `NxGraphMeta` 并写入 `graph.meta`
# - 运行 `CodeGenPass`，收集全局和 node 级别的 `marco_op_list`
# - 对完整 `macro_op_list` 运行一次硬件仿真，并把完整 trace 保存到 `trace/dense/full_simulation.json`
# - 对每个 node 单独运行硬件仿真，并把 node trace 保存到 `trace/dense/` 目录
# - 汇总完整仿真和 node 级别的 macro op、时延和 trace 信息

# %%
import json
import logging
import re
from collections import Counter
from dataclasses import fields, is_dataclass
from math import ceil
from pathlib import Path
from pprint import pprint

import torch
from Desim import SimSession
from torch.fx import GraphModule

from nandmachine.commands.macro import AllReduceOp, FlashAttnOp, MacroOp, MatMulOp, VectorOp
from nandmachine.config.config import NandConfig
from nandmachine.config.hardware_config import get_device_or_raise
from nandmachine.config.inference_config import DenseParallelConfig, InferenceConfig
from nandmachine.config.model_config import LlamaModelConfig
from nandmachine.frontend.core.graph.base import NxGraphMeta, NxTracer
from nandmachine.frontend.core.passes.cod_gen import CodeGenPass
from nandmachine.frontend.core.passes.normalize import NormalizePass
from nandmachine.frontend.network.llama import LlamaDecoderLayer
from nandmachine.frontend.utlis import build_kv_cache_state
from nandmachine.simulator.hardware.xpu import xPU

MODEL_CARD_PATH = Path("model_cards/llama-405B.json")
DEVICE_NAME = "H100_SXM"
COMPILE_MODE = "heuristic-GPU"
TP_SIZE = 8
HBM_BANDWIDTH_GBPS = 3350
TRACE_DIR = Path("trace/dense")
FULL_TRACE_FILE_NAME = "full_simulation.json"

assert MODEL_CARD_PATH.exists(), MODEL_CARD_PATH
assert TP_SIZE > 0, TP_SIZE


def node_summary(graph_module: GraphModule) -> list[tuple[str, str, str]]:
    return [(node.name, node.op, str(node.target)) for node in graph_module.graph.nodes]


def macro_summary(macro_op_list: list[object]) -> Counter:
    return Counter(type(op).__name__ for op in macro_op_list)


def node_info(node: torch.fx.Node) -> dict[str, object]:
    return {
        "node_name": node.name,
        "node_op": node.op,
        "node_target": str(node.target),
    }


def _serialize_value(value: object) -> object:
    if isinstance(value, MacroOp):
        return {
            "id": value.id,
            "type": type(value).__name__,
        }
    if isinstance(value, list):
        return [_serialize_value(item) for item in value]
    if isinstance(value, tuple):
        return tuple(_serialize_value(item) for item in value)
    return value


def macro_info(op: MacroOp) -> dict[str, object]:
    assert is_dataclass(op), type(op)
    payload = {field.name: _serialize_value(getattr(op, field.name)) for field in fields(op)}
    payload["type"] = type(op).__name__
    return payload


def _sanitize_trace_name(raw_name: str) -> str:
    return re.sub(r"[^0-9A-Za-z._-]+", "_", raw_name).strip("._")


def trace_file_path(node_index: int, node: torch.fx.Node) -> Path:
    file_name = _sanitize_trace_name(f"node_{node_index:03d}_{node.name}_{node.op}")
    return TRACE_DIR / f"{file_name}.json"


def full_trace_file_path() -> Path:
    return TRACE_DIR / FULL_TRACE_FILE_NAME


def run_macro_ops_with_trace(
    nand_config: NandConfig,
    commands: list[MacroOp],
    *,
    trace_path: Path,
    device_name: str,
    compile_mode: str,
    hbm_bandwidth_GBps: float,
) -> dict[str, object]:
    SimSession.reset()
    SimSession.init()

    hbm_bandwidth_bytes_per_sec = hbm_bandwidth_GBps * 10**9

    sim_xpu = xPU(
        nand_config,
        hbm_bandwidth_bytes_per_sec=hbm_bandwidth_bytes_per_sec,
        device_name=device_name,
        compile_mode=compile_mode,
        enable_trace=True,
    )
    sim_xpu.load_command(commands)
    SimSession.scheduler.run()

    final_time_ns = int(SimSession.sim_time.cycle)
    device = get_device_or_raise(device_name)
    final_cycle = ceil(final_time_ns * device.compute_module.clock_freq / 1e9)

    trace_path.parent.mkdir(parents=True, exist_ok=True)
    saved_trace_path = Path(sim_xpu.save_trace_file(str(trace_path)))

    tracer = sim_xpu.tracer
    assert tracer is not None
    complete_events = [event for event in tracer._events if event["ph"] == "X"]

    return {
        "cycle": final_cycle,
        "time_ns": final_time_ns,
        "trace_path": str(saved_trace_path),
        "trace_event_count": len(tracer._events),
        "trace_complete_event_count": len(complete_events),
        "trace_complete_event_categories": dict(
            Counter(event["cat"] for event in complete_events)
        ),
    }

# %%
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
)

model_config = LlamaModelConfig.from_dict(json.loads(MODEL_CARD_PATH.read_text()))

parallel_config = DenseParallelConfig(
    num_ranks=TP_SIZE,
    tp_size=TP_SIZE,
    dp_size=1,
)
inference_config = InferenceConfig(
    batch_size=512, # 总的 batch size
    input_sequence_length=8096,
    output_sequence_length=1024,
    weight_bits=16,
    activation_bits=16,
    kv_cache_bits=16,
    kv_block_size_bytes=1024 * 256,  # bytes
    memory_backend="nand",
    parallel_config=parallel_config,
)
kv_cache_state = build_kv_cache_state(nand_config, model_config, inference_config)
graph_meta = NxGraphMeta(
    nand_config=nand_config,
    model_config=model_config,
    inference_config=inference_config,
    kv_cache_state=kv_cache_state,
)
simulator_config = {
    "device_name": DEVICE_NAME,
    "compile_mode": COMPILE_MODE,
    "hbm_bandwidth_GBps": HBM_BANDWIDTH_GBPS,
}
runtime_simulator_config = {
    "device_name": simulator_config["device_name"],
    "compile_mode": simulator_config["compile_mode"],
    "hbm_bandwidth_GBps": simulator_config["hbm_bandwidth_GBps"],
}
TRACE_DIR.mkdir(parents=True, exist_ok=True)

print("HBM bandwidth (GBps):", HBM_BANDWIDTH_GBPS)
print("trace output dir:", TRACE_DIR)
print("full simulation trace path:", full_trace_file_path())
# Out:
# HBM bandwidth (GBps): 3350
# trace output dir: trace/dense
# full simulation trace path: trace/dense/full_simulation.json

# %%
with torch.device("meta"):
    model = LlamaDecoderLayer(model_config, tp_size=TP_SIZE)
    graph = NxTracer().trace(model)
    graph_module = GraphModule(model, graph)

NormalizePass().transform(graph_module)
graph_module.graph.meta = {CodeGenPass.GRAPH_META_KEY: graph_meta}
CodeGenPass().transform(graph_module)

all_graph_nodes = list(graph_module.graph.nodes)
all_node_infos = [node_info(node) for node in all_graph_nodes]
node_count_with_macro_ops = sum(1 for node in all_graph_nodes if "marco_op_list" in node.meta)
macro_op_list = graph_module.graph.meta[CodeGenPass.MACRO_OP_LIST_META_KEY]
vector_ops = [op for op in macro_op_list if isinstance(op, VectorOp)]

print("normalized node count:", len(node_summary(graph_module)))
print("node count with macro op entries:", node_count_with_macro_ops)
print("global macro op count:", len(macro_op_list))
print("global macro op type summary:", dict(macro_summary(macro_op_list)))
print("all node infos:")
for current_node_info in all_node_infos:
    pprint(current_node_info)
# Out:
# 2026-04-05 19:17:56,207 - INFO - Processed node=input_layernorm generated_macro_ops=1
# 2026-04-05 19:17:56,208 - INFO - Processed node=self_attn_qkv_proj generated_macro_ops=3
# 2026-04-05 19:17:56,209 - INFO - Processed node=self_attn_rotary_emb generated_macro_ops=0
# 2026-04-05 19:17:56,213 - INFO - Processed node=self_attn_attn generated_macro_ops=381
# 2026-04-05 19:17:56,213 - INFO - Processed node=self_attn_o_proj generated_macro_ops=4
# 2026-04-05 19:17:56,213 - INFO - Processed node=post_attention_layernorm generated_macro_ops=1
# 2026-04-05 19:17:56,214 - INFO - Processed node=mlp_gate_up_proj generated_macro_ops=18
# 2026-04-05 19:17:56,214 - INFO - Processed node=mlp_act_fn generated_macro_ops=1
# 2026-04-05 19:17:56,215 - INFO - Processed node=mlp_down_proj generated_macro_ops=10
# normalized node count: 13
# node count with macro op entries: 9
# global macro op count: 419
# global macro op type summary: {'VectorOp': 3, 'SramPrefetch': 138, 'MatMulOp': 11, 'SramPrefetchRelease': 138, 'FlashAttnOp': 127, 'AllReduceOp': 2}
# all node infos:
# {'node_name': 'hidden_states',
#  'node_op': 'placeholder',
#  'node_target': 'hidden_states'}
# {'node_name': 'input_layernorm',
#  'node_op': 'call_module',
#  'node_target': 'input_layernorm'}
# {'node_name': 'self_attn_qkv_proj',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.qkv_proj'}
# {'node_name': 'self_attn__dummy_positions',
#  'node_op': 'get_attr',
#  'node_target': 'self_attn._dummy_positions'}
# {'node_name': 'self_attn_rotary_emb',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.rotary_emb'}
# {'node_name': 'self_attn_attn',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.attn'}
# {'node_name': 'self_attn_o_proj',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.o_proj'}
# {'node_name': 'add',
#  'node_op': 'call_function',
#  'node_target': '<built-in function add>'}
# {'node_name': 'post_attention_layernorm',
#  'node_op': 'call_module',
#  'node_target': 'post_attention_layernorm'}
# {'node_name': 'mlp_gate_up_proj',
#  'node_op': 'call_module',
#  'node_target': 'mlp.gate_up_proj'}
# {'node_name': 'mlp_act_fn',
#  'node_op': 'call_module',
#  'node_target': 'mlp.act_fn'}
# {'node_name': 'mlp_down_proj',
#  'node_op': 'call_module',
#  'node_target': 'mlp.down_proj'}
# {'node_name': 'add_1',
#  'node_op': 'call_function',
#  'node_target': '<built-in function add>'}

# %%
assert macro_op_list
assert all_graph_nodes
assert node_count_with_macro_ops > 0
assert any(isinstance(op, MatMulOp) for op in macro_op_list)
assert any(isinstance(op, FlashAttnOp) for op in macro_op_list)
assert any(op.vector_op_type == "rms_norm" for op in vector_ops)
assert any(op.vector_op_type == "silu_mul" for op in vector_ops)
assert all(all(dim > 0 for dim in op.vector_shape) for op in vector_ops)
if TP_SIZE > 1:
    assert any(isinstance(op, AllReduceOp) for op in macro_op_list)

print("dense node-level frontend pipeline completed successfully")
# Out:
# dense node-level frontend pipeline completed successfully

# %%
print("=" * 120)
print("full simulation")
print("macro op count:", len(macro_op_list))
print("macro op type summary:", dict(macro_summary(macro_op_list)))

full_trace_path = full_trace_file_path()
full_sim_result = run_macro_ops_with_trace(
    nand_config,
    macro_op_list,
    trace_path=full_trace_path,
    **runtime_simulator_config,
)
assert full_sim_result["cycle"] > 0
assert full_sim_result["time_ns"] > 0
print("sim cycle:", full_sim_result["cycle"])
print("sim time ns:", full_sim_result["time_ns"])
print("trace path:", full_sim_result["trace_path"])
print("trace event count:", full_sim_result["trace_event_count"])
print("trace complete event count:", full_sim_result["trace_complete_event_count"])
print(
    "trace complete event categories:",
    full_sim_result["trace_complete_event_categories"],
)

node_sim_results = []

for node_index, node in enumerate(all_graph_nodes):
    node_macro_ops = node.meta.get("marco_op_list", [])
    current_node_info = node_info(node)
    current_macro_summary = dict(macro_summary(node_macro_ops))

    print("=" * 120)
    print("node index:", node_index)
    print("node info:")
    pprint(current_node_info)
    print("macro op count:", len(node_macro_ops))
    print("macro op type summary:", current_macro_summary)

    serialized_macro_ops = [macro_info(op) for op in node_macro_ops]
    print("macro op details:")
    for macro_op_payload in serialized_macro_ops:
        pprint(macro_op_payload)

    if not node_macro_ops:
        print("simulation skipped because this node produced no macro ops")
        node_sim_results.append(
            {
                **current_node_info,
                "macro_op_count": 0,
                "macro_op_types": [],
                "sim_cycle": None,
                "sim_time_ns": None,
                "trace_path": None,
                "trace_event_count": None,
                "trace_complete_event_count": None,
                "trace_complete_event_categories": None,
                "macro_ops": serialized_macro_ops,
            }
        )
        continue

    current_trace_path = trace_file_path(node_index, node)
    sim_result = run_macro_ops_with_trace(
        nand_config,
        node_macro_ops,
        trace_path=current_trace_path,
        **runtime_simulator_config,
    )
    assert sim_result["cycle"] > 0
    assert sim_result["time_ns"] > 0
    print("sim cycle:", sim_result["cycle"])
    print("sim time ns:", sim_result["time_ns"])
    print("trace path:", sim_result["trace_path"])
    print("trace event count:", sim_result["trace_event_count"])
    print("trace complete event count:", sim_result["trace_complete_event_count"])
    print(
        "trace complete event categories:",
        sim_result["trace_complete_event_categories"],
    )

    node_sim_results.append(
        {
            **current_node_info,
            "macro_op_count": len(node_macro_ops),
            "macro_op_types": [type(op).__name__ for op in node_macro_ops],
            "sim_cycle": sim_result["cycle"],
            "sim_time_ns": sim_result["time_ns"],
            "trace_path": sim_result["trace_path"],
            "trace_event_count": sim_result["trace_event_count"],
            "trace_complete_event_count": sim_result["trace_complete_event_count"],
            "trace_complete_event_categories": sim_result[
                "trace_complete_event_categories"
            ],
            "macro_ops": serialized_macro_ops,
        }
    )
# Out:
# ========================================================================================================================
# full simulation
# macro op count: 419
# macro op type summary: {'VectorOp': 3, 'SramPrefetch': 138, 'MatMulOp': 11, 'SramPrefetchRelease': 138, 'FlashAttnOp': 127, 'AllReduceOp': 2}
# VectorOp(id=135, input_ops=[], vector_op_type='rms_norm', vector_shape=[512, 16384], weight_bits=16)
# MatMulOp(id=137, input_ops=[SramPrefetch(id=136, input_ops=[], num_prefetch_pages=18432), VectorOp(id=135, input_ops=[], vector_op_type='rms_norm', vector_shape=[512, 16384], weight_bits=16)], dim=(512, 16384, 2304), weight_bits=16)
# FlashAttnOp(id=140, input_ops=[SramPrefetch(id=139, input_ops=[], num_prefetch_pages=4608), MatMulOp(id=137, input_ops=[SramPrefetch(id=136, input_ops=[], num_prefetch_pages=18432), VectorOp(id=135, input_ops=[], vector_op_type='rms_norm', vector_shape=[512, 16384], weight_bits=16)], dim=(512, 16384, 2304), weight_bits=16)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=143, input_ops=[SramPrefetch(id=142, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=146, input_ops=[SramPrefetch(id=145, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=149, input_ops=[SramPrefetch(id=148, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=152, input_ops=[SramPrefetch(id=151, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=155, input_ops=[SramPrefetch(id=154, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=158, input_ops=[SramPrefetch(id=157, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=161, input_ops=[SramPrefetch(id=160, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=164, input_ops=[SramPrefetch(id=163, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=167, input_ops=[SramPrefetch(id=166, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=170, input_ops=[SramPrefetch(id=169, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=173, input_ops=[SramPrefetch(id=172, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=176, input_ops=[SramPrefetch(id=175, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=179, input_ops=[SramPrefetch(id=178, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=182, input_ops=[SramPrefetch(id=181, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=185, input_ops=[SramPrefetch(id=184, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=188, input_ops=[SramPrefetch(id=187, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=191, input_ops=[SramPrefetch(id=190, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=194, input_ops=[SramPrefetch(id=193, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=197, input_ops=[SramPrefetch(id=196, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=200, input_ops=[SramPrefetch(id=199, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=203, input_ops=[SramPrefetch(id=202, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=206, input_ops=[SramPrefetch(id=205, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=209, input_ops=[SramPrefetch(id=208, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=212, input_ops=[SramPrefetch(id=211, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=215, input_ops=[SramPrefetch(id=214, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=218, input_ops=[SramPrefetch(id=217, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=221, input_ops=[SramPrefetch(id=220, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=224, input_ops=[SramPrefetch(id=223, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=227, input_ops=[SramPrefetch(id=226, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=230, input_ops=[SramPrefetch(id=229, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=233, input_ops=[SramPrefetch(id=232, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=236, input_ops=[SramPrefetch(id=235, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=239, input_ops=[SramPrefetch(id=238, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=242, input_ops=[SramPrefetch(id=241, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=245, input_ops=[SramPrefetch(id=244, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=248, input_ops=[SramPrefetch(id=247, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=251, input_ops=[SramPrefetch(id=250, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=254, input_ops=[SramPrefetch(id=253, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=257, input_ops=[SramPrefetch(id=256, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=260, input_ops=[SramPrefetch(id=259, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=263, input_ops=[SramPrefetch(id=262, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=266, input_ops=[SramPrefetch(id=265, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=269, input_ops=[SramPrefetch(id=268, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=272, input_ops=[SramPrefetch(id=271, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=275, input_ops=[SramPrefetch(id=274, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=278, input_ops=[SramPrefetch(id=277, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=281, input_ops=[SramPrefetch(id=280, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=284, input_ops=[SramPrefetch(id=283, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=287, input_ops=[SramPrefetch(id=286, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=290, input_ops=[SramPrefetch(id=289, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=293, input_ops=[SramPrefetch(id=292, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=296, input_ops=[SramPrefetch(id=295, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=299, input_ops=[SramPrefetch(id=298, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=302, input_ops=[SramPrefetch(id=301, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=305, input_ops=[SramPrefetch(id=304, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=308, input_ops=[SramPrefetch(id=307, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=311, input_ops=[SramPrefetch(id=310, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=314, input_ops=[SramPrefetch(id=313, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=317, input_ops=[SramPrefetch(id=316, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=320, input_ops=[SramPrefetch(id=319, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=323, input_ops=[SramPrefetch(id=322, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=326, input_ops=[SramPrefetch(id=325, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=329, input_ops=[SramPrefetch(id=328, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=332, input_ops=[SramPrefetch(id=331, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=335, input_ops=[SramPrefetch(id=334, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=338, input_ops=[SramPrefetch(id=337, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=341, input_ops=[SramPrefetch(id=340, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=344, input_ops=[SramPrefetch(id=343, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=347, input_ops=[SramPrefetch(id=346, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=350, input_ops=[SramPrefetch(id=349, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=353, input_ops=[SramPrefetch(id=352, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=356, input_ops=[SramPrefetch(id=355, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=359, input_ops=[SramPrefetch(id=358, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=362, input_ops=[SramPrefetch(id=361, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=365, input_ops=[SramPrefetch(id=364, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=368, input_ops=[SramPrefetch(id=367, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=371, input_ops=[SramPrefetch(id=370, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=374, input_ops=[SramPrefetch(id=373, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=377, input_ops=[SramPrefetch(id=376, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=380, input_ops=[SramPrefetch(id=379, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=383, input_ops=[SramPrefetch(id=382, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=386, input_ops=[SramPrefetch(id=385, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=389, input_ops=[SramPrefetch(id=388, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=392, input_ops=[SramPrefetch(id=391, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=395, input_ops=[SramPrefetch(id=394, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=398, input_ops=[SramPrefetch(id=397, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=401, input_ops=[SramPrefetch(id=400, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=404, input_ops=[SramPrefetch(id=403, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=407, input_ops=[SramPrefetch(id=406, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=410, input_ops=[SramPrefetch(id=409, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=413, input_ops=[SramPrefetch(id=412, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=416, input_ops=[SramPrefetch(id=415, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=419, input_ops=[SramPrefetch(id=418, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=422, input_ops=[SramPrefetch(id=421, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=425, input_ops=[SramPrefetch(id=424, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=428, input_ops=[SramPrefetch(id=427, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=431, input_ops=[SramPrefetch(id=430, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=434, input_ops=[SramPrefetch(id=433, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=437, input_ops=[SramPrefetch(id=436, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=440, input_ops=[SramPrefetch(id=439, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=443, input_ops=[SramPrefetch(id=442, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=446, input_ops=[SramPrefetch(id=445, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=449, input_ops=[SramPrefetch(id=448, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=452, input_ops=[SramPrefetch(id=451, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=455, input_ops=[SramPrefetch(id=454, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=458, input_ops=[SramPrefetch(id=457, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=461, input_ops=[SramPrefetch(id=460, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=464, input_ops=[SramPrefetch(id=463, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=467, input_ops=[SramPrefetch(id=466, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=470, input_ops=[SramPrefetch(id=469, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=473, input_ops=[SramPrefetch(id=472, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=476, input_ops=[SramPrefetch(id=475, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=479, input_ops=[SramPrefetch(id=478, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=482, input_ops=[SramPrefetch(id=481, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=485, input_ops=[SramPrefetch(id=484, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=488, input_ops=[SramPrefetch(id=487, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=491, input_ops=[SramPrefetch(id=490, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=494, input_ops=[SramPrefetch(id=493, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=497, input_ops=[SramPrefetch(id=496, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=500, input_ops=[SramPrefetch(id=499, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=503, input_ops=[SramPrefetch(id=502, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=506, input_ops=[SramPrefetch(id=505, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=509, input_ops=[SramPrefetch(id=508, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=512, input_ops=[SramPrefetch(id=511, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=515, input_ops=[SramPrefetch(id=514, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=518, input_ops=[SramPrefetch(id=517, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# MatMulOp(id=521, input_ops=[SramPrefetch(id=520, input_ops=[], num_prefetch_pages=16384), FlashAttnOp(id=518, input_ops=[SramPrefetch(id=517, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)], dim=(512, 2048, 16384), weight_bits=16)
# VectorOp(id=524, input_ops=[AllReduceOp(id=523, input_ops=[MatMulOp(id=521, input_ops=[SramPrefetch(id=520, input_ops=[], num_prefetch_pages=16384), FlashAttnOp(id=518, input_ops=[SramPrefetch(id=517, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)], dim=(512, 2048, 16384), weight_bits=16)], num_ranks=8, data_size=16777216, weight_bits=16)], vector_op_type='rms_norm', vector_shape=[512, 16384], weight_bits=16)
# MatMulOp(id=526, input_ops=[SramPrefetch(id=525, input_ops=[], num_prefetch_pages=20480), VectorOp(id=524, input_ops=[AllReduceOp(id=523, input_ops=[MatMulOp(id=521, input_ops=[SramPrefetch(id=520, input_ops=[], num_prefetch_pages=16384), FlashAttnOp(id=518, input_ops=[SramPrefetch(id=517, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)], dim=(512, 2048, 16384), weight_bits=16)], num_ranks=8, data_size=16777216, weight_bits=16)], vector_op_type='rms_norm', vector_shape=[512, 16384], weight_bits=16)], dim=(512, 16384, 2560), weight_bits=16)
# MatMulOp(id=529, input_ops=[SramPrefetch(id=528, input_ops=[], num_prefetch_pages=20480)], dim=(512, 16384, 2560), weight_bits=16)
# MatMulOp(id=532, input_ops=[SramPrefetch(id=531, input_ops=[], num_prefetch_pages=20480)], dim=(512, 16384, 2560), weight_bits=16)
# MatMulOp(id=535, input_ops=[SramPrefetch(id=534, input_ops=[], num_prefetch_pages=20480)], dim=(512, 16384, 2560), weight_bits=16)
# MatMulOp(id=538, input_ops=[SramPrefetch(id=537, input_ops=[], num_prefetch_pages=20480)], dim=(512, 16384, 2560), weight_bits=16)
# MatMulOp(id=541, input_ops=[SramPrefetch(id=540, input_ops=[], num_prefetch_pages=4096)], dim=(512, 16384, 512), weight_bits=16)
# VectorOp(id=543, input_ops=[MatMulOp(id=541, input_ops=[SramPrefetch(id=540, input_ops=[], num_prefetch_pages=4096)], dim=(512, 16384, 512), weight_bits=16)], vector_op_type='silu_mul', vector_shape=[512, 6656], weight_bits=16)
# MatMulOp(id=545, input_ops=[SramPrefetch(id=544, input_ops=[], num_prefetch_pages=20479), VectorOp(id=543, input_ops=[MatMulOp(id=541, input_ops=[SramPrefetch(id=540, input_ops=[], num_prefetch_pages=4096)], dim=(512, 16384, 512), weight_bits=16)], vector_op_type='silu_mul', vector_shape=[512, 6656], weight_bits=16)], dim=(512, 6656, 6301), weight_bits=16)
# MatMulOp(id=548, input_ops=[SramPrefetch(id=547, input_ops=[], num_prefetch_pages=20479)], dim=(512, 6656, 6301), weight_bits=16)
# MatMulOp(id=551, input_ops=[SramPrefetch(id=550, input_ops=[], num_prefetch_pages=12292)], dim=(512, 6656, 3782), weight_bits=16)
# sim cycle: 4149990
# sim time ns: 2267754
# trace path: trace/dense/full_simulation.json
# trace event count: 285
# trace complete event count: 281
# trace complete event categories: {'compute': 141, 'prefetch': 138, 'transfer': 2}
# ========================================================================================================================
# node index: 0
# node info:
# {'node_name': 'hidden_states',
#  'node_op': 'placeholder',
#  'node_target': 'hidden_states'}
# macro op count: 0
# macro op type summary: {}
# macro op details:
# simulation skipped because this node produced no macro ops
# ========================================================================================================================
# node index: 1
# node info:
# {'node_name': 'input_layernorm',
#  'node_op': 'call_module',
#  'node_target': 'input_layernorm'}
# macro op count: 1
# macro op type summary: {'VectorOp': 1}
# macro op details:
# {'id': 135,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'rms_norm',
#  'vector_shape': [512, 16384],
#  'weight_bits': 16}
# VectorOp(id=135, input_ops=[], vector_op_type='rms_norm', vector_shape=[512, 16384], weight_bits=16)
# sim cycle: 996
# sim time ns: 544
# trace path: trace/dense/node_001_input_layernorm_call_module.json
# trace event count: 5
# trace complete event count: 1
# trace complete event categories: {'compute': 1}
# ========================================================================================================================
# node index: 2
# node info:
# {'node_name': 'self_attn_qkv_proj',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.qkv_proj'}
# macro op count: 3
# macro op type summary: {'SramPrefetch': 1, 'MatMulOp': 1, 'SramPrefetchRelease': 1}
# macro op details:
# {'id': 136,
#  'input_ops': [],
#  'num_prefetch_pages': 18432,
#  'type': 'SramPrefetch'}
# {'dim': (512, 16384, 2304),
#  'id': 137,
#  'input_ops': [{'id': 136, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 138,
#  'input_ops': [{'id': 137, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# MatMulOp(id=137, input_ops=[SramPrefetch(id=136, input_ops=[], num_prefetch_pages=18432)], dim=(512, 16384, 2304), weight_bits=16)
# sim cycle: 116793
# sim time ns: 63821
# trace path: trace/dense/node_002_self_attn_qkv_proj_call_module.json
# trace event count: 6
# trace complete event count: 2
# trace complete event categories: {'prefetch': 1, 'compute': 1}
# ========================================================================================================================
# node index: 3
# node info:
# {'node_name': 'self_attn__dummy_positions',
#  'node_op': 'get_attr',
#  'node_target': 'self_attn._dummy_positions'}
# macro op count: 0
# macro op type summary: {}
# macro op details:
# simulation skipped because this node produced no macro ops
# ========================================================================================================================
# node index: 4
# node info:
# {'node_name': 'self_attn_rotary_emb',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.rotary_emb'}
# macro op count: 0
# macro op type summary: {}
# macro op details:
# simulation skipped because this node produced no macro ops
# ========================================================================================================================
# node index: 5
# node info:
# {'node_name': 'self_attn_attn',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.attn'}
# macro op count: 381
# macro op type summary: {'SramPrefetch': 127, 'FlashAttnOp': 127, 'SramPrefetchRelease': 127}
# macro op details:
# {'id': 139, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 140,
#  'input_ops': [{'id': 139, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 141,
#  'input_ops': [{'id': 140, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 142, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 143,
#  'input_ops': [{'id': 142, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 144,
#  'input_ops': [{'id': 143, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 145, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 146,
#  'input_ops': [{'id': 145, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 147,
#  'input_ops': [{'id': 146, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 148, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 149,
#  'input_ops': [{'id': 148, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 150,
#  'input_ops': [{'id': 149, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 151, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 152,
#  'input_ops': [{'id': 151, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 153,
#  'input_ops': [{'id': 152, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 154, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 155,
#  'input_ops': [{'id': 154, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 156,
#  'input_ops': [{'id': 155, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 157, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 158,
#  'input_ops': [{'id': 157, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 159,
#  'input_ops': [{'id': 158, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 160, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 161,
#  'input_ops': [{'id': 160, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 162,
#  'input_ops': [{'id': 161, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 163, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 164,
#  'input_ops': [{'id': 163, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 165,
#  'input_ops': [{'id': 164, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 166, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 167,
#  'input_ops': [{'id': 166, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 168,
#  'input_ops': [{'id': 167, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 169, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 170,
#  'input_ops': [{'id': 169, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 171,
#  'input_ops': [{'id': 170, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 172, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 173,
#  'input_ops': [{'id': 172, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 174,
#  'input_ops': [{'id': 173, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 175, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 176,
#  'input_ops': [{'id': 175, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 177,
#  'input_ops': [{'id': 176, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 178, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 179,
#  'input_ops': [{'id': 178, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 180,
#  'input_ops': [{'id': 179, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 181, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 182,
#  'input_ops': [{'id': 181, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 183,
#  'input_ops': [{'id': 182, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 184, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 185,
#  'input_ops': [{'id': 184, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 186,
#  'input_ops': [{'id': 185, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 187, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 188,
#  'input_ops': [{'id': 187, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 189,
#  'input_ops': [{'id': 188, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 190, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 191,
#  'input_ops': [{'id': 190, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 192,
#  'input_ops': [{'id': 191, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 193, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 194,
#  'input_ops': [{'id': 193, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 195,
#  'input_ops': [{'id': 194, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 196, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 197,
#  'input_ops': [{'id': 196, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 198,
#  'input_ops': [{'id': 197, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 199, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 200,
#  'input_ops': [{'id': 199, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 201,
#  'input_ops': [{'id': 200, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 202, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 203,
#  'input_ops': [{'id': 202, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 204,
#  'input_ops': [{'id': 203, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 205, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 206,
#  'input_ops': [{'id': 205, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 207,
#  'input_ops': [{'id': 206, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 208, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 209,
#  'input_ops': [{'id': 208, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 210,
#  'input_ops': [{'id': 209, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 211, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 212,
#  'input_ops': [{'id': 211, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 213,
#  'input_ops': [{'id': 212, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 214, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 215,
#  'input_ops': [{'id': 214, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 216,
#  'input_ops': [{'id': 215, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 217, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 218,
#  'input_ops': [{'id': 217, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 219,
#  'input_ops': [{'id': 218, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 220, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 221,
#  'input_ops': [{'id': 220, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 222,
#  'input_ops': [{'id': 221, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 223, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 224,
#  'input_ops': [{'id': 223, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 225,
#  'input_ops': [{'id': 224, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 226, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 227,
#  'input_ops': [{'id': 226, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 228,
#  'input_ops': [{'id': 227, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 229, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 230,
#  'input_ops': [{'id': 229, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 231,
#  'input_ops': [{'id': 230, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 232, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 233,
#  'input_ops': [{'id': 232, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 234,
#  'input_ops': [{'id': 233, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 235, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 236,
#  'input_ops': [{'id': 235, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 237,
#  'input_ops': [{'id': 236, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 238, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 239,
#  'input_ops': [{'id': 238, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 240,
#  'input_ops': [{'id': 239, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 241, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 242,
#  'input_ops': [{'id': 241, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 243,
#  'input_ops': [{'id': 242, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 244, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 245,
#  'input_ops': [{'id': 244, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 246,
#  'input_ops': [{'id': 245, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 247, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 248,
#  'input_ops': [{'id': 247, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 249,
#  'input_ops': [{'id': 248, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 250, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 251,
#  'input_ops': [{'id': 250, 'type': 'SramPrefetch'}],
#  'qk_bmm_shape': (72, 16, 128, 512),
#  'softmax_shape': (1152, 512),
#  'sv_bmm_shape': (72, 16, 512, 128),
#  'type': 'FlashAttnOp',
#  'weight_bits': 16}
# {'id': 252,
#  'input_ops': [{'id': 251, 'type': 'FlashAttnOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 253, 'input_ops': [], 'num_prefetch_pages': 4608, 'type': 'SramPrefetch'}
# {'id': 254,
# ...
# FlashAttnOp(id=419, input_ops=[SramPrefetch(id=418, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=422, input_ops=[SramPrefetch(id=421, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=425, input_ops=[SramPrefetch(id=424, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=428, input_ops=[SramPrefetch(id=427, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=431, input_ops=[SramPrefetch(id=430, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=434, input_ops=[SramPrefetch(id=433, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=437, input_ops=[SramPrefetch(id=436, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=440, input_ops=[SramPrefetch(id=439, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=443, input_ops=[SramPrefetch(id=442, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=446, input_ops=[SramPrefetch(id=445, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=449, input_ops=[SramPrefetch(id=448, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=452, input_ops=[SramPrefetch(id=451, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=455, input_ops=[SramPrefetch(id=454, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=458, input_ops=[SramPrefetch(id=457, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=461, input_ops=[SramPrefetch(id=460, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=464, input_ops=[SramPrefetch(id=463, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=467, input_ops=[SramPrefetch(id=466, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=470, input_ops=[SramPrefetch(id=469, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=473, input_ops=[SramPrefetch(id=472, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=476, input_ops=[SramPrefetch(id=475, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=479, input_ops=[SramPrefetch(id=478, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=482, input_ops=[SramPrefetch(id=481, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=485, input_ops=[SramPrefetch(id=484, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=488, input_ops=[SramPrefetch(id=487, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=491, input_ops=[SramPrefetch(id=490, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=494, input_ops=[SramPrefetch(id=493, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=497, input_ops=[SramPrefetch(id=496, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=500, input_ops=[SramPrefetch(id=499, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=503, input_ops=[SramPrefetch(id=502, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=506, input_ops=[SramPrefetch(id=505, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=509, input_ops=[SramPrefetch(id=508, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=512, input_ops=[SramPrefetch(id=511, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=515, input_ops=[SramPrefetch(id=514, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# FlashAttnOp(id=518, input_ops=[SramPrefetch(id=517, input_ops=[], num_prefetch_pages=4608)], qk_bmm_shape=(72, 16, 128, 512), sv_bmm_shape=(72, 16, 512, 128), softmax_shape=(1152, 512), weight_bits=16)
# sim cycle: 1097792
# sim time ns: 599886
# trace path: trace/dense/node_005_self_attn_attn_call_module.json
# trace event count: 258
# trace complete event count: 254
# trace complete event categories: {'prefetch': 127, 'compute': 127}
# ========================================================================================================================
# node index: 6
# node info:
# {'node_name': 'self_attn_o_proj',
#  'node_op': 'call_module',
#  'node_target': 'self_attn.o_proj'}
# macro op count: 4
# macro op type summary: {'SramPrefetch': 1, 'MatMulOp': 1, 'SramPrefetchRelease': 1, 'AllReduceOp': 1}
# macro op details:
# {'id': 520,
#  'input_ops': [],
#  'num_prefetch_pages': 16384,
#  'type': 'SramPrefetch'}
# {'dim': (512, 2048, 16384),
#  'id': 521,
#  'input_ops': [{'id': 520, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 522,
#  'input_ops': [{'id': 521, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'data_size': 16777216,
#  'id': 523,
#  'input_ops': [{'id': 521, 'type': 'MatMulOp'}],
#  'num_ranks': 8,
#  'type': 'AllReduceOp',
#  'weight_bits': 16}
# MatMulOp(id=521, input_ops=[SramPrefetch(id=520, input_ops=[], num_prefetch_pages=16384)], dim=(512, 2048, 16384), weight_bits=16)
# sim cycle: 1153320
# sim time ns: 630229
# trace path: trace/dense/node_006_self_attn_o_proj_call_module.json
# trace event count: 7
# trace complete event count: 3
# trace complete event categories: {'prefetch': 1, 'compute': 1, 'transfer': 1}
# ========================================================================================================================
# node index: 7
# node info:
# {'node_name': 'add',
#  'node_op': 'call_function',
#  'node_target': '<built-in function add>'}
# macro op count: 0
# macro op type summary: {}
# macro op details:
# simulation skipped because this node produced no macro ops
# ========================================================================================================================
# node index: 8
# node info:
# {'node_name': 'post_attention_layernorm',
#  'node_op': 'call_module',
#  'node_target': 'post_attention_layernorm'}
# macro op count: 1
# macro op type summary: {'VectorOp': 1}
# macro op details:
# {'id': 524,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'rms_norm',
#  'vector_shape': [512, 16384],
#  'weight_bits': 16}
# VectorOp(id=524, input_ops=[], vector_op_type='rms_norm', vector_shape=[512, 16384], weight_bits=16)
# sim cycle: 996
# sim time ns: 544
# trace path: trace/dense/node_008_post_attention_layernorm_call_module.json
# trace event count: 5
# trace complete event count: 1
# trace complete event categories: {'compute': 1}
# ========================================================================================================================
# node index: 9
# node info:
# {'node_name': 'mlp_gate_up_proj',
#  'node_op': 'call_module',
#  'node_target': 'mlp.gate_up_proj'}
# macro op count: 18
# macro op type summary: {'SramPrefetch': 6, 'MatMulOp': 6, 'SramPrefetchRelease': 6}
# macro op details:
# {'id': 525,
#  'input_ops': [],
#  'num_prefetch_pages': 20480,
#  'type': 'SramPrefetch'}
# {'dim': (512, 16384, 2560),
#  'id': 526,
#  'input_ops': [{'id': 525, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 527,
#  'input_ops': [{'id': 526, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 528,
#  'input_ops': [],
#  'num_prefetch_pages': 20480,
#  'type': 'SramPrefetch'}
# {'dim': (512, 16384, 2560),
#  'id': 529,
#  'input_ops': [{'id': 528, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 530,
#  'input_ops': [{'id': 529, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 531,
#  'input_ops': [],
#  'num_prefetch_pages': 20480,
#  'type': 'SramPrefetch'}
# {'dim': (512, 16384, 2560),
#  'id': 532,
#  'input_ops': [{'id': 531, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 533,
#  'input_ops': [{'id': 532, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 534,
#  'input_ops': [],
#  'num_prefetch_pages': 20480,
#  'type': 'SramPrefetch'}
# {'dim': (512, 16384, 2560),
#  'id': 535,
#  'input_ops': [{'id': 534, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 536,
#  'input_ops': [{'id': 535, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 537,
#  'input_ops': [],
#  'num_prefetch_pages': 20480,
#  'type': 'SramPrefetch'}
# {'dim': (512, 16384, 2560),
#  'id': 538,
#  'input_ops': [{'id': 537, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 539,
#  'input_ops': [{'id': 538, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 540, 'input_ops': [], 'num_prefetch_pages': 4096, 'type': 'SramPrefetch'}
# {'dim': (512, 16384, 512),
#  'id': 541,
#  'input_ops': [{'id': 540, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 542,
#  'input_ops': [{'id': 541, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# MatMulOp(id=526, input_ops=[SramPrefetch(id=525, input_ops=[], num_prefetch_pages=20480)], dim=(512, 16384, 2560), weight_bits=16)
# MatMulOp(id=529, input_ops=[SramPrefetch(id=528, input_ops=[], num_prefetch_pages=20480)], dim=(512, 16384, 2560), weight_bits=16)
# MatMulOp(id=532, input_ops=[SramPrefetch(id=531, input_ops=[], num_prefetch_pages=20480)], dim=(512, 16384, 2560), weight_bits=16)
# MatMulOp(id=535, input_ops=[SramPrefetch(id=534, input_ops=[], num_prefetch_pages=20480)], dim=(512, 16384, 2560), weight_bits=16)
# MatMulOp(id=538, input_ops=[SramPrefetch(id=537, input_ops=[], num_prefetch_pages=20480)], dim=(512, 16384, 2560), weight_bits=16)
# MatMulOp(id=541, input_ops=[SramPrefetch(id=540, input_ops=[], num_prefetch_pages=4096)], dim=(512, 16384, 512), weight_bits=16)
# sim cycle: 535259
# sim time ns: 292491
# trace path: trace/dense/node_009_mlp_gate_up_proj_call_module.json
# trace event count: 16
# trace complete event count: 12
# trace complete event categories: {'prefetch': 6, 'compute': 6}
# ========================================================================================================================
# node index: 10
# node info:
# {'node_name': 'mlp_act_fn',
#  'node_op': 'call_module',
#  'node_target': 'mlp.act_fn'}
# macro op count: 1
# macro op type summary: {'VectorOp': 1}
# macro op details:
# {'id': 543,
#  'input_ops': [],
#  'type': 'VectorOp',
#  'vector_op_type': 'silu_mul',
#  'vector_shape': [512, 6656],
#  'weight_bits': 16}
# VectorOp(id=543, input_ops=[], vector_op_type='silu_mul', vector_shape=[512, 6656], weight_bits=16)
# sim cycle: 2070
# sim time ns: 1131
# trace path: trace/dense/node_010_mlp_act_fn_call_module.json
# trace event count: 5
# trace complete event count: 1
# trace complete event categories: {'compute': 1}
# ========================================================================================================================
# node index: 11
# node info:
# {'node_name': 'mlp_down_proj',
#  'node_op': 'call_module',
#  'node_target': 'mlp.down_proj'}
# macro op count: 10
# macro op type summary: {'SramPrefetch': 3, 'MatMulOp': 3, 'SramPrefetchRelease': 3, 'AllReduceOp': 1}
# macro op details:
# {'id': 544,
#  'input_ops': [],
#  'num_prefetch_pages': 20479,
#  'type': 'SramPrefetch'}
# {'dim': (512, 6656, 6301),
#  'id': 545,
#  'input_ops': [{'id': 544, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 546,
#  'input_ops': [{'id': 545, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 547,
#  'input_ops': [],
#  'num_prefetch_pages': 20479,
#  'type': 'SramPrefetch'}
# {'dim': (512, 6656, 6301),
#  'id': 548,
#  'input_ops': [{'id': 547, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 549,
#  'input_ops': [{'id': 548, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'id': 550,
#  'input_ops': [],
#  'num_prefetch_pages': 12292,
#  'type': 'SramPrefetch'}
# {'dim': (512, 6656, 3782),
#  'id': 551,
#  'input_ops': [{'id': 550, 'type': 'SramPrefetch'}],
#  'type': 'MatMulOp',
#  'weight_bits': 16}
# {'id': 552,
#  'input_ops': [{'id': 551, 'type': 'MatMulOp'}],
#  'type': 'SramPrefetchRelease'}
# {'data_size': 16777216,
#  'id': 553,
#  'input_ops': [{'id': 545, 'type': 'MatMulOp'},
#                {'id': 548, 'type': 'MatMulOp'},
#                {'id': 551, 'type': 'MatMulOp'}],
#  'num_ranks': 8,
#  'type': 'AllReduceOp',
#  'weight_bits': 16}
# MatMulOp(id=545, input_ops=[SramPrefetch(id=544, input_ops=[], num_prefetch_pages=20479)], dim=(512, 6656, 6301), weight_bits=16)
# MatMulOp(id=548, input_ops=[SramPrefetch(id=547, input_ops=[], num_prefetch_pages=20479)], dim=(512, 6656, 6301), weight_bits=16)
# MatMulOp(id=551, input_ops=[SramPrefetch(id=550, input_ops=[], num_prefetch_pages=12292)], dim=(512, 6656, 3782), weight_bits=16)
# sim cycle: 1342187
# sim time ns: 733435
# trace path: trace/dense/node_011_mlp_down_proj_call_module.json
# trace event count: 11
# trace complete event count: 7
# trace complete event categories: {'prefetch': 3, 'compute': 3, 'transfer': 1}
# ========================================================================================================================
# node index: 12
# node info:
# {'node_name': 'add_1',
#  'node_op': 'call_function',
#  'node_target': '<built-in function add>'}
# macro op count: 0
# macro op type summary: {}
# macro op details:
# simulation skipped because this node produced no macro ops

# %%
node_sim_results
# Out:
# [{'node_name': 'hidden_states',
#   'node_op': 'placeholder',
#   'node_target': 'hidden_states',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []},
#  {'node_name': 'input_layernorm',
#   'node_op': 'call_module',
#   'node_target': 'input_layernorm',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 996,
#   'sim_time_ns': 544,
#   'trace_path': 'trace/dense/node_001_input_layernorm_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 135,
#     'input_ops': [],
#     'vector_op_type': 'rms_norm',
#     'vector_shape': [512, 16384],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'self_attn_qkv_proj',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.qkv_proj',
#   'macro_op_count': 3,
#   'macro_op_types': ['SramPrefetch', 'MatMulOp', 'SramPrefetchRelease'],
#   'sim_cycle': 116793,
#   'sim_time_ns': 63821,
#   'trace_path': 'trace/dense/node_002_self_attn_qkv_proj_call_module.json',
#   'trace_event_count': 6,
#   'trace_complete_event_count': 2,
#   'trace_complete_event_categories': {'prefetch': 1, 'compute': 1},
#   'macro_ops': [{'id': 136,
#     'input_ops': [],
#     'num_prefetch_pages': 18432,
#     'type': 'SramPrefetch'},
#    {'id': 137,
#     'input_ops': [{'id': 136, 'type': 'SramPrefetch'}],
#     'dim': (512, 16384, 2304),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 138,
#     'input_ops': [{'id': 137, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'}]},
#  {'node_name': 'self_attn__dummy_positions',
#   'node_op': 'get_attr',
#   'node_target': 'self_attn._dummy_positions',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []},
#  {'node_name': 'self_attn_rotary_emb',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.rotary_emb',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []},
#  {'node_name': 'self_attn_attn',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.attn',
#   'macro_op_count': 381,
#   'macro_op_types': ['SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'FlashAttnOp',
#    'SramPrefetchRelease'],
#   'sim_cycle': 1097792,
#   'sim_time_ns': 599886,
#   'trace_path': 'trace/dense/node_005_self_attn_attn_call_module.json',
#   'trace_event_count': 258,
#   'trace_complete_event_count': 254,
#   'trace_complete_event_categories': {'prefetch': 127, 'compute': 127},
#   'macro_ops': [{'id': 139,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 140,
#     'input_ops': [{'id': 139, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 141,
#     'input_ops': [{'id': 140, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 142,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 143,
#     'input_ops': [{'id': 142, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 144,
#     'input_ops': [{'id': 143, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 145,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 146,
#     'input_ops': [{'id': 145, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 147,
#     'input_ops': [{'id': 146, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 148,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 149,
#     'input_ops': [{'id': 148, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 150,
#     'input_ops': [{'id': 149, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 151,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 152,
#     'input_ops': [{'id': 151, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 153,
#     'input_ops': [{'id': 152, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 154,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 155,
#     'input_ops': [{'id': 154, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 156,
#     'input_ops': [{'id': 155, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 157,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 158,
#     'input_ops': [{'id': 157, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 159,
#     'input_ops': [{'id': 158, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 160,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 161,
#     'input_ops': [{'id': 160, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 162,
#     'input_ops': [{'id': 161, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 163,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 164,
#     'input_ops': [{'id': 163, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 165,
#     'input_ops': [{'id': 164, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 166,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 167,
#     'input_ops': [{'id': 166, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 168,
#     'input_ops': [{'id': 167, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 169,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 170,
#     'input_ops': [{'id': 169, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 171,
#     'input_ops': [{'id': 170, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 172,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 173,
#     'input_ops': [{'id': 172, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 174,
#     'input_ops': [{'id': 173, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 175,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 176,
#     'input_ops': [{'id': 175, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 177,
#     'input_ops': [{'id': 176, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 178,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 179,
#     'input_ops': [{'id': 178, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 180,
#     'input_ops': [{'id': 179, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 181,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 182,
#     'input_ops': [{'id': 181, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 183,
#     'input_ops': [{'id': 182, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 184,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 185,
#     'input_ops': [{'id': 184, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 186,
#     'input_ops': [{'id': 185, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 187,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 188,
#     'input_ops': [{'id': 187, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 189,
#     'input_ops': [{'id': 188, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 190,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 191,
#     'input_ops': [{'id': 190, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 192,
#     'input_ops': [{'id': 191, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 193,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 194,
#     'input_ops': [{'id': 193, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 195,
#     'input_ops': [{'id': 194, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 196,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 197,
#     'input_ops': [{'id': 196, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 198,
#     'input_ops': [{'id': 197, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 199,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 200,
#     'input_ops': [{'id': 199, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 201,
#     'input_ops': [{'id': 200, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 202,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 203,
#     'input_ops': [{'id': 202, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 204,
#     'input_ops': [{'id': 203, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 205,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 206,
#     'input_ops': [{'id': 205, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 207,
#     'input_ops': [{'id': 206, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 208,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 209,
#     'input_ops': [{'id': 208, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 210,
#     'input_ops': [{'id': 209, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 211,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 212,
#     'input_ops': [{'id': 211, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 213,
#     'input_ops': [{'id': 212, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 214,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 215,
#     'input_ops': [{'id': 214, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 216,
#     'input_ops': [{'id': 215, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 217,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 218,
#     'input_ops': [{'id': 217, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 219,
#     'input_ops': [{'id': 218, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 220,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 221,
#     'input_ops': [{'id': 220, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 222,
#     'input_ops': [{'id': 221, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 223,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 224,
#     'input_ops': [{'id': 223, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 225,
#     'input_ops': [{'id': 224, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 226,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 227,
#     'input_ops': [{'id': 226, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 228,
#     'input_ops': [{'id': 227, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 229,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 230,
#     'input_ops': [{'id': 229, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 231,
#     'input_ops': [{'id': 230, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 232,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 233,
#     'input_ops': [{'id': 232, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 234,
#     'input_ops': [{'id': 233, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 235,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 236,
#     'input_ops': [{'id': 235, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 237,
#     'input_ops': [{'id': 236, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 238,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 239,
#     'input_ops': [{'id': 238, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 240,
#     'input_ops': [{'id': 239, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 241,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 242,
#     'input_ops': [{'id': 241, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 243,
#     'input_ops': [{'id': 242, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 244,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 245,
#     'input_ops': [{'id': 244, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 246,
#     'input_ops': [{'id': 245, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 247,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 248,
#     'input_ops': [{'id': 247, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 249,
#     'input_ops': [{'id': 248, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 250,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 251,
#     'input_ops': [{'id': 250, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 252,
#     'input_ops': [{'id': 251, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 253,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 254,
#     'input_ops': [{'id': 253, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 255,
#     'input_ops': [{'id': 254, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 256,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 257,
#     'input_ops': [{'id': 256, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 258,
#     'input_ops': [{'id': 257, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 259,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 260,
#     'input_ops': [{'id': 259, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 261,
#     'input_ops': [{'id': 260, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 262,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 263,
#     'input_ops': [{'id': 262, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 264,
#     'input_ops': [{'id': 263, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 265,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 266,
#     'input_ops': [{'id': 265, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 267,
#     'input_ops': [{'id': 266, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 268,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 269,
#     'input_ops': [{'id': 268, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 270,
#     'input_ops': [{'id': 269, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 271,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 272,
#     'input_ops': [{'id': 271, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 273,
#     'input_ops': [{'id': 272, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 274,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 275,
#     'input_ops': [{'id': 274, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 276,
#     'input_ops': [{'id': 275, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 277,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 278,
#     'input_ops': [{'id': 277, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 279,
#     'input_ops': [{'id': 278, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 280,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 281,
#     'input_ops': [{'id': 280, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 282,
#     'input_ops': [{'id': 281, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 283,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 284,
#     'input_ops': [{'id': 283, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 285,
#     'input_ops': [{'id': 284, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 286,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 287,
#     'input_ops': [{'id': 286, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 288,
#     'input_ops': [{'id': 287, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 289,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 290,
#     'input_ops': [{'id': 289, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 291,
#     'input_ops': [{'id': 290, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 292,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 293,
#     'input_ops': [{'id': 292, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 294,
#     'input_ops': [{'id': 293, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 295,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 296,
#     'input_ops': [{'id': 295, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 297,
#     'input_ops': [{'id': 296, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 298,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 299,
#     'input_ops': [{'id': 298, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 300,
#     'input_ops': [{'id': 299, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 301,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 302,
#     'input_ops': [{'id': 301, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 303,
#     'input_ops': [{'id': 302, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 304,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 305,
#     'input_ops': [{'id': 304, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 306,
#     'input_ops': [{'id': 305, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 307,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 308,
#     'input_ops': [{'id': 307, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 309,
#     'input_ops': [{'id': 308, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 310,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 311,
#     'input_ops': [{'id': 310, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 312,
#     'input_ops': [{'id': 311, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 313,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 314,
#     'input_ops': [{'id': 313, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 315,
#     'input_ops': [{'id': 314, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 316,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 317,
#     'input_ops': [{'id': 316, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 318,
#     'input_ops': [{'id': 317, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 319,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 320,
#     'input_ops': [{'id': 319, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 321,
#     'input_ops': [{'id': 320, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 322,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 323,
#     'input_ops': [{'id': 322, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 324,
#     'input_ops': [{'id': 323, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 325,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 326,
#     'input_ops': [{'id': 325, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 327,
#     'input_ops': [{'id': 326, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 328,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 329,
#     'input_ops': [{'id': 328, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 330,
#     'input_ops': [{'id': 329, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 331,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 332,
#     'input_ops': [{'id': 331, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 333,
#     'input_ops': [{'id': 332, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 334,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 335,
#     'input_ops': [{'id': 334, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 336,
#     'input_ops': [{'id': 335, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 337,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 338,
#     'input_ops': [{'id': 337, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 339,
#     'input_ops': [{'id': 338, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 340,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 341,
#     'input_ops': [{'id': 340, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 342,
#     'input_ops': [{'id': 341, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 343,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 344,
#     'input_ops': [{'id': 343, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 345,
#     'input_ops': [{'id': 344, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 346,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 347,
#     'input_ops': [{'id': 346, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 348,
#     'input_ops': [{'id': 347, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 349,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 350,
#     'input_ops': [{'id': 349, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 351,
#     'input_ops': [{'id': 350, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 352,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 353,
#     'input_ops': [{'id': 352, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 354,
#     'input_ops': [{'id': 353, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 355,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 356,
#     'input_ops': [{'id': 355, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 357,
#     'input_ops': [{'id': 356, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 358,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 359,
#     'input_ops': [{'id': 358, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 360,
#     'input_ops': [{'id': 359, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 361,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 362,
#     'input_ops': [{'id': 361, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 363,
#     'input_ops': [{'id': 362, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 364,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 365,
#     'input_ops': [{'id': 364, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 366,
#     'input_ops': [{'id': 365, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 367,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 368,
#     'input_ops': [{'id': 367, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 369,
#     'input_ops': [{'id': 368, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 370,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 371,
#     'input_ops': [{'id': 370, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 372,
#     'input_ops': [{'id': 371, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 373,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 374,
#     'input_ops': [{'id': 373, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 375,
#     'input_ops': [{'id': 374, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 376,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 377,
#     'input_ops': [{'id': 376, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 378,
#     'input_ops': [{'id': 377, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 379,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 380,
#     'input_ops': [{'id': 379, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 381,
#     'input_ops': [{'id': 380, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 382,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 383,
#     'input_ops': [{'id': 382, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 384,
#     'input_ops': [{'id': 383, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 385,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 386,
#     'input_ops': [{'id': 385, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 387,
#     'input_ops': [{'id': 386, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 388,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 389,
#     'input_ops': [{'id': 388, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 390,
#     'input_ops': [{'id': 389, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 391,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 392,
#     'input_ops': [{'id': 391, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
# ...
#     'type': 'SramPrefetchRelease'},
#    {'id': 463,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 464,
#     'input_ops': [{'id': 463, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 465,
#     'input_ops': [{'id': 464, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 466,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 467,
#     'input_ops': [{'id': 466, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 468,
#     'input_ops': [{'id': 467, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 469,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 470,
#     'input_ops': [{'id': 469, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 471,
#     'input_ops': [{'id': 470, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 472,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 473,
#     'input_ops': [{'id': 472, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 474,
#     'input_ops': [{'id': 473, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 475,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 476,
#     'input_ops': [{'id': 475, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 477,
#     'input_ops': [{'id': 476, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 478,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 479,
#     'input_ops': [{'id': 478, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 480,
#     'input_ops': [{'id': 479, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 481,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 482,
#     'input_ops': [{'id': 481, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 483,
#     'input_ops': [{'id': 482, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 484,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 485,
#     'input_ops': [{'id': 484, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 486,
#     'input_ops': [{'id': 485, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 487,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 488,
#     'input_ops': [{'id': 487, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 489,
#     'input_ops': [{'id': 488, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 490,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 491,
#     'input_ops': [{'id': 490, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 492,
#     'input_ops': [{'id': 491, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 493,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 494,
#     'input_ops': [{'id': 493, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 495,
#     'input_ops': [{'id': 494, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 496,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 497,
#     'input_ops': [{'id': 496, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 498,
#     'input_ops': [{'id': 497, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 499,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 500,
#     'input_ops': [{'id': 499, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 501,
#     'input_ops': [{'id': 500, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 502,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 503,
#     'input_ops': [{'id': 502, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 504,
#     'input_ops': [{'id': 503, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 505,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 506,
#     'input_ops': [{'id': 505, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 507,
#     'input_ops': [{'id': 506, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 508,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 509,
#     'input_ops': [{'id': 508, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 510,
#     'input_ops': [{'id': 509, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 511,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 512,
#     'input_ops': [{'id': 511, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 513,
#     'input_ops': [{'id': 512, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 514,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 515,
#     'input_ops': [{'id': 514, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 516,
#     'input_ops': [{'id': 515, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 517,
#     'input_ops': [],
#     'num_prefetch_pages': 4608,
#     'type': 'SramPrefetch'},
#    {'id': 518,
#     'input_ops': [{'id': 517, 'type': 'SramPrefetch'}],
#     'qk_bmm_shape': (72, 16, 128, 512),
#     'sv_bmm_shape': (72, 16, 512, 128),
#     'softmax_shape': (1152, 512),
#     'weight_bits': 16,
#     'type': 'FlashAttnOp'},
#    {'id': 519,
#     'input_ops': [{'id': 518, 'type': 'FlashAttnOp'}],
#     'type': 'SramPrefetchRelease'}]},
#  {'node_name': 'self_attn_o_proj',
#   'node_op': 'call_module',
#   'node_target': 'self_attn.o_proj',
#   'macro_op_count': 4,
#   'macro_op_types': ['SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'AllReduceOp'],
#   'sim_cycle': 1153320,
#   'sim_time_ns': 630229,
#   'trace_path': 'trace/dense/node_006_self_attn_o_proj_call_module.json',
#   'trace_event_count': 7,
#   'trace_complete_event_count': 3,
#   'trace_complete_event_categories': {'prefetch': 1,
#    'compute': 1,
#    'transfer': 1},
#   'macro_ops': [{'id': 520,
#     'input_ops': [],
#     'num_prefetch_pages': 16384,
#     'type': 'SramPrefetch'},
#    {'id': 521,
#     'input_ops': [{'id': 520, 'type': 'SramPrefetch'}],
#     'dim': (512, 2048, 16384),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 522,
#     'input_ops': [{'id': 521, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 523,
#     'input_ops': [{'id': 521, 'type': 'MatMulOp'}],
#     'num_ranks': 8,
#     'data_size': 16777216,
#     'weight_bits': 16,
#     'type': 'AllReduceOp'}]},
#  {'node_name': 'add',
#   'node_op': 'call_function',
#   'node_target': '<built-in function add>',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []},
#  {'node_name': 'post_attention_layernorm',
#   'node_op': 'call_module',
#   'node_target': 'post_attention_layernorm',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 996,
#   'sim_time_ns': 544,
#   'trace_path': 'trace/dense/node_008_post_attention_layernorm_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 524,
#     'input_ops': [],
#     'vector_op_type': 'rms_norm',
#     'vector_shape': [512, 16384],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'mlp_gate_up_proj',
#   'node_op': 'call_module',
#   'node_target': 'mlp.gate_up_proj',
#   'macro_op_count': 18,
#   'macro_op_types': ['SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease'],
#   'sim_cycle': 535259,
#   'sim_time_ns': 292491,
#   'trace_path': 'trace/dense/node_009_mlp_gate_up_proj_call_module.json',
#   'trace_event_count': 16,
#   'trace_complete_event_count': 12,
#   'trace_complete_event_categories': {'prefetch': 6, 'compute': 6},
#   'macro_ops': [{'id': 525,
#     'input_ops': [],
#     'num_prefetch_pages': 20480,
#     'type': 'SramPrefetch'},
#    {'id': 526,
#     'input_ops': [{'id': 525, 'type': 'SramPrefetch'}],
#     'dim': (512, 16384, 2560),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 527,
#     'input_ops': [{'id': 526, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 528,
#     'input_ops': [],
#     'num_prefetch_pages': 20480,
#     'type': 'SramPrefetch'},
#    {'id': 529,
#     'input_ops': [{'id': 528, 'type': 'SramPrefetch'}],
#     'dim': (512, 16384, 2560),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 530,
#     'input_ops': [{'id': 529, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 531,
#     'input_ops': [],
#     'num_prefetch_pages': 20480,
#     'type': 'SramPrefetch'},
#    {'id': 532,
#     'input_ops': [{'id': 531, 'type': 'SramPrefetch'}],
#     'dim': (512, 16384, 2560),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 533,
#     'input_ops': [{'id': 532, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 534,
#     'input_ops': [],
#     'num_prefetch_pages': 20480,
#     'type': 'SramPrefetch'},
#    {'id': 535,
#     'input_ops': [{'id': 534, 'type': 'SramPrefetch'}],
#     'dim': (512, 16384, 2560),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 536,
#     'input_ops': [{'id': 535, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 537,
#     'input_ops': [],
#     'num_prefetch_pages': 20480,
#     'type': 'SramPrefetch'},
#    {'id': 538,
#     'input_ops': [{'id': 537, 'type': 'SramPrefetch'}],
#     'dim': (512, 16384, 2560),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 539,
#     'input_ops': [{'id': 538, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 540,
#     'input_ops': [],
#     'num_prefetch_pages': 4096,
#     'type': 'SramPrefetch'},
#    {'id': 541,
#     'input_ops': [{'id': 540, 'type': 'SramPrefetch'}],
#     'dim': (512, 16384, 512),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 542,
#     'input_ops': [{'id': 541, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'}]},
#  {'node_name': 'mlp_act_fn',
#   'node_op': 'call_module',
#   'node_target': 'mlp.act_fn',
#   'macro_op_count': 1,
#   'macro_op_types': ['VectorOp'],
#   'sim_cycle': 2070,
#   'sim_time_ns': 1131,
#   'trace_path': 'trace/dense/node_010_mlp_act_fn_call_module.json',
#   'trace_event_count': 5,
#   'trace_complete_event_count': 1,
#   'trace_complete_event_categories': {'compute': 1},
#   'macro_ops': [{'id': 543,
#     'input_ops': [],
#     'vector_op_type': 'silu_mul',
#     'vector_shape': [512, 6656],
#     'weight_bits': 16,
#     'type': 'VectorOp'}]},
#  {'node_name': 'mlp_down_proj',
#   'node_op': 'call_module',
#   'node_target': 'mlp.down_proj',
#   'macro_op_count': 10,
#   'macro_op_types': ['SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'SramPrefetch',
#    'MatMulOp',
#    'SramPrefetchRelease',
#    'AllReduceOp'],
#   'sim_cycle': 1342187,
#   'sim_time_ns': 733435,
#   'trace_path': 'trace/dense/node_011_mlp_down_proj_call_module.json',
#   'trace_event_count': 11,
#   'trace_complete_event_count': 7,
#   'trace_complete_event_categories': {'prefetch': 3,
#    'compute': 3,
#    'transfer': 1},
#   'macro_ops': [{'id': 544,
#     'input_ops': [],
#     'num_prefetch_pages': 20479,
#     'type': 'SramPrefetch'},
#    {'id': 545,
#     'input_ops': [{'id': 544, 'type': 'SramPrefetch'}],
#     'dim': (512, 6656, 6301),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 546,
#     'input_ops': [{'id': 545, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 547,
#     'input_ops': [],
#     'num_prefetch_pages': 20479,
#     'type': 'SramPrefetch'},
#    {'id': 548,
#     'input_ops': [{'id': 547, 'type': 'SramPrefetch'}],
#     'dim': (512, 6656, 6301),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 549,
#     'input_ops': [{'id': 548, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 550,
#     'input_ops': [],
#     'num_prefetch_pages': 12292,
#     'type': 'SramPrefetch'},
#    {'id': 551,
#     'input_ops': [{'id': 550, 'type': 'SramPrefetch'}],
#     'dim': (512, 6656, 3782),
#     'weight_bits': 16,
#     'type': 'MatMulOp'},
#    {'id': 552,
#     'input_ops': [{'id': 551, 'type': 'MatMulOp'}],
#     'type': 'SramPrefetchRelease'},
#    {'id': 553,
#     'input_ops': [{'id': 545, 'type': 'MatMulOp'},
#      {'id': 548, 'type': 'MatMulOp'},
#      {'id': 551, 'type': 'MatMulOp'}],
#     'num_ranks': 8,
#     'data_size': 16777216,
#     'weight_bits': 16,
#     'type': 'AllReduceOp'}]},
#  {'node_name': 'add_1',
#   'node_op': 'call_function',
#   'node_target': '<built-in function add>',
#   'macro_op_count': 0,
#   'macro_op_types': [],
#   'sim_cycle': None,
#   'sim_time_ns': None,
#   'trace_path': None,
#   'trace_event_count': None,
#   'trace_complete_event_count': None,
#   'trace_complete_event_categories': None,
#   'macro_ops': []}]

# %%
non_empty_node_results = [result for result in node_sim_results if result["macro_op_count"] > 0]
empty_node_results = [result for result in node_sim_results if result["macro_op_count"] == 0]

assert len(node_sim_results) == len(all_graph_nodes)
assert full_sim_result["cycle"] > 0
assert full_sim_result["time_ns"] > 0
assert full_sim_result["trace_path"] is not None
assert full_sim_result["trace_event_count"] is not None
assert full_sim_result["trace_complete_event_count"] is not None
assert non_empty_node_results
assert all(result["sim_cycle"] is not None for result in non_empty_node_results)
assert all(result["sim_time_ns"] is not None for result in non_empty_node_results)
assert all(result["trace_path"] is not None for result in non_empty_node_results)
assert all(result["trace_event_count"] is not None for result in non_empty_node_results)
assert all(result["trace_complete_event_count"] is not None for result in non_empty_node_results)
assert all(result["sim_cycle"] is None for result in empty_node_results)
assert all(result["trace_path"] is None for result in empty_node_results)

full_sim_summary = {
    "macro_op_count": len(macro_op_list),
    "macro_op_type_summary": dict(macro_summary(macro_op_list)),
    "sim_cycle": full_sim_result["cycle"],
    "sim_time_ns": full_sim_result["time_ns"],
    "trace_path": full_sim_result["trace_path"],
    "trace_event_count": full_sim_result["trace_event_count"],
    "trace_complete_event_count": full_sim_result["trace_complete_event_count"],
    "trace_complete_event_categories": full_sim_result[
        "trace_complete_event_categories"
    ],
}

summary_rows = [
    {
        "node_name": result["node_name"],
        "node_op": result["node_op"],
        "node_target": result["node_target"],
        "macro_op_count": result["macro_op_count"],
        "macro_op_types": result["macro_op_types"],
        "sim_cycle": result["sim_cycle"],
        "sim_time_ns": result["sim_time_ns"],
        "trace_path": result["trace_path"],
        "trace_event_count": result["trace_event_count"],
        "trace_complete_event_count": result["trace_complete_event_count"],
        "trace_complete_event_categories": result["trace_complete_event_categories"],
    }
    for result in node_sim_results
]

{
    "full_simulation": full_sim_summary,
    "node_simulations": summary_rows,
}
# Out:
# {'full_simulation': {'macro_op_count': 419,
#   'macro_op_type_summary': {'VectorOp': 3,
#    'SramPrefetch': 138,
#    'MatMulOp': 11,
#    'SramPrefetchRelease': 138,
#    'FlashAttnOp': 127,
#    'AllReduceOp': 2},
#   'sim_cycle': 4149990,
#   'sim_time_ns': 2267754,
#   'trace_path': 'trace/dense/full_simulation.json',
#   'trace_event_count': 285,
#   'trace_complete_event_count': 281,
#   'trace_complete_event_categories': {'compute': 141,
#    'prefetch': 138,
#    'transfer': 2}},
#  'node_simulations': [{'node_name': 'hidden_states',
#    'node_op': 'placeholder',
#    'node_target': 'hidden_states',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None},
#   {'node_name': 'input_layernorm',
#    'node_op': 'call_module',
#    'node_target': 'input_layernorm',
#    'macro_op_count': 1,
#    'macro_op_types': ['VectorOp'],
#    'sim_cycle': 996,
#    'sim_time_ns': 544,
#    'trace_path': 'trace/dense/node_001_input_layernorm_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'self_attn_qkv_proj',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.qkv_proj',
#    'macro_op_count': 3,
#    'macro_op_types': ['SramPrefetch', 'MatMulOp', 'SramPrefetchRelease'],
#    'sim_cycle': 116793,
#    'sim_time_ns': 63821,
#    'trace_path': 'trace/dense/node_002_self_attn_qkv_proj_call_module.json',
#    'trace_event_count': 6,
#    'trace_complete_event_count': 2,
#    'trace_complete_event_categories': {'prefetch': 1, 'compute': 1}},
#   {'node_name': 'self_attn__dummy_positions',
#    'node_op': 'get_attr',
#    'node_target': 'self_attn._dummy_positions',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None},
#   {'node_name': 'self_attn_rotary_emb',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.rotary_emb',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None},
#   {'node_name': 'self_attn_attn',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.attn',
#    'macro_op_count': 381,
#    'macro_op_types': ['SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'FlashAttnOp',
#     'SramPrefetchRelease'],
#    'sim_cycle': 1097792,
#    'sim_time_ns': 599886,
#    'trace_path': 'trace/dense/node_005_self_attn_attn_call_module.json',
#    'trace_event_count': 258,
#    'trace_complete_event_count': 254,
#    'trace_complete_event_categories': {'prefetch': 127, 'compute': 127}},
#   {'node_name': 'self_attn_o_proj',
#    'node_op': 'call_module',
#    'node_target': 'self_attn.o_proj',
#    'macro_op_count': 4,
#    'macro_op_types': ['SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'AllReduceOp'],
#    'sim_cycle': 1153320,
#    'sim_time_ns': 630229,
#    'trace_path': 'trace/dense/node_006_self_attn_o_proj_call_module.json',
#    'trace_event_count': 7,
#    'trace_complete_event_count': 3,
#    'trace_complete_event_categories': {'prefetch': 1,
#     'compute': 1,
#     'transfer': 1}},
#   {'node_name': 'add',
#    'node_op': 'call_function',
#    'node_target': '<built-in function add>',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None},
#   {'node_name': 'post_attention_layernorm',
#    'node_op': 'call_module',
#    'node_target': 'post_attention_layernorm',
#    'macro_op_count': 1,
#    'macro_op_types': ['VectorOp'],
#    'sim_cycle': 996,
#    'sim_time_ns': 544,
#    'trace_path': 'trace/dense/node_008_post_attention_layernorm_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'mlp_gate_up_proj',
#    'node_op': 'call_module',
#    'node_target': 'mlp.gate_up_proj',
#    'macro_op_count': 18,
#    'macro_op_types': ['SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease'],
#    'sim_cycle': 535259,
#    'sim_time_ns': 292491,
#    'trace_path': 'trace/dense/node_009_mlp_gate_up_proj_call_module.json',
#    'trace_event_count': 16,
#    'trace_complete_event_count': 12,
#    'trace_complete_event_categories': {'prefetch': 6, 'compute': 6}},
#   {'node_name': 'mlp_act_fn',
#    'node_op': 'call_module',
#    'node_target': 'mlp.act_fn',
#    'macro_op_count': 1,
#    'macro_op_types': ['VectorOp'],
#    'sim_cycle': 2070,
#    'sim_time_ns': 1131,
#    'trace_path': 'trace/dense/node_010_mlp_act_fn_call_module.json',
#    'trace_event_count': 5,
#    'trace_complete_event_count': 1,
#    'trace_complete_event_categories': {'compute': 1}},
#   {'node_name': 'mlp_down_proj',
#    'node_op': 'call_module',
#    'node_target': 'mlp.down_proj',
#    'macro_op_count': 10,
#    'macro_op_types': ['SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'SramPrefetch',
#     'MatMulOp',
#     'SramPrefetchRelease',
#     'AllReduceOp'],
#    'sim_cycle': 1342187,
#    'sim_time_ns': 733435,
#    'trace_path': 'trace/dense/node_011_mlp_down_proj_call_module.json',
#    'trace_event_count': 11,
#    'trace_complete_event_count': 7,
#    'trace_complete_event_categories': {'prefetch': 3,
#     'compute': 3,
#     'transfer': 1}},
#   {'node_name': 'add_1',
#    'node_op': 'call_function',
#    'node_target': '<built-in function add>',
#    'macro_op_count': 0,
#    'macro_op_types': [],
#    'sim_cycle': None,
#    'sim_time_ns': None,
#    'trace_path': None,
#    'trace_event_count': None,
#    'trace_complete_event_count': None,
#    'trace_complete_event_categories': None}]}

# %%
print(kv_cache_state)
# Out:
# KVCacheState(total_kv_cache_size_per_layer=19126026240, kv_block_size_tokens=64, num_kv_blocks=72960, num_nand_pages_per_layer=4669440, num_hyper_pages_per_layer=1014)
